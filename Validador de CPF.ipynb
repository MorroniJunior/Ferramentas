# %% [markdown]
# ## Case Validador de CPF:
#
# O desafio é montar um validador de CPF que não demore muito para rodar.
#
# Primeiro, vamos entender como esse validador funciona e depois vamos para o código.
#
# Um CPF é composto de 11 dígitos, sendo seus 2 últimos dígitos funções dos dígitos anteriores.
#
# Chamaremos, nesse case, os dois últimos dígitos de dígitos de validação.
#
# As fórmulas para o primeiro dígito de validação são:
#
#   $$Soma_1 = D_1 * 10 + D_2 * 9 + D_3 * 8 + D_4 * 7 + D_5 * 6 + D_6 * 5 + D_7 * 4 + D_8 * 3 + D_9 * 2$$
#
#   $$r_1 = (Soma_1 * 10) / 11 $$
#
# Para que o CPF seja válido, $D_{10}$, ou seja, primeiro dígito de validação, deve ser igual ao resto de $r_1$, em que, $D_1$, $D_2$, $D_3$, ... , $D_9$ são o primeiro, segundo, terceiro, e assim sucessivamente, até o nono dígito do CPF.
#
# Já para o segundo dígito de validação do CPF, ou $D11$, temos algo parecido, porém agora, utilizamos o $D10$ também, obtendo a seguinte equação.
#
#
#   $$Soma_2 = D_1 * 11 + D_2 * 10 + D_3 * 9 + D_4 * 8 + D_5 * 7 + D_6 * 6 + D_7 * 5 + D_8 * 4 + D_9 * 3 + D_{10} * 2$$
#
#   $$r_2 = (Soma_2 * 10) / 11 $$
#
# Para que o número do CPF seja válido, $D_{11}$ também deve ser igual ao resto de $r_2$.
#
# Fazendo um exemplo:
#
#  CPF = 454.325.088-50
# $$Soma_1 = 4 * 10 + 5 * 9 + 4 * 8 + 3 * 7 + 2 * 6 + 5 * 5 + 0 * 4 + 8 * 3 + 8 * 2$$
# $$r_1 = (215 * 10) / 11  = 195.45$$
#
# Portanto, arredondando, $r_1 = D10$
#
# $$Soma_2 = 4 * 11 + 5 * 10 + 4 * 9 + 3 * 8 + 2 * 7 + 5 * 6 + 0 * 5 + 8 * 4 + 8 * 3 + 5 * 2$$
#
#  $$r_2 = (264 * 10) / 11 = 240.0$$
#
# Pelo resto de $r_2$ ser igual ao $D_{11}$ e resto de $r_1$ ser igual a $D10$, temos que o CPF 454.325.088-50 é válido.
#
# ### Fazendo os códigos:

# %%
def validacao_cpf(cpf):
    '''
    Função que recebe um CPF e tem como objetivo retornar se esse número de CPF é válido ou não
    
    '''
    if(type(cpf == int)):  #Caso o CPF inserido seja do tipo INT, transformamos em string para que possamos
        cpf = str(cpf)     #passar para uma lista e trabalhar com os números separadamente
        
    cpf1 = list(cpf)       #Separando os número em uma lista
    NOVO_CPF = ''.join(filter(str.isdigit, cpf1))        #Funcao para tirar caracteres especiais da lista
    
    if(NOVO_CPF == NOVO_CPF[0] * 11):                         #Não validando CPFs que os dígitos são todos iguais 
        return print("O CPF {} não é válido.".format(cpf))    # ex: 000.000.000-00 ou 111.111.111-11
    
    if(len(NOVO_CPF) == 11):               #Calculando as multiplicações para fazer a soma 1
        n1 = int(NOVO_CPF[0]) * 10
        n2 = int(NOVO_CPF[1]) * 9
        n3 = int(NOVO_CPF[2]) * 8
        n4 = int(NOVO_CPF[3]) * 7
        n5 = int(NOVO_CPF[4]) * 6
        n6 = int(NOVO_CPF[5]) * 5
        n7 = int(NOVO_CPF[6]) * 4
        n8 = int(NOVO_CPF[7]) * 3
        n9 = int(NOVO_CPF[8]) * 2

        m1 = int(NOVO_CPF[0]) * 11         #Calculando as multiplicações para fazer a soma 2
        m2 = int(NOVO_CPF[1]) * 10
        m3 = int(NOVO_CPF[2]) * 9
        m4 = int(NOVO_CPF[3]) * 8
        m5 = int(NOVO_CPF[4]) * 7
        m6 = int(NOVO_CPF[5]) * 6
        m7 = int(NOVO_CPF[6]) * 5
        m8 = int(NOVO_CPF[7]) * 4
        m9 = int(NOVO_CPF[8]) * 3
        m10 = int(NOVO_CPF[9]) * 2
        soma_validacao = (n1 + n2 + n3 + n4 + n5 + n6 + n7 + n8 + n9) * 10    #Calculando a soma 1
        resto1 = soma_validacao%11    #Calculando o resto da soma 1
        soma_validacao_2 = (m1 + m2 + m3 + m4 + m5 + m6 + m7 + m8 + m9 + m10) * 10     # Calculando a soma 2
        resto2 = soma_validacao_2%11    #Calculando o resto da soma 2
        if (resto1 != int(NOVO_CPF[9])):  #Caso o resto da soma 1 seja diferente do D10 (como explicado em cima), não é valido
            return print("O CPF {} não é válido.".format(cpf))
        if (resto2 != int(NOVO_CPF[10])): #Caso o resto da soma 2 seja diferente do D11 (como explicado em cima), não é valido
            return print("O CPF {} não é válido.".format(cpf))
        else:             #Caso ambos os números correspondam aos restos, então o cpf é válido
            return print("O CPF {} é válido.".format(cpf))
    else:
        return print("O CPF {} não é válido.".format(cpf))

# %%
def validar_cpf(cpf):
    '''
    Função que recebe um CPF e tem como objetivo retornar se esse número de CPF é válido ou não
    
    '''  
    
    if(type(cpf == int)):  #Caso o CPF inserido seja do tipo INT, transformamos em string para que possamos
        cpf = str(cpf)     #passar para uma lista e trabalhar com os números separadamente
        
    cpf1 = list(cpf) #Separando os número em uma lista
    cpf1 = ''.join(filter(str.isdigit, cpf1))  #Funcao para tirar caracteres especiais da lista
    
    if(cpf1 == cpf1[0] * 11):                                   #Não validando CPFs que os dígitos são todos iguais
        return print("O CPF {} não é válido.".format(cpf))      # ex: 000.000.000-00 ou 111.111.111-11
    
    #Invalidando o cpf caso o usuário insira menos ou mais de 11 numeros
    if(len(cpf1) != 11):
        return print("O CPF {} não é válido.".format(cpf))
    
    #Validando o primeiro dígito de validação, o D10
    s = 0
    for i in range(0,9):
        s += int(cpf1[i]) * (10-i)
    val = s*10%11
    if(val != int(cpf1[9])):
        return print("O CPF {} não é válido.".format(cpf))
    
    #Validando o segundo dígito de validação, o D11
    s2 = 0
    for i in range(0,10):
        s2 += int(cpf1[i]) * (11-i)
    val2 = s2*10%11
    if(val2 != int(cpf1[10])):
        return print("O CPF {} não é válido.".format(cpf))
    else:
        return print("O CPF {} é válido.".format(cpf))

# %%
def somaeresto(x, cpf):
    '''
    Funcao que recebe o cpf e retorna o resto da divisao da soma
    '''
    s = 0
    if(x == 9):
        for i in range(0,x):
             s += int(cpf[i]) * (10-i)
    elif(x == 10):
        for i in range(0,x):
            s += int(cpf[i]) * (11-i)
    else:
         return 'Error'
    
    val = s*10%11
    return val

def validar_cpf2(cpf):
    '''
    Função que recebe um CPF e tem como objetivo retornar se esse número de CPF é válido ou não
    
    '''  
    
    if(type(cpf == int)):  #Caso o CPF inserido seja do tipo INT, transformamos em string para que possamos
        cpf = str(cpf)     #passar para uma lista e trabalhar com os números separadamente
        
    cpf1 = list(cpf)       #Separando os número em uma lista
    cpf1 = ''.join(filter(str.isdigit, cpf1))  #Funcao para tirar caracteres especiais da lista
    
    if(cpf1 == cpf1[0] * 11):                                   #Invalidando validando CPFs que os dígitos são todos iguais
        return print("O CPF {} não é válido.".format(cpf))      # ex: 000.000.000-00 ou 111.111.111-11
    
    #Invalidando o cpf caso o usuário insira menos ou mais de 11 numeros
    if(len(cpf1) != 11):
        return print("O CPF {} não é válido.".format(cpf))
    
    #Validando o primeiro dígito de validação, o D10
    val = somaeresto(9,cpf1)
    if(val != int(cpf1[9])):
        return print("O CPF {} não é válido.".format(cpf))
    #Validando o segundo dígito de validação, o D11
    val2 = somaeresto(10,cpf1)
    if(val2 != int(cpf1[10])):
        return print("O CPF {} não é válido.".format(cpf))
    else:
        return print("O CPF {} é válido.".format(cpf))

# %%
def recurssiva(cpf, soma, x):
    '''
    Retorna a soma de maneira recurssiva
    '''
    if(len(cpf) == 0):
        return soma
    else:
        soma += int(cpf[0]) * x
        cpf = cpf[1:]
    return recurssiva(cpf, soma, x-1)


def validar_recurssiva(cpf):
    '''
    Função que recebe um CPF e tem como objetivo retornar se esse número de CPF é válido ou não
    
    '''  
    
    if(type(cpf == int)):  #Caso o CPF inserido seja do tipo INT, transformamos em string para que possamos
        cpf = str(cpf)     #passar para uma lista e trabalhar com os números separadamente
        
    cpf1 = list(cpf) #Separando os número em uma lista
    cpf1 = ''.join(filter(str.isdigit, cpf1))  #Funcao para tirar caracteres especiais da lista
    
    if(cpf1 == cpf1[0] * 11):                                   #Não validando CPFs que os dígitos são todos iguais
        return print("O CPF {} não é válido.".format(cpf))      # ex: 000.000.000-00 ou 111.111.111-11
    
    #Invalidando o cpf caso o usuário insira menos ou mais de 11 numeros
    if(len(cpf1) != 11):
        return print("O CPF {} não é válido.".format(cpf))
    
    #Validando o primeiro dígito de validação, o D10
    
    s = recurssiva(cpf1[:-2],0,10)
    val = s*10%11
    if(val != int(cpf1[9])):
        return print("O CPF {} não é válido.".format(cpf))
    
    #Validando o segundo dígito de validação, o D11
    s2 = recurssiva(cpf1[:-1],0,11)
    val2 = s2*10%11
    if(val2 != int(cpf1[10])):
        return print("O CPF {} não é válido.".format(cpf))
    else:
        return print("O CPF {} é válido.".format(cpf))

# %% [markdown]
# ### Fazendo alguns testes:

# %%
validar_cpf('454.325.088-50')
validacao_cpf('45432508850')
validar_cpf2(45432508850)
validar_recurssiva('454.325.088-50')
# Out:
# O CPF 454.325.088-50 é válido.
# O CPF 45432508850 é válido.
# O CPF 45432508850 é válido.
# O CPF 454.325.088-50 é válido.

# %% [markdown]
# #### Portanto, vimos que ambas as 4 funções estão funcionando, tendo em vista que foram testada. Agora, a fim de verificar qual é a mais rápida, iremos testar 10.000 números diferentes.

# %%
num_samples = 10_000
cpfs = []
for i in range(0,num_samples):
    cpfs.append('{:011}'.format(i))

# %%
import time
from tqdm import tqdm
start_time = time.time()
_ = [validar_cpf(cpf) for cpf in cpfs]   
end_time = time.time()
# Out:
# O CPF 00000000000 não é válido.
# O CPF 00000000001 não é válido.
# O CPF 00000000002 não é válido.
# O CPF 00000000003 não é válido.
# O CPF 00000000004 não é válido.
# O CPF 00000000005 não é válido.
# O CPF 00000000006 não é válido.
# O CPF 00000000007 não é válido.
# O CPF 00000000008 não é válido.
# O CPF 00000000009 não é válido.
# O CPF 00000000010 não é válido.
# O CPF 00000000011 não é válido.
# O CPF 00000000012 não é válido.
# O CPF 00000000013 não é válido.
# O CPF 00000000014 não é válido.
# O CPF 00000000015 não é válido.
# O CPF 00000000016 não é válido.
# O CPF 00000000017 não é válido.
# O CPF 00000000018 não é válido.
# O CPF 00000000019 não é válido.
# O CPF 00000000020 não é válido.
# O CPF 00000000021 não é válido.
# O CPF 00000000022 não é válido.
# O CPF 00000000023 não é válido.
# O CPF 00000000024 não é válido.
# O CPF 00000000025 não é válido.
# O CPF 00000000026 não é válido.
# O CPF 00000000027 não é válido.
# O CPF 00000000028 não é válido.
# O CPF 00000000029 não é válido.
# O CPF 00000000030 não é válido.
# O CPF 00000000031 não é válido.
# O CPF 00000000032 não é válido.
# O CPF 00000000033 não é válido.
# O CPF 00000000034 não é válido.
# O CPF 00000000035 não é válido.
# O CPF 00000000036 não é válido.
# O CPF 00000000037 não é válido.
# O CPF 00000000038 não é válido.
# O CPF 00000000039 não é válido.
# O CPF 00000000040 não é válido.
# O CPF 00000000041 não é válido.
# O CPF 00000000042 não é válido.
# O CPF 00000000043 não é válido.
# O CPF 00000000044 não é válido.
# O CPF 00000000045 não é válido.
# O CPF 00000000046 não é válido.
# O CPF 00000000047 não é válido.
# O CPF 00000000048 não é válido.
# O CPF 00000000049 não é válido.
# O CPF 00000000050 não é válido.
# O CPF 00000000051 não é válido.
# O CPF 00000000052 não é válido.
# O CPF 00000000053 não é válido.
# O CPF 00000000054 não é válido.
# O CPF 00000000055 não é válido.
# O CPF 00000000056 não é válido.
# O CPF 00000000057 não é válido.
# O CPF 00000000058 não é válido.
# O CPF 00000000059 não é válido.
# O CPF 00000000060 não é válido.
# O CPF 00000000061 não é válido.
# O CPF 00000000062 não é válido.
# O CPF 00000000063 não é válido.
# O CPF 00000000064 não é válido.
# O CPF 00000000065 não é válido.
# O CPF 00000000066 não é válido.
# O CPF 00000000067 não é válido.
# O CPF 00000000068 não é válido.
# O CPF 00000000069 não é válido.
# O CPF 00000000070 não é válido.
# O CPF 00000000071 não é válido.
# O CPF 00000000072 não é válido.
# O CPF 00000000073 não é válido.
# O CPF 00000000074 não é válido.
# O CPF 00000000075 não é válido.
# O CPF 00000000076 não é válido.
# O CPF 00000000077 não é válido.
# O CPF 00000000078 não é válido.
# O CPF 00000000079 não é válido.
# O CPF 00000000080 não é válido.
# O CPF 00000000081 não é válido.
# O CPF 00000000082 não é válido.
# O CPF 00000000083 não é válido.
# O CPF 00000000084 não é válido.
# O CPF 00000000085 não é válido.
# O CPF 00000000086 não é válido.
# O CPF 00000000087 não é válido.
# O CPF 00000000088 não é válido.
# O CPF 00000000089 não é válido.
# O CPF 00000000090 não é válido.
# O CPF 00000000091 não é válido.
# O CPF 00000000092 não é válido.
# O CPF 00000000093 não é válido.
# O CPF 00000000094 não é válido.
# O CPF 00000000095 não é válido.
# O CPF 00000000096 não é válido.
# O CPF 00000000097 não é válido.
# O CPF 00000000098 não é válido.
# O CPF 00000000099 não é válido.
# O CPF 00000000100 não é válido.
# O CPF 00000000101 não é válido.
# O CPF 00000000102 não é válido.
# O CPF 00000000103 não é válido.
# O CPF 00000000104 não é válido.
# O CPF 00000000105 não é válido.
# O CPF 00000000106 não é válido.
# O CPF 00000000107 não é válido.
# O CPF 00000000108 não é válido.
# O CPF 00000000109 não é válido.
# O CPF 00000000110 não é válido.
# O CPF 00000000111 não é válido.
# O CPF 00000000112 não é válido.
# O CPF 00000000113 não é válido.
# O CPF 00000000114 não é válido.
# O CPF 00000000115 não é válido.
# O CPF 00000000116 não é válido.
# O CPF 00000000117 não é válido.
# O CPF 00000000118 não é válido.
# O CPF 00000000119 não é válido.
# O CPF 00000000120 não é válido.
# O CPF 00000000121 não é válido.
# O CPF 00000000122 não é válido.
# O CPF 00000000123 não é válido.
# O CPF 00000000124 não é válido.
# O CPF 00000000125 não é válido.
# O CPF 00000000126 não é válido.
# O CPF 00000000127 não é válido.
# O CPF 00000000128 não é válido.
# O CPF 00000000129 não é válido.
# O CPF 00000000130 não é válido.
# O CPF 00000000131 não é válido.
# O CPF 00000000132 não é válido.
# O CPF 00000000133 não é válido.
# O CPF 00000000134 não é válido.
# O CPF 00000000135 não é válido.
# O CPF 00000000136 não é válido.
# O CPF 00000000137 não é válido.
# O CPF 00000000138 não é válido.
# O CPF 00000000139 não é válido.
# O CPF 00000000140 não é válido.
# O CPF 00000000141 não é válido.
# O CPF 00000000142 não é válido.
# O CPF 00000000143 não é válido.
# O CPF 00000000144 não é válido.
# O CPF 00000000145 não é válido.
# O CPF 00000000146 não é válido.
# O CPF 00000000147 não é válido.
# O CPF 00000000148 não é válido.
# O CPF 00000000149 não é válido.
# O CPF 00000000150 não é válido.
# O CPF 00000000151 não é válido.
# O CPF 00000000152 não é válido.
# O CPF 00000000153 não é válido.
# O CPF 00000000154 não é válido.
# O CPF 00000000155 não é válido.
# O CPF 00000000156 não é válido.
# O CPF 00000000157 não é válido.
# O CPF 00000000158 não é válido.
# O CPF 00000000159 não é válido.
# O CPF 00000000160 não é válido.
# O CPF 00000000161 não é válido.
# O CPF 00000000162 não é válido.
# O CPF 00000000163 não é válido.
# O CPF 00000000164 não é válido.
# O CPF 00000000165 não é válido.
# O CPF 00000000166 não é válido.
# O CPF 00000000167 não é válido.
# O CPF 00000000168 não é válido.
# O CPF 00000000169 não é válido.
# O CPF 00000000170 não é válido.
# O CPF 00000000171 não é válido.
# O CPF 00000000172 não é válido.
# O CPF 00000000173 não é válido.
# O CPF 00000000174 não é válido.
# O CPF 00000000175 não é válido.
# O CPF 00000000176 não é válido.
# O CPF 00000000177 não é válido.
# O CPF 00000000178 não é válido.
# O CPF 00000000179 não é válido.
# O CPF 00000000180 não é válido.
# O CPF 00000000181 não é válido.
# O CPF 00000000182 não é válido.
# O CPF 00000000183 não é válido.
# O CPF 00000000184 não é válido.
# O CPF 00000000185 não é válido.
# O CPF 00000000186 não é válido.
# O CPF 00000000187 não é válido.
# O CPF 00000000188 não é válido.
# O CPF 00000000189 não é válido.
# O CPF 00000000190 não é válido.
# O CPF 00000000191 é válido.
# O CPF 00000000192 não é válido.
# O CPF 00000000193 não é válido.
# O CPF 00000000194 não é válido.
# O CPF 00000000195 não é válido.
# O CPF 00000000196 não é válido.
# O CPF 00000000197 não é válido.
# O CPF 00000000198 não é válido.
# O CPF 00000000199 não é válido.
# O CPF 00000000200 não é válido.
# O CPF 00000000201 não é válido.
# O CPF 00000000202 não é válido.
# O CPF 00000000203 não é válido.
# O CPF 00000000204 não é válido.
# O CPF 00000000205 não é válido.
# O CPF 00000000206 não é válido.
# O CPF 00000000207 não é válido.
# O CPF 00000000208 não é válido.
# O CPF 00000000209 não é válido.
# O CPF 00000000210 não é válido.
# O CPF 00000000211 não é válido.
# O CPF 00000000212 não é válido.
# O CPF 00000000213 não é válido.
# O CPF 00000000214 não é válido.
# O CPF 00000000215 não é válido.
# O CPF 00000000216 não é válido.
# O CPF 00000000217 não é válido.
# O CPF 00000000218 não é válido.
# O CPF 00000000219 não é válido.
# O CPF 00000000220 não é válido.
# O CPF 00000000221 não é válido.
# O CPF 00000000222 não é válido.
# O CPF 00000000223 não é válido.
# O CPF 00000000224 não é válido.
# O CPF 00000000225 não é válido.
# O CPF 00000000226 não é válido.
# O CPF 00000000227 não é válido.
# O CPF 00000000228 não é válido.
# O CPF 00000000229 não é válido.
# O CPF 00000000230 não é válido.
# O CPF 00000000231 não é válido.
# O CPF 00000000232 não é válido.
# O CPF 00000000233 não é válido.
# O CPF 00000000234 não é válido.
# O CPF 00000000235 não é válido.
# O CPF 00000000236 não é válido.
# O CPF 00000000237 não é válido.
# O CPF 00000000238 não é válido.
# O CPF 00000000239 não é válido.
# O CPF 00000000240 não é válido.
# O CPF 00000000241 não é válido.
# O CPF 00000000242 não é válido.
# O CPF 00000000243 não é válido.
# O CPF 00000000244 não é válido.
# O CPF 00000000245 não é válido.
# O CPF 00000000246 não é válido.
# O CPF 00000000247 não é válido.
# O CPF 00000000248 não é válido.
# O CPF 00000000249 não é válido.
# O CPF 00000000250 não é válido.
# O CPF 00000000251 não é válido.
# O CPF 00000000252 não é válido.
# O CPF 00000000253 não é válido.
# O CPF 00000000254 não é válido.
# O CPF 00000000255 não é válido.
# O CPF 00000000256 não é válido.
# O CPF 00000000257 não é válido.
# O CPF 00000000258 não é válido.
# O CPF 00000000259 não é válido.
# O CPF 00000000260 não é válido.
# O CPF 00000000261 não é válido.
# O CPF 00000000262 não é válido.
# O CPF 00000000263 não é válido.
# O CPF 00000000264 não é válido.
# O CPF 00000000265 não é válido.
# O CPF 00000000266 não é válido.
# O CPF 00000000267 não é válido.
# O CPF 00000000268 não é válido.
# O CPF 00000000269 não é válido.
# O CPF 00000000270 não é válido.
# O CPF 00000000271 não é válido.
# O CPF 00000000272 é válido.
# O CPF 00000000273 não é válido.
# O CPF 00000000274 não é válido.
# O CPF 00000000275 não é válido.
# O CPF 00000000276 não é válido.
# O CPF 00000000277 não é válido.
# O CPF 00000000278 não é válido.
# O CPF 00000000279 não é válido.
# O CPF 00000000280 não é válido.
# O CPF 00000000281 não é válido.
# O CPF 00000000282 não é válido.
# O CPF 00000000283 não é válido.
# O CPF 00000000284 não é válido.
# O CPF 00000000285 não é válido.
# O CPF 00000000286 não é válido.
# O CPF 00000000287 não é válido.
# O CPF 00000000288 não é válido.
# O CPF 00000000289 não é válido.
# O CPF 00000000290 não é válido.
# O CPF 00000000291 não é válido.
# O CPF 00000000292 não é válido.
# O CPF 00000000293 não é válido.
# O CPF 00000000294 não é válido.
# O CPF 00000000295 não é válido.
# O CPF 00000000296 não é válido.
# O CPF 00000000297 não é válido.
# O CPF 00000000298 não é válido.
# O CPF 00000000299 não é válido.
# O CPF 00000000300 não é válido.
# O CPF 00000000301 não é válido.
# O CPF 00000000302 não é válido.
# O CPF 00000000303 não é válido.
# O CPF 00000000304 não é válido.
# O CPF 00000000305 não é válido.
# O CPF 00000000306 não é válido.
# O CPF 00000000307 não é válido.
# O CPF 00000000308 não é válido.
# O CPF 00000000309 não é válido.
# O CPF 00000000310 não é válido.
# O CPF 00000000311 não é válido.
# O CPF 00000000312 não é válido.
# O CPF 00000000313 não é válido.
# O CPF 00000000314 não é válido.
# O CPF 00000000315 não é válido.
# O CPF 00000000316 não é válido.
# O CPF 00000000317 não é válido.
# O CPF 00000000318 não é válido.
# O CPF 00000000319 não é válido.
# O CPF 00000000320 não é válido.
# O CPF 00000000321 não é válido.
# O CPF 00000000322 não é válido.
# O CPF 00000000323 não é válido.
# O CPF 00000000324 não é válido.
# O CPF 00000000325 não é válido.
# O CPF 00000000326 não é válido.
# O CPF 00000000327 não é válido.
# O CPF 00000000328 não é válido.
# O CPF 00000000329 não é válido.
# O CPF 00000000330 não é válido.
# O CPF 00000000331 não é válido.
# O CPF 00000000332 não é válido.
# O CPF 00000000333 não é válido.
# O CPF 00000000334 não é válido.
# O CPF 00000000335 não é válido.
# O CPF 00000000336 não é válido.
# O CPF 00000000337 não é válido.
# O CPF 00000000338 não é válido.
# O CPF 00000000339 não é válido.
# O CPF 00000000340 não é válido.
# O CPF 00000000341 não é válido.
# O CPF 00000000342 não é válido.
# O CPF 00000000343 não é válido.
# O CPF 00000000344 não é válido.
# O CPF 00000000345 não é válido.
# O CPF 00000000346 não é válido.
# O CPF 00000000347 não é válido.
# O CPF 00000000348 não é válido.
# O CPF 00000000349 não é válido.
# O CPF 00000000350 não é válido.
# O CPF 00000000351 não é válido.
# O CPF 00000000352 não é válido.
# O CPF 00000000353 é válido.
# O CPF 00000000354 não é válido.
# O CPF 00000000355 não é válido.
# O CPF 00000000356 não é válido.
# O CPF 00000000357 não é válido.
# O CPF 00000000358 não é válido.
# O CPF 00000000359 não é válido.
# O CPF 00000000360 não é válido.
# O CPF 00000000361 não é válido.
# O CPF 00000000362 não é válido.
# O CPF 00000000363 não é válido.
# O CPF 00000000364 não é válido.
# O CPF 00000000365 não é válido.
# O CPF 00000000366 não é válido.
# O CPF 00000000367 não é válido.
# O CPF 00000000368 não é válido.
# O CPF 00000000369 não é válido.
# O CPF 00000000370 não é válido.
# O CPF 00000000371 não é válido.
# O CPF 00000000372 não é válido.
# O CPF 00000000373 não é válido.
# O CPF 00000000374 não é válido.
# O CPF 00000000375 não é válido.
# O CPF 00000000376 não é válido.
# O CPF 00000000377 não é válido.
# O CPF 00000000378 não é válido.
# O CPF 00000000379 não é válido.
# O CPF 00000000380 não é válido.
# O CPF 00000000381 não é válido.
# O CPF 00000000382 não é válido.
# O CPF 00000000383 não é válido.
# O CPF 00000000384 não é válido.
# O CPF 00000000385 não é válido.
# O CPF 00000000386 não é válido.
# O CPF 00000000387 não é válido.
# O CPF 00000000388 não é válido.
# O CPF 00000000389 não é válido.
# O CPF 00000000390 não é válido.
# O CPF 00000000391 não é válido.
# O CPF 00000000392 não é válido.
# O CPF 00000000393 não é válido.
# O CPF 00000000394 não é válido.
# O CPF 00000000395 não é válido.
# O CPF 00000000396 não é válido.
# O CPF 00000000397 não é válido.
# O CPF 00000000398 não é válido.
# O CPF 00000000399 não é válido.
# O CPF 00000000400 não é válido.
# O CPF 00000000401 não é válido.
# O CPF 00000000402 não é válido.
# O CPF 00000000403 não é válido.
# O CPF 00000000404 não é válido.
# O CPF 00000000405 não é válido.
# O CPF 00000000406 não é válido.
# O CPF 00000000407 não é válido.
# O CPF 00000000408 não é válido.
# O CPF 00000000409 não é válido.
# O CPF 00000000410 não é válido.
# O CPF 00000000411 não é válido.
# O CPF 00000000412 não é válido.
# O CPF 00000000413 não é válido.
# O CPF 00000000414 não é válido.
# O CPF 00000000415 não é válido.
# O CPF 00000000416 não é válido.
# O CPF 00000000417 não é válido.
# O CPF 00000000418 não é válido.
# O CPF 00000000419 não é válido.
# O CPF 00000000420 não é válido.
# O CPF 00000000421 não é válido.
# O CPF 00000000422 não é válido.
# O CPF 00000000423 não é válido.
# O CPF 00000000424 não é válido.
# O CPF 00000000425 não é válido.
# O CPF 00000000426 não é válido.
# O CPF 00000000427 não é válido.
# O CPF 00000000428 não é válido.
# O CPF 00000000429 não é válido.
# O CPF 00000000430 não é válido.
# O CPF 00000000431 não é válido.
# O CPF 00000000432 não é válido.
# O CPF 00000000433 não é válido.
# O CPF 00000000434 é válido.
# O CPF 00000000435 não é válido.
# O CPF 00000000436 não é válido.
# O CPF 00000000437 não é válido.
# O CPF 00000000438 não é válido.
# O CPF 00000000439 não é válido.
# O CPF 00000000440 não é válido.
# O CPF 00000000441 não é válido.
# O CPF 00000000442 não é válido.
# O CPF 00000000443 não é válido.
# O CPF 00000000444 não é válido.
# O CPF 00000000445 não é válido.
# O CPF 00000000446 não é válido.
# O CPF 00000000447 não é válido.
# O CPF 00000000448 não é válido.
# O CPF 00000000449 não é válido.
# O CPF 00000000450 não é válido.
# O CPF 00000000451 não é válido.
# O CPF 00000000452 não é válido.
# O CPF 00000000453 não é válido.
# O CPF 00000000454 não é válido.
# O CPF 00000000455 não é válido.
# O CPF 00000000456 não é válido.
# O CPF 00000000457 não é válido.
# O CPF 00000000458 não é válido.
# O CPF 00000000459 não é válido.
# O CPF 00000000460 não é válido.
# O CPF 00000000461 não é válido.
# O CPF 00000000462 não é válido.
# O CPF 00000000463 não é válido.
# O CPF 00000000464 não é válido.
# O CPF 00000000465 não é válido.
# O CPF 00000000466 não é válido.
# O CPF 00000000467 não é válido.
# O CPF 00000000468 não é válido.
# O CPF 00000000469 não é válido.
# O CPF 00000000470 não é válido.
# O CPF 00000000471 não é válido.
# O CPF 00000000472 não é válido.
# O CPF 00000000473 não é válido.
# O CPF 00000000474 não é válido.
# O CPF 00000000475 não é válido.
# O CPF 00000000476 não é válido.
# O CPF 00000000477 não é válido.
# O CPF 00000000478 não é válido.
# O CPF 00000000479 não é válido.
# O CPF 00000000480 não é válido.
# O CPF 00000000481 não é válido.
# O CPF 00000000482 não é válido.
# O CPF 00000000483 não é válido.
# O CPF 00000000484 não é válido.
# O CPF 00000000485 não é válido.
# O CPF 00000000486 não é válido.
# O CPF 00000000487 não é válido.
# O CPF 00000000488 não é válido.
# O CPF 00000000489 não é válido.
# O CPF 00000000490 não é válido.
# O CPF 00000000491 não é válido.
# O CPF 00000000492 não é válido.
# O CPF 00000000493 não é válido.
# O CPF 00000000494 não é válido.
# O CPF 00000000495 não é válido.
# O CPF 00000000496 não é válido.
# O CPF 00000000497 não é válido.
# O CPF 00000000498 não é válido.
# O CPF 00000000499 não é válido.
# O CPF 00000000500 não é válido.
# O CPF 00000000501 não é válido.
# O CPF 00000000502 não é válido.
# O CPF 00000000503 não é válido.
# O CPF 00000000504 não é válido.
# O CPF 00000000505 não é válido.
# O CPF 00000000506 não é válido.
# O CPF 00000000507 não é válido.
# O CPF 00000000508 não é válido.
# O CPF 00000000509 não é válido.
# O CPF 00000000510 não é válido.
# O CPF 00000000511 não é válido.
# O CPF 00000000512 não é válido.
# O CPF 00000000513 não é válido.
# O CPF 00000000514 não é válido.
# O CPF 00000000515 é válido.
# O CPF 00000000516 não é válido.
# O CPF 00000000517 não é válido.
# O CPF 00000000518 não é válido.
# O CPF 00000000519 não é válido.
# O CPF 00000000520 não é válido.
# O CPF 00000000521 não é válido.
# O CPF 00000000522 não é válido.
# O CPF 00000000523 não é válido.
# O CPF 00000000524 não é válido.
# O CPF 00000000525 não é válido.
# O CPF 00000000526 não é válido.
# O CPF 00000000527 não é válido.
# O CPF 00000000528 não é válido.
# O CPF 00000000529 não é válido.
# O CPF 00000000530 não é válido.
# O CPF 00000000531 não é válido.
# O CPF 00000000532 não é válido.
# O CPF 00000000533 não é válido.
# O CPF 00000000534 não é válido.
# O CPF 00000000535 não é válido.
# O CPF 00000000536 não é válido.
# O CPF 00000000537 não é válido.
# O CPF 00000000538 não é válido.
# O CPF 00000000539 não é válido.
# O CPF 00000000540 não é válido.
# O CPF 00000000541 não é válido.
# O CPF 00000000542 não é válido.
# O CPF 00000000543 não é válido.
# O CPF 00000000544 não é válido.
# O CPF 00000000545 não é válido.
# O CPF 00000000546 não é válido.
# O CPF 00000000547 não é válido.
# O CPF 00000000548 não é válido.
# O CPF 00000000549 não é válido.
# O CPF 00000000550 não é válido.
# O CPF 00000000551 não é válido.
# O CPF 00000000552 não é válido.
# O CPF 00000000553 não é válido.
# O CPF 00000000554 não é válido.
# O CPF 00000000555 não é válido.
# O CPF 00000000556 não é válido.
# O CPF 00000000557 não é válido.
# O CPF 00000000558 não é válido.
# O CPF 00000000559 não é válido.
# O CPF 00000000560 não é válido.
# O CPF 00000000561 não é válido.
# O CPF 00000000562 não é válido.
# O CPF 00000000563 não é válido.
# O CPF 00000000564 não é válido.
# O CPF 00000000565 não é válido.
# O CPF 00000000566 não é válido.
# O CPF 00000000567 não é válido.
# O CPF 00000000568 não é válido.
# O CPF 00000000569 não é válido.
# O CPF 00000000570 não é válido.
# O CPF 00000000571 não é válido.
# O CPF 00000000572 não é válido.
# O CPF 00000000573 não é válido.
# O CPF 00000000574 não é válido.
# O CPF 00000000575 não é válido.
# O CPF 00000000576 não é válido.
# O CPF 00000000577 não é válido.
# O CPF 00000000578 não é válido.
# O CPF 00000000579 não é válido.
# O CPF 00000000580 não é válido.
# O CPF 00000000581 não é válido.
# O CPF 00000000582 não é válido.
# O CPF 00000000583 não é válido.
# O CPF 00000000584 não é válido.
# O CPF 00000000585 não é válido.
# O CPF 00000000586 não é válido.
# O CPF 00000000587 não é válido.
# O CPF 00000000588 não é válido.
# O CPF 00000000589 não é válido.
# O CPF 00000000590 não é válido.
# O CPF 00000000591 não é válido.
# O CPF 00000000592 não é válido.
# O CPF 00000000593 não é válido.
# O CPF 00000000594 não é válido.
# O CPF 00000000595 não é válido.
# O CPF 00000000596 não é válido.
# O CPF 00000000597 não é válido.
# O CPF 00000000598 não é válido.
# O CPF 00000000599 não é válido.
# O CPF 00000000600 não é válido.
# O CPF 00000000601 não é válido.
# O CPF 00000000602 não é válido.
# O CPF 00000000603 não é válido.
# O CPF 00000000604 não é válido.
# O CPF 00000000605 não é válido.
# O CPF 00000000606 não é válido.
# O CPF 00000000607 não é válido.
# O CPF 00000000608 não é válido.
# O CPF 00000000609 não é válido.
# O CPF 00000000610 não é válido.
# O CPF 00000000611 não é válido.
# O CPF 00000000612 não é válido.
# O CPF 00000000613 não é válido.
# O CPF 00000000614 não é válido.
# O CPF 00000000615 não é válido.
# O CPF 00000000616 não é válido.
# O CPF 00000000617 não é válido.
# O CPF 00000000618 não é válido.
# O CPF 00000000619 não é válido.
# O CPF 00000000620 não é válido.
# O CPF 00000000621 não é válido.
# O CPF 00000000622 não é válido.
# O CPF 00000000623 não é válido.
# O CPF 00000000624 não é válido.
# O CPF 00000000625 não é válido.
# O CPF 00000000626 não é válido.
# O CPF 00000000627 não é válido.
# O CPF 00000000628 não é válido.
# O CPF 00000000629 não é válido.
# O CPF 00000000630 não é válido.
# O CPF 00000000631 não é válido.
# O CPF 00000000632 não é válido.
# O CPF 00000000633 não é válido.
# O CPF 00000000634 não é válido.
# O CPF 00000000635 não é válido.
# O CPF 00000000636 não é válido.
# O CPF 00000000637 não é válido.
# O CPF 00000000638 não é válido.
# O CPF 00000000639 não é válido.
# O CPF 00000000640 não é válido.
# O CPF 00000000641 não é válido.
# O CPF 00000000642 não é válido.
# O CPF 00000000643 não é válido.
# O CPF 00000000644 não é válido.
# O CPF 00000000645 não é válido.
# O CPF 00000000646 não é válido.
# O CPF 00000000647 não é válido.
# O CPF 00000000648 não é válido.
# O CPF 00000000649 não é válido.
# O CPF 00000000650 não é válido.
# O CPF 00000000651 não é válido.
# O CPF 00000000652 não é válido.
# O CPF 00000000653 não é válido.
# O CPF 00000000654 não é válido.
# O CPF 00000000655 não é válido.
# O CPF 00000000656 não é válido.
# O CPF 00000000657 não é válido.
# O CPF 00000000658 não é válido.
# O CPF 00000000659 não é válido.
# O CPF 00000000660 não é válido.
# O CPF 00000000661 não é válido.
# O CPF 00000000662 não é válido.
# O CPF 00000000663 não é válido.
# O CPF 00000000664 não é válido.
# O CPF 00000000665 não é válido.
# O CPF 00000000666 não é válido.
# O CPF 00000000667 não é válido.
# O CPF 00000000668 não é válido.
# O CPF 00000000669 não é válido.
# O CPF 00000000670 não é válido.
# O CPF 00000000671 não é válido.
# O CPF 00000000672 não é válido.
# O CPF 00000000673 não é válido.
# O CPF 00000000674 não é válido.
# O CPF 00000000675 não é válido.
# O CPF 00000000676 não é válido.
# O CPF 00000000677 não é válido.
# O CPF 00000000678 não é válido.
# O CPF 00000000679 não é válido.
# O CPF 00000000680 não é válido.
# O CPF 00000000681 não é válido.
# O CPF 00000000682 não é válido.
# O CPF 00000000683 não é válido.
# O CPF 00000000684 não é válido.
# O CPF 00000000685 não é válido.
# O CPF 00000000686 não é válido.
# O CPF 00000000687 não é válido.
# O CPF 00000000688 não é válido.
# O CPF 00000000689 não é válido.
# O CPF 00000000690 não é válido.
# O CPF 00000000691 não é válido.
# O CPF 00000000692 não é válido.
# O CPF 00000000693 não é válido.
# O CPF 00000000694 não é válido.
# O CPF 00000000695 não é válido.
# O CPF 00000000696 não é válido.
# O CPF 00000000697 não é válido.
# O CPF 00000000698 não é válido.
# O CPF 00000000699 não é válido.
# O CPF 00000000700 não é válido.
# O CPF 00000000701 não é válido.
# O CPF 00000000702 não é válido.
# O CPF 00000000703 não é válido.
# O CPF 00000000704 não é válido.
# O CPF 00000000705 não é válido.
# O CPF 00000000706 não é válido.
# O CPF 00000000707 não é válido.
# O CPF 00000000708 não é válido.
# O CPF 00000000709 não é válido.
# O CPF 00000000710 não é válido.
# O CPF 00000000711 não é válido.
# O CPF 00000000712 não é válido.
# O CPF 00000000713 não é válido.
# O CPF 00000000714 não é válido.
# O CPF 00000000715 não é válido.
# O CPF 00000000716 não é válido.
# O CPF 00000000717 não é válido.
# O CPF 00000000718 não é válido.
# O CPF 00000000719 não é válido.
# O CPF 00000000720 não é válido.
# O CPF 00000000721 não é válido.
# O CPF 00000000722 não é válido.
# O CPF 00000000723 não é válido.
# O CPF 00000000724 não é válido.
# O CPF 00000000725 não é válido.
# O CPF 00000000726 não é válido.
# O CPF 00000000727 não é válido.
# O CPF 00000000728 não é válido.
# O CPF 00000000729 não é válido.
# O CPF 00000000730 não é válido.
# O CPF 00000000731 não é válido.
# O CPF 00000000732 não é válido.
# O CPF 00000000733 não é válido.
# O CPF 00000000734 não é válido.
# O CPF 00000000735 não é válido.
# O CPF 00000000736 não é válido.
# O CPF 00000000737 não é válido.
# O CPF 00000000738 não é válido.
# O CPF 00000000739 não é válido.
# O CPF 00000000740 não é válido.
# O CPF 00000000741 não é válido.
# O CPF 00000000742 não é válido.
# O CPF 00000000743 não é válido.
# O CPF 00000000744 não é válido.
# O CPF 00000000745 não é válido.
# O CPF 00000000746 não é válido.
# O CPF 00000000747 não é válido.
# O CPF 00000000748 não é válido.
# O CPF 00000000749 não é válido.
# O CPF 00000000750 não é válido.
# O CPF 00000000751 não é válido.
# O CPF 00000000752 não é válido.
# O CPF 00000000753 não é válido.
# O CPF 00000000754 não é válido.
# O CPF 00000000755 não é válido.
# O CPF 00000000756 não é válido.
# O CPF 00000000757 não é válido.
# O CPF 00000000758 não é válido.
# O CPF 00000000759 não é válido.
# O CPF 00000000760 não é válido.
# O CPF 00000000761 não é válido.
# O CPF 00000000762 não é válido.
# O CPF 00000000763 não é válido.
# O CPF 00000000764 não é válido.
# O CPF 00000000765 não é válido.
# O CPF 00000000766 não é válido.
# O CPF 00000000767 não é válido.
# O CPF 00000000768 não é válido.
# O CPF 00000000769 não é válido.
# O CPF 00000000770 não é válido.
# O CPF 00000000771 não é válido.
# O CPF 00000000772 não é válido.
# O CPF 00000000773 não é válido.
# O CPF 00000000774 não é válido.
# O CPF 00000000775 não é válido.
# O CPF 00000000776 não é válido.
# O CPF 00000000777 não é válido.
# O CPF 00000000778 não é válido.
# O CPF 00000000779 não é válido.
# O CPF 00000000780 não é válido.
# O CPF 00000000781 não é válido.
# O CPF 00000000782 não é válido.
# O CPF 00000000783 não é válido.
# O CPF 00000000784 não é válido.
# O CPF 00000000785 não é válido.
# O CPF 00000000786 não é válido.
# O CPF 00000000787 é válido.
# O CPF 00000000788 não é válido.
# O CPF 00000000789 não é válido.
# O CPF 00000000790 não é válido.
# O CPF 00000000791 não é válido.
# O CPF 00000000792 não é válido.
# O CPF 00000000793 não é válido.
# O CPF 00000000794 não é válido.
# O CPF 00000000795 não é válido.
# O CPF 00000000796 não é válido.
# O CPF 00000000797 não é válido.
# O CPF 00000000798 não é válido.
# O CPF 00000000799 não é válido.
# O CPF 00000000800 não é válido.
# O CPF 00000000801 não é válido.
# O CPF 00000000802 não é válido.
# O CPF 00000000803 não é válido.
# O CPF 00000000804 não é válido.
# O CPF 00000000805 não é válido.
# O CPF 00000000806 não é válido.
# O CPF 00000000807 não é válido.
# O CPF 00000000808 não é válido.
# O CPF 00000000809 não é válido.
# O CPF 00000000810 não é válido.
# O CPF 00000000811 não é válido.
# O CPF 00000000812 não é válido.
# O CPF 00000000813 não é válido.
# O CPF 00000000814 não é válido.
# O CPF 00000000815 não é válido.
# O CPF 00000000816 não é válido.
# O CPF 00000000817 não é válido.
# O CPF 00000000818 não é válido.
# O CPF 00000000819 não é válido.
# O CPF 00000000820 não é válido.
# O CPF 00000000821 não é válido.
# O CPF 00000000822 não é válido.
# O CPF 00000000823 não é válido.
# O CPF 00000000824 não é válido.
# O CPF 00000000825 não é válido.
# O CPF 00000000826 não é válido.
# O CPF 00000000827 não é válido.
# O CPF 00000000828 não é válido.
# O CPF 00000000829 não é válido.
# O CPF 00000000830 não é válido.
# O CPF 00000000831 não é válido.
# O CPF 00000000832 não é válido.
# O CPF 00000000833 não é válido.
# O CPF 00000000834 não é válido.
# O CPF 00000000835 não é válido.
# O CPF 00000000836 não é válido.
# O CPF 00000000837 não é válido.
# O CPF 00000000838 não é válido.
# O CPF 00000000839 não é válido.
# O CPF 00000000840 não é válido.
# O CPF 00000000841 não é válido.
# O CPF 00000000842 não é válido.
# O CPF 00000000843 não é válido.
# O CPF 00000000844 não é válido.
# O CPF 00000000845 não é válido.
# O CPF 00000000846 não é válido.
# O CPF 00000000847 não é válido.
# O CPF 00000000848 não é válido.
# O CPF 00000000849 não é válido.
# O CPF 00000000850 não é válido.
# O CPF 00000000851 não é válido.
# O CPF 00000000852 não é válido.
# O CPF 00000000853 não é válido.
# O CPF 00000000854 não é válido.
# O CPF 00000000855 não é válido.
# O CPF 00000000856 não é válido.
# O CPF 00000000857 não é válido.
# O CPF 00000000858 não é válido.
# O CPF 00000000859 não é válido.
# O CPF 00000000860 não é válido.
# O CPF 00000000861 não é válido.
# O CPF 00000000862 não é válido.
# O CPF 00000000863 não é válido.
# O CPF 00000000864 não é válido.
# O CPF 00000000865 não é válido.
# O CPF 00000000866 não é válido.
# O CPF 00000000867 não é válido.
# O CPF 00000000868 é válido.
# O CPF 00000000869 não é válido.
# O CPF 00000000870 não é válido.
# O CPF 00000000871 não é válido.
# O CPF 00000000872 não é válido.
# O CPF 00000000873 não é válido.
# O CPF 00000000874 não é válido.
# O CPF 00000000875 não é válido.
# O CPF 00000000876 não é válido.
# O CPF 00000000877 não é válido.
# O CPF 00000000878 não é válido.
# O CPF 00000000879 não é válido.
# O CPF 00000000880 não é válido.
# O CPF 00000000881 não é válido.
# O CPF 00000000882 não é válido.
# O CPF 00000000883 não é válido.
# O CPF 00000000884 não é válido.
# O CPF 00000000885 não é válido.
# O CPF 00000000886 não é válido.
# O CPF 00000000887 não é válido.
# O CPF 00000000888 não é válido.
# O CPF 00000000889 não é válido.
# O CPF 00000000890 não é válido.
# O CPF 00000000891 não é válido.
# O CPF 00000000892 não é válido.
# O CPF 00000000893 não é válido.
# O CPF 00000000894 não é válido.
# O CPF 00000000895 não é válido.
# O CPF 00000000896 não é válido.
# O CPF 00000000897 não é válido.
# O CPF 00000000898 não é válido.
# O CPF 00000000899 não é válido.
# O CPF 00000000900 não é válido.
# O CPF 00000000901 não é válido.
# O CPF 00000000902 não é válido.
# O CPF 00000000903 não é válido.
# O CPF 00000000904 não é válido.
# O CPF 00000000905 não é válido.
# O CPF 00000000906 não é válido.
# O CPF 00000000907 não é válido.
# O CPF 00000000908 não é válido.
# O CPF 00000000909 não é válido.
# O CPF 00000000910 não é válido.
# O CPF 00000000911 não é válido.
# O CPF 00000000912 não é válido.
# O CPF 00000000913 não é válido.
# O CPF 00000000914 não é válido.
# O CPF 00000000915 não é válido.
# O CPF 00000000916 não é válido.
# O CPF 00000000917 não é válido.
# O CPF 00000000918 não é válido.
# O CPF 00000000919 não é válido.
# O CPF 00000000920 não é válido.
# O CPF 00000000921 não é válido.
# O CPF 00000000922 não é válido.
# O CPF 00000000923 não é válido.
# O CPF 00000000924 não é válido.
# O CPF 00000000925 não é válido.
# O CPF 00000000926 não é válido.
# O CPF 00000000927 não é válido.
# O CPF 00000000928 não é válido.
# O CPF 00000000929 não é válido.
# O CPF 00000000930 não é válido.
# O CPF 00000000931 não é válido.
# O CPF 00000000932 não é válido.
# O CPF 00000000933 não é válido.
# O CPF 00000000934 não é válido.
# O CPF 00000000935 não é válido.
# O CPF 00000000936 não é válido.
# O CPF 00000000937 não é válido.
# O CPF 00000000938 não é válido.
# O CPF 00000000939 não é válido.
# O CPF 00000000940 não é válido.
# O CPF 00000000941 não é válido.
# O CPF 00000000942 não é válido.
# O CPF 00000000943 não é válido.
# O CPF 00000000944 não é válido.
# O CPF 00000000945 não é válido.
# O CPF 00000000946 não é válido.
# O CPF 00000000947 não é válido.
# O CPF 00000000948 não é válido.
# O CPF 00000000949 é válido.
# O CPF 00000000950 não é válido.
# O CPF 00000000951 não é válido.
# O CPF 00000000952 não é válido.
# O CPF 00000000953 não é válido.
# O CPF 00000000954 não é válido.
# O CPF 00000000955 não é válido.
# O CPF 00000000956 não é válido.
# O CPF 00000000957 não é válido.
# O CPF 00000000958 não é válido.
# O CPF 00000000959 não é válido.
# O CPF 00000000960 não é válido.
# O CPF 00000000961 não é válido.
# O CPF 00000000962 não é válido.
# O CPF 00000000963 não é válido.
# O CPF 00000000964 não é válido.
# O CPF 00000000965 não é válido.
# O CPF 00000000966 não é válido.
# O CPF 00000000967 não é válido.
# O CPF 00000000968 não é válido.
# O CPF 00000000969 não é válido.
# O CPF 00000000970 não é válido.
# O CPF 00000000971 não é válido.
# O CPF 00000000972 não é válido.
# O CPF 00000000973 não é válido.
# O CPF 00000000974 não é válido.
# O CPF 00000000975 não é válido.
# O CPF 00000000976 não é válido.
# O CPF 00000000977 não é válido.
# O CPF 00000000978 não é válido.
# O CPF 00000000979 não é válido.
# O CPF 00000000980 não é válido.
# O CPF 00000000981 não é válido.
# O CPF 00000000982 não é válido.
# O CPF 00000000983 não é válido.
# O CPF 00000000984 não é válido.
# O CPF 00000000985 não é válido.
# O CPF 00000000986 não é válido.
# O CPF 00000000987 não é válido.
# O CPF 00000000988 não é válido.
# O CPF 00000000989 não é válido.
# O CPF 00000000990 não é válido.
# O CPF 00000000991 não é válido.
# O CPF 00000000992 não é válido.
# O CPF 00000000993 não é válido.
# O CPF 00000000994 não é válido.
# O CPF 00000000995 não é válido.
# O CPF 00000000996 não é válido.
# O CPF 00000000997 não é válido.
# O CPF 00000000998 não é válido.
# O CPF 00000000999 não é válido.
# O CPF 00000001000 não é válido.
# O CPF 00000001001 não é válido.
# O CPF 00000001002 não é válido.
# O CPF 00000001003 não é válido.
# O CPF 00000001004 não é válido.
# O CPF 00000001005 não é válido.
# O CPF 00000001006 não é válido.
# O CPF 00000001007 não é válido.
# O CPF 00000001008 não é válido.
# O CPF 00000001009 não é válido.
# O CPF 00000001010 não é válido.
# O CPF 00000001011 não é válido.
# O CPF 00000001012 não é válido.
# O CPF 00000001013 não é válido.
# O CPF 00000001014 não é válido.
# O CPF 00000001015 não é válido.
# O CPF 00000001016 não é válido.
# O CPF 00000001017 não é válido.
# O CPF 00000001018 não é válido.
# O CPF 00000001019 não é válido.
# O CPF 00000001020 não é válido.
# O CPF 00000001021 não é válido.
# O CPF 00000001022 não é válido.
# O CPF 00000001023 não é válido.
# O CPF 00000001024 não é válido.
# O CPF 00000001025 não é válido.
# O CPF 00000001026 não é válido.
# O CPF 00000001027 não é válido.
# O CPF 00000001028 não é válido.
# O CPF 00000001029 não é válido.
# O CPF 00000001030 não é válido.
# O CPF 00000001031 não é válido.
# O CPF 00000001032 não é válido.
# O CPF 00000001033 não é válido.
# O CPF 00000001034 não é válido.
# O CPF 00000001035 não é válido.
# O CPF 00000001036 não é válido.
# O CPF 00000001037 não é válido.
# O CPF 00000001038 não é válido.
# O CPF 00000001039 não é válido.
# O CPF 00000001040 não é válido.
# O CPF 00000001041 não é válido.
# O CPF 00000001042 não é válido.
# O CPF 00000001043 não é válido.
# O CPF 00000001044 não é válido.
# O CPF 00000001045 não é válido.
# O CPF 00000001046 não é válido.
# O CPF 00000001047 não é válido.
# O CPF 00000001048 não é válido.
# O CPF 00000001049 não é válido.
# O CPF 00000001050 não é válido.
# O CPF 00000001051 não é válido.
# O CPF 00000001052 não é válido.
# O CPF 00000001053 não é válido.
# O CPF 00000001054 não é válido.
# O CPF 00000001055 não é válido.
# O CPF 00000001056 não é válido.
# O CPF 00000001057 não é válido.
# O CPF 00000001058 não é válido.
# O CPF 00000001059 não é válido.
# O CPF 00000001060 não é válido.
# O CPF 00000001061 não é válido.
# O CPF 00000001062 não é válido.
# O CPF 00000001063 não é válido.
# O CPF 00000001064 não é válido.
# O CPF 00000001065 não é válido.
# O CPF 00000001066 não é válido.
# O CPF 00000001067 não é válido.
# O CPF 00000001068 não é válido.
# O CPF 00000001069 não é válido.
# O CPF 00000001070 não é válido.
# O CPF 00000001071 não é válido.
# O CPF 00000001072 não é válido.
# O CPF 00000001073 não é válido.
# O CPF 00000001074 não é válido.
# O CPF 00000001075 não é válido.
# O CPF 00000001076 não é válido.
# O CPF 00000001077 não é válido.
# O CPF 00000001078 não é válido.
# O CPF 00000001079 não é válido.
# O CPF 00000001080 não é válido.
# O CPF 00000001081 não é válido.
# O CPF 00000001082 é válido.
# O CPF 00000001083 não é válido.
# O CPF 00000001084 não é válido.
# O CPF 00000001085 não é válido.
# O CPF 00000001086 não é válido.
# O CPF 00000001087 não é válido.
# O CPF 00000001088 não é válido.
# O CPF 00000001089 não é válido.
# O CPF 00000001090 não é válido.
# O CPF 00000001091 não é válido.
# O CPF 00000001092 não é válido.
# O CPF 00000001093 não é válido.
# O CPF 00000001094 não é válido.
# O CPF 00000001095 não é válido.
# O CPF 00000001096 não é válido.
# O CPF 00000001097 não é válido.
# O CPF 00000001098 não é válido.
# O CPF 00000001099 não é válido.
# O CPF 00000001100 não é válido.
# O CPF 00000001101 não é válido.
# O CPF 00000001102 não é válido.
# O CPF 00000001103 não é válido.
# O CPF 00000001104 não é válido.
# O CPF 00000001105 não é válido.
# O CPF 00000001106 não é válido.
# O CPF 00000001107 não é válido.
# O CPF 00000001108 não é válido.
# O CPF 00000001109 não é válido.
# O CPF 00000001110 não é válido.
# O CPF 00000001111 não é válido.
# O CPF 00000001112 não é válido.
# O CPF 00000001113 não é válido.
# O CPF 00000001114 não é válido.
# O CPF 00000001115 não é válido.
# O CPF 00000001116 não é válido.
# O CPF 00000001117 não é válido.
# O CPF 00000001118 não é válido.
# O CPF 00000001119 não é válido.
# O CPF 00000001120 não é válido.
# O CPF 00000001121 não é válido.
# O CPF 00000001122 não é válido.
# O CPF 00000001123 não é válido.
# O CPF 00000001124 não é válido.
# O CPF 00000001125 não é válido.
# O CPF 00000001126 não é válido.
# O CPF 00000001127 não é válido.
# O CPF 00000001128 não é válido.
# O CPF 00000001129 não é válido.
# O CPF 00000001130 não é válido.
# O CPF 00000001131 não é válido.
# O CPF 00000001132 não é válido.
# O CPF 00000001133 não é válido.
# O CPF 00000001134 não é válido.
# O CPF 00000001135 não é válido.
# O CPF 00000001136 não é válido.
# O CPF 00000001137 não é válido.
# O CPF 00000001138 não é válido.
# O CPF 00000001139 não é válido.
# O CPF 00000001140 não é válido.
# O CPF 00000001141 não é válido.
# O CPF 00000001142 não é válido.
# O CPF 00000001143 não é válido.
# O CPF 00000001144 não é válido.
# O CPF 00000001145 não é válido.
# O CPF 00000001146 não é válido.
# O CPF 00000001147 não é válido.
# O CPF 00000001148 não é válido.
# O CPF 00000001149 não é válido.
# O CPF 00000001150 não é válido.
# O CPF 00000001151 não é válido.
# O CPF 00000001152 não é válido.
# O CPF 00000001153 não é válido.
# O CPF 00000001154 não é válido.
# O CPF 00000001155 não é válido.
# O CPF 00000001156 não é válido.
# O CPF 00000001157 não é válido.
# O CPF 00000001158 não é válido.
# O CPF 00000001159 não é válido.
# O CPF 00000001160 não é válido.
# O CPF 00000001161 não é válido.
# O CPF 00000001162 não é válido.
# O CPF 00000001163 é válido.
# O CPF 00000001164 não é válido.
# O CPF 00000001165 não é válido.
# O CPF 00000001166 não é válido.
# O CPF 00000001167 não é válido.
# O CPF 00000001168 não é válido.
# O CPF 00000001169 não é válido.
# O CPF 00000001170 não é válido.
# O CPF 00000001171 não é válido.
# O CPF 00000001172 não é válido.
# O CPF 00000001173 não é válido.
# O CPF 00000001174 não é válido.
# O CPF 00000001175 não é válido.
# O CPF 00000001176 não é válido.
# O CPF 00000001177 não é válido.
# O CPF 00000001178 não é válido.
# O CPF 00000001179 não é válido.
# O CPF 00000001180 não é válido.
# O CPF 00000001181 não é válido.
# O CPF 00000001182 não é válido.
# O CPF 00000001183 não é válido.
# O CPF 00000001184 não é válido.
# O CPF 00000001185 não é válido.
# O CPF 00000001186 não é válido.
# O CPF 00000001187 não é válido.
# O CPF 00000001188 não é válido.
# O CPF 00000001189 não é válido.
# O CPF 00000001190 não é válido.
# O CPF 00000001191 não é válido.
# O CPF 00000001192 não é válido.
# O CPF 00000001193 não é válido.
# O CPF 00000001194 não é válido.
# O CPF 00000001195 não é válido.
# O CPF 00000001196 não é válido.
# O CPF 00000001197 não é válido.
# O CPF 00000001198 não é válido.
# O CPF 00000001199 não é válido.
# O CPF 00000001200 não é válido.
# O CPF 00000001201 não é válido.
# O CPF 00000001202 não é válido.
# O CPF 00000001203 não é válido.
# O CPF 00000001204 não é válido.
# O CPF 00000001205 não é válido.
# O CPF 00000001206 não é válido.
# O CPF 00000001207 não é válido.
# O CPF 00000001208 não é válido.
# O CPF 00000001209 não é válido.
# O CPF 00000001210 não é válido.
# O CPF 00000001211 não é válido.
# O CPF 00000001212 não é válido.
# O CPF 00000001213 não é válido.
# O CPF 00000001214 não é válido.
# O CPF 00000001215 não é válido.
# O CPF 00000001216 não é válido.
# O CPF 00000001217 não é válido.
# O CPF 00000001218 não é válido.
# O CPF 00000001219 não é válido.
# O CPF 00000001220 não é válido.
# O CPF 00000001221 não é válido.
# O CPF 00000001222 não é válido.
# O CPF 00000001223 não é válido.
# O CPF 00000001224 não é válido.
# O CPF 00000001225 não é válido.
# O CPF 00000001226 não é válido.
# O CPF 00000001227 não é válido.
# O CPF 00000001228 não é válido.
# O CPF 00000001229 não é válido.
# O CPF 00000001230 não é válido.
# O CPF 00000001231 não é válido.
# O CPF 00000001232 não é válido.
# O CPF 00000001233 não é válido.
# O CPF 00000001234 não é válido.
# O CPF 00000001235 não é válido.
# O CPF 00000001236 não é válido.
# O CPF 00000001237 não é válido.
# O CPF 00000001238 não é válido.
# O CPF 00000001239 não é válido.
# O CPF 00000001240 não é válido.
# O CPF 00000001241 não é válido.
# O CPF 00000001242 não é válido.
# O CPF 00000001243 não é válido.
# O CPF 00000001244 é válido.
# O CPF 00000001245 não é válido.
# O CPF 00000001246 não é válido.
# O CPF 00000001247 não é válido.
# O CPF 00000001248 não é válido.
# O CPF 00000001249 não é válido.
# O CPF 00000001250 não é válido.
# O CPF 00000001251 não é válido.
# O CPF 00000001252 não é válido.
# O CPF 00000001253 não é válido.
# O CPF 00000001254 não é válido.
# O CPF 00000001255 não é válido.
# O CPF 00000001256 não é válido.
# O CPF 00000001257 não é válido.
# O CPF 00000001258 não é válido.
# O CPF 00000001259 não é válido.
# O CPF 00000001260 não é válido.
# O CPF 00000001261 não é válido.
# O CPF 00000001262 não é válido.
# O CPF 00000001263 não é válido.
# O CPF 00000001264 não é válido.
# O CPF 00000001265 não é válido.
# O CPF 00000001266 não é válido.
# O CPF 00000001267 não é válido.
# O CPF 00000001268 não é válido.
# O CPF 00000001269 não é válido.
# O CPF 00000001270 não é válido.
# O CPF 00000001271 não é válido.
# O CPF 00000001272 não é válido.
# O CPF 00000001273 não é válido.
# O CPF 00000001274 não é válido.
# O CPF 00000001275 não é válido.
# O CPF 00000001276 não é válido.
# O CPF 00000001277 não é válido.
# O CPF 00000001278 não é válido.
# O CPF 00000001279 não é válido.
# O CPF 00000001280 não é válido.
# O CPF 00000001281 não é válido.
# O CPF 00000001282 não é válido.
# O CPF 00000001283 não é válido.
# O CPF 00000001284 não é válido.
# O CPF 00000001285 não é válido.
# O CPF 00000001286 não é válido.
# O CPF 00000001287 não é válido.
# O CPF 00000001288 não é válido.
# O CPF 00000001289 não é válido.
# O CPF 00000001290 não é válido.
# O CPF 00000001291 não é válido.
# O CPF 00000001292 não é válido.
# O CPF 00000001293 não é válido.
# O CPF 00000001294 não é válido.
# O CPF 00000001295 não é válido.
# O CPF 00000001296 não é válido.
# O CPF 00000001297 não é válido.
# O CPF 00000001298 não é válido.
# O CPF 00000001299 não é válido.
# O CPF 00000001300 não é válido.
# O CPF 00000001301 não é válido.
# O CPF 00000001302 não é válido.
# O CPF 00000001303 não é válido.
# O CPF 00000001304 não é válido.
# O CPF 00000001305 não é válido.
# O CPF 00000001306 não é válido.
# O CPF 00000001307 não é válido.
# O CPF 00000001308 não é válido.
# O CPF 00000001309 não é válido.
# O CPF 00000001310 não é válido.
# O CPF 00000001311 não é válido.
# O CPF 00000001312 não é válido.
# O CPF 00000001313 não é válido.
# O CPF 00000001314 não é válido.
# O CPF 00000001315 não é válido.
# O CPF 00000001316 não é válido.
# O CPF 00000001317 não é válido.
# O CPF 00000001318 não é válido.
# O CPF 00000001319 não é válido.
# O CPF 00000001320 não é válido.
# O CPF 00000001321 não é válido.
# O CPF 00000001322 não é válido.
# O CPF 00000001323 não é válido.
# O CPF 00000001324 não é válido.
# O CPF 00000001325 é válido.
# O CPF 00000001326 não é válido.
# O CPF 00000001327 não é válido.
# O CPF 00000001328 não é válido.
# O CPF 00000001329 não é válido.
# O CPF 00000001330 não é válido.
# O CPF 00000001331 não é válido.
# O CPF 00000001332 não é válido.
# O CPF 00000001333 não é válido.
# O CPF 00000001334 não é válido.
# O CPF 00000001335 não é válido.
# O CPF 00000001336 não é válido.
# O CPF 00000001337 não é válido.
# O CPF 00000001338 não é válido.
# O CPF 00000001339 não é válido.
# O CPF 00000001340 não é válido.
# O CPF 00000001341 não é válido.
# O CPF 00000001342 não é válido.
# O CPF 00000001343 não é válido.
# O CPF 00000001344 não é válido.
# O CPF 00000001345 não é válido.
# O CPF 00000001346 não é válido.
# O CPF 00000001347 não é válido.
# O CPF 00000001348 não é válido.
# O CPF 00000001349 não é válido.
# O CPF 00000001350 não é válido.
# O CPF 00000001351 não é válido.
# O CPF 00000001352 não é válido.
# O CPF 00000001353 não é válido.
# O CPF 00000001354 não é válido.
# O CPF 00000001355 não é válido.
# O CPF 00000001356 não é válido.
# O CPF 00000001357 não é válido.
# O CPF 00000001358 não é válido.
# O CPF 00000001359 não é válido.
# O CPF 00000001360 não é válido.
# O CPF 00000001361 não é válido.
# O CPF 00000001362 não é válido.
# O CPF 00000001363 não é válido.
# O CPF 00000001364 não é válido.
# O CPF 00000001365 não é válido.
# O CPF 00000001366 não é válido.
# O CPF 00000001367 não é válido.
# O CPF 00000001368 não é válido.
# O CPF 00000001369 não é válido.
# O CPF 00000001370 não é válido.
# O CPF 00000001371 não é válido.
# O CPF 00000001372 não é válido.
# O CPF 00000001373 não é válido.
# O CPF 00000001374 não é válido.
# O CPF 00000001375 não é válido.
# O CPF 00000001376 não é válido.
# O CPF 00000001377 não é válido.
# O CPF 00000001378 não é válido.
# O CPF 00000001379 não é válido.
# O CPF 00000001380 não é válido.
# O CPF 00000001381 não é válido.
# O CPF 00000001382 não é válido.
# O CPF 00000001383 não é válido.
# O CPF 00000001384 não é válido.
# O CPF 00000001385 não é válido.
# O CPF 00000001386 não é válido.
# O CPF 00000001387 não é válido.
# O CPF 00000001388 não é válido.
# O CPF 00000001389 não é válido.
# O CPF 00000001390 não é válido.
# O CPF 00000001391 não é válido.
# O CPF 00000001392 não é válido.
# O CPF 00000001393 não é válido.
# O CPF 00000001394 não é válido.
# O CPF 00000001395 não é válido.
# O CPF 00000001396 não é válido.
# O CPF 00000001397 não é válido.
# O CPF 00000001398 não é válido.
# O CPF 00000001399 não é válido.
# O CPF 00000001400 não é válido.
# O CPF 00000001401 não é válido.
# O CPF 00000001402 não é válido.
# O CPF 00000001403 não é válido.
# O CPF 00000001404 não é válido.
# O CPF 00000001405 não é válido.
# O CPF 00000001406 é válido.
# O CPF 00000001407 não é válido.
# O CPF 00000001408 não é válido.
# O CPF 00000001409 não é válido.
# O CPF 00000001410 não é válido.
# O CPF 00000001411 não é válido.
# O CPF 00000001412 não é válido.
# O CPF 00000001413 não é válido.
# O CPF 00000001414 não é válido.
# O CPF 00000001415 não é válido.
# O CPF 00000001416 não é válido.
# O CPF 00000001417 não é válido.
# O CPF 00000001418 não é válido.
# O CPF 00000001419 não é válido.
# O CPF 00000001420 não é válido.
# O CPF 00000001421 não é válido.
# O CPF 00000001422 não é válido.
# O CPF 00000001423 não é válido.
# O CPF 00000001424 não é válido.
# O CPF 00000001425 não é válido.
# O CPF 00000001426 não é válido.
# O CPF 00000001427 não é válido.
# O CPF 00000001428 não é válido.
# O CPF 00000001429 não é válido.
# O CPF 00000001430 não é válido.
# O CPF 00000001431 não é válido.
# O CPF 00000001432 não é válido.
# O CPF 00000001433 não é válido.
# O CPF 00000001434 não é válido.
# O CPF 00000001435 não é válido.
# O CPF 00000001436 não é válido.
# O CPF 00000001437 não é válido.
# O CPF 00000001438 não é válido.
# O CPF 00000001439 não é válido.
# O CPF 00000001440 não é válido.
# O CPF 00000001441 não é válido.
# O CPF 00000001442 não é válido.
# O CPF 00000001443 não é válido.
# O CPF 00000001444 não é válido.
# O CPF 00000001445 não é válido.
# O CPF 00000001446 não é válido.
# O CPF 00000001447 não é válido.
# O CPF 00000001448 não é válido.
# O CPF 00000001449 não é válido.
# O CPF 00000001450 não é válido.
# O CPF 00000001451 não é válido.
# O CPF 00000001452 não é válido.
# O CPF 00000001453 não é válido.
# O CPF 00000001454 não é válido.
# O CPF 00000001455 não é válido.
# O CPF 00000001456 não é válido.
# O CPF 00000001457 não é válido.
# O CPF 00000001458 não é válido.
# O CPF 00000001459 não é válido.
# O CPF 00000001460 não é válido.
# O CPF 00000001461 não é válido.
# O CPF 00000001462 não é válido.
# O CPF 00000001463 não é válido.
# O CPF 00000001464 não é válido.
# O CPF 00000001465 não é válido.
# O CPF 00000001466 não é válido.
# O CPF 00000001467 não é válido.
# O CPF 00000001468 não é válido.
# O CPF 00000001469 não é válido.
# O CPF 00000001470 não é válido.
# O CPF 00000001471 não é válido.
# O CPF 00000001472 não é válido.
# O CPF 00000001473 não é válido.
# O CPF 00000001474 não é válido.
# O CPF 00000001475 não é válido.
# O CPF 00000001476 não é válido.
# O CPF 00000001477 não é válido.
# O CPF 00000001478 não é válido.
# O CPF 00000001479 não é válido.
# O CPF 00000001480 não é válido.
# O CPF 00000001481 não é válido.
# O CPF 00000001482 não é válido.
# O CPF 00000001483 não é válido.
# O CPF 00000001484 não é válido.
# O CPF 00000001485 não é válido.
# O CPF 00000001486 não é válido.
# O CPF 00000001487 não é válido.
# O CPF 00000001488 não é válido.
# O CPF 00000001489 não é válido.
# O CPF 00000001490 não é válido.
# O CPF 00000001491 não é válido.
# O CPF 00000001492 não é válido.
# O CPF 00000001493 não é válido.
# O CPF 00000001494 não é válido.
# O CPF 00000001495 não é válido.
# O CPF 00000001496 não é válido.
# O CPF 00000001497 não é válido.
# O CPF 00000001498 não é válido.
# O CPF 00000001499 não é válido.
# O CPF 00000001500 não é válido.
# ...
# O CPF 00000009500 não é válido.
# O CPF 00000009501 não é válido.
# O CPF 00000009502 não é válido.
# O CPF 00000009503 não é válido.
# O CPF 00000009504 não é válido.
# O CPF 00000009505 não é válido.
# O CPF 00000009506 não é válido.
# O CPF 00000009507 não é válido.
# O CPF 00000009508 não é válido.
# O CPF 00000009509 não é válido.
# O CPF 00000009510 não é válido.
# O CPF 00000009511 não é válido.
# O CPF 00000009512 não é válido.
# O CPF 00000009513 não é válido.
# O CPF 00000009514 não é válido.
# O CPF 00000009515 não é válido.
# O CPF 00000009516 não é válido.
# O CPF 00000009517 não é válido.
# O CPF 00000009518 não é válido.
# O CPF 00000009519 não é válido.
# O CPF 00000009520 não é válido.
# O CPF 00000009521 não é válido.
# O CPF 00000009522 não é válido.
# O CPF 00000009523 não é válido.
# O CPF 00000009524 não é válido.
# O CPF 00000009525 não é válido.
# O CPF 00000009526 não é válido.
# O CPF 00000009527 não é válido.
# O CPF 00000009528 não é válido.
# O CPF 00000009529 não é válido.
# O CPF 00000009530 não é válido.
# O CPF 00000009531 não é válido.
# O CPF 00000009532 não é válido.
# O CPF 00000009533 não é válido.
# O CPF 00000009534 não é válido.
# O CPF 00000009535 não é válido.
# O CPF 00000009536 não é válido.
# O CPF 00000009537 não é válido.
# O CPF 00000009538 não é válido.
# O CPF 00000009539 não é válido.
# O CPF 00000009540 não é válido.
# O CPF 00000009541 não é válido.
# O CPF 00000009542 não é válido.
# O CPF 00000009543 não é válido.
# O CPF 00000009544 não é válido.
# O CPF 00000009545 não é válido.
# O CPF 00000009546 não é válido.
# O CPF 00000009547 não é válido.
# O CPF 00000009548 não é válido.
# O CPF 00000009549 não é válido.
# O CPF 00000009550 não é válido.
# O CPF 00000009551 não é válido.
# O CPF 00000009552 não é válido.
# O CPF 00000009553 não é válido.
# O CPF 00000009554 não é válido.
# O CPF 00000009555 não é válido.
# O CPF 00000009556 não é válido.
# O CPF 00000009557 não é válido.
# O CPF 00000009558 não é válido.
# O CPF 00000009559 não é válido.
# O CPF 00000009560 não é válido.
# O CPF 00000009561 não é válido.
# O CPF 00000009562 não é válido.
# O CPF 00000009563 não é válido.
# O CPF 00000009564 não é válido.
# O CPF 00000009565 não é válido.
# O CPF 00000009566 não é válido.
# O CPF 00000009567 não é válido.
# O CPF 00000009568 não é válido.
# O CPF 00000009569 não é válido.
# O CPF 00000009570 não é válido.
# O CPF 00000009571 é válido.
# O CPF 00000009572 não é válido.
# O CPF 00000009573 não é válido.
# O CPF 00000009574 não é válido.
# O CPF 00000009575 não é válido.
# O CPF 00000009576 não é válido.
# O CPF 00000009577 não é válido.
# O CPF 00000009578 não é válido.
# O CPF 00000009579 não é válido.
# O CPF 00000009580 não é válido.
# O CPF 00000009581 não é válido.
# O CPF 00000009582 não é válido.
# O CPF 00000009583 não é válido.
# O CPF 00000009584 não é válido.
# O CPF 00000009585 não é válido.
# O CPF 00000009586 não é válido.
# O CPF 00000009587 não é válido.
# O CPF 00000009588 não é válido.
# O CPF 00000009589 não é válido.
# O CPF 00000009590 não é válido.
# O CPF 00000009591 não é válido.
# O CPF 00000009592 não é válido.
# O CPF 00000009593 não é válido.
# O CPF 00000009594 não é válido.
# O CPF 00000009595 não é válido.
# O CPF 00000009596 não é válido.
# O CPF 00000009597 não é válido.
# O CPF 00000009598 não é válido.
# O CPF 00000009599 não é válido.
# O CPF 00000009600 não é válido.
# O CPF 00000009601 não é válido.
# O CPF 00000009602 não é válido.
# O CPF 00000009603 não é válido.
# O CPF 00000009604 não é válido.
# O CPF 00000009605 não é válido.
# O CPF 00000009606 não é válido.
# O CPF 00000009607 não é válido.
# O CPF 00000009608 não é válido.
# O CPF 00000009609 não é válido.
# O CPF 00000009610 não é válido.
# O CPF 00000009611 não é válido.
# O CPF 00000009612 não é válido.
# O CPF 00000009613 não é válido.
# O CPF 00000009614 não é válido.
# O CPF 00000009615 não é válido.
# O CPF 00000009616 não é válido.
# O CPF 00000009617 não é válido.
# O CPF 00000009618 não é válido.
# O CPF 00000009619 não é válido.
# O CPF 00000009620 não é válido.
# O CPF 00000009621 não é válido.
# O CPF 00000009622 não é válido.
# O CPF 00000009623 não é válido.
# O CPF 00000009624 não é válido.
# O CPF 00000009625 não é válido.
# O CPF 00000009626 não é válido.
# O CPF 00000009627 não é válido.
# O CPF 00000009628 não é válido.
# O CPF 00000009629 não é válido.
# O CPF 00000009630 não é válido.
# O CPF 00000009631 não é válido.
# O CPF 00000009632 não é válido.
# O CPF 00000009633 não é válido.
# O CPF 00000009634 não é válido.
# O CPF 00000009635 não é válido.
# O CPF 00000009636 não é válido.
# O CPF 00000009637 não é válido.
# O CPF 00000009638 não é válido.
# O CPF 00000009639 não é válido.
# O CPF 00000009640 não é válido.
# O CPF 00000009641 não é válido.
# O CPF 00000009642 não é válido.
# O CPF 00000009643 não é válido.
# O CPF 00000009644 não é válido.
# O CPF 00000009645 não é válido.
# O CPF 00000009646 não é válido.
# O CPF 00000009647 não é válido.
# O CPF 00000009648 não é válido.
# O CPF 00000009649 não é válido.
# O CPF 00000009650 não é válido.
# O CPF 00000009651 não é válido.
# O CPF 00000009652 é válido.
# O CPF 00000009653 não é válido.
# O CPF 00000009654 não é válido.
# O CPF 00000009655 não é válido.
# O CPF 00000009656 não é válido.
# O CPF 00000009657 não é válido.
# O CPF 00000009658 não é válido.
# O CPF 00000009659 não é válido.
# O CPF 00000009660 não é válido.
# O CPF 00000009661 não é válido.
# O CPF 00000009662 não é válido.
# O CPF 00000009663 não é válido.
# O CPF 00000009664 não é válido.
# O CPF 00000009665 não é válido.
# O CPF 00000009666 não é válido.
# O CPF 00000009667 não é válido.
# O CPF 00000009668 não é válido.
# O CPF 00000009669 não é válido.
# O CPF 00000009670 não é válido.
# O CPF 00000009671 não é válido.
# O CPF 00000009672 não é válido.
# O CPF 00000009673 não é válido.
# O CPF 00000009674 não é válido.
# O CPF 00000009675 não é válido.
# O CPF 00000009676 não é válido.
# O CPF 00000009677 não é válido.
# O CPF 00000009678 não é válido.
# O CPF 00000009679 não é válido.
# O CPF 00000009680 não é válido.
# O CPF 00000009681 não é válido.
# O CPF 00000009682 não é válido.
# O CPF 00000009683 não é válido.
# O CPF 00000009684 não é válido.
# O CPF 00000009685 não é válido.
# O CPF 00000009686 não é válido.
# O CPF 00000009687 não é válido.
# O CPF 00000009688 não é válido.
# O CPF 00000009689 não é válido.
# O CPF 00000009690 não é válido.
# O CPF 00000009691 não é válido.
# O CPF 00000009692 não é válido.
# O CPF 00000009693 não é válido.
# O CPF 00000009694 não é válido.
# O CPF 00000009695 não é válido.
# O CPF 00000009696 não é válido.
# O CPF 00000009697 não é válido.
# O CPF 00000009698 não é válido.
# O CPF 00000009699 não é válido.
# O CPF 00000009700 não é válido.
# O CPF 00000009701 não é válido.
# O CPF 00000009702 não é válido.
# O CPF 00000009703 não é válido.
# O CPF 00000009704 não é válido.
# O CPF 00000009705 não é válido.
# O CPF 00000009706 não é válido.
# O CPF 00000009707 não é válido.
# O CPF 00000009708 não é válido.
# O CPF 00000009709 não é válido.
# O CPF 00000009710 não é válido.
# O CPF 00000009711 não é válido.
# O CPF 00000009712 não é válido.
# O CPF 00000009713 não é válido.
# O CPF 00000009714 não é válido.
# O CPF 00000009715 não é válido.
# O CPF 00000009716 não é válido.
# O CPF 00000009717 não é válido.
# O CPF 00000009718 não é válido.
# O CPF 00000009719 não é válido.
# O CPF 00000009720 não é válido.
# O CPF 00000009721 não é válido.
# O CPF 00000009722 não é válido.
# O CPF 00000009723 não é válido.
# O CPF 00000009724 não é válido.
# O CPF 00000009725 não é válido.
# O CPF 00000009726 não é válido.
# O CPF 00000009727 não é válido.
# O CPF 00000009728 não é válido.
# O CPF 00000009729 não é válido.
# O CPF 00000009730 não é válido.
# O CPF 00000009731 não é válido.
# O CPF 00000009732 não é válido.
# O CPF 00000009733 é válido.
# O CPF 00000009734 não é válido.
# O CPF 00000009735 não é válido.
# O CPF 00000009736 não é válido.
# O CPF 00000009737 não é válido.
# O CPF 00000009738 não é válido.
# O CPF 00000009739 não é válido.
# O CPF 00000009740 não é válido.
# O CPF 00000009741 não é válido.
# O CPF 00000009742 não é válido.
# O CPF 00000009743 não é válido.
# O CPF 00000009744 não é válido.
# O CPF 00000009745 não é válido.
# O CPF 00000009746 não é válido.
# O CPF 00000009747 não é válido.
# O CPF 00000009748 não é válido.
# O CPF 00000009749 não é válido.
# O CPF 00000009750 não é válido.
# O CPF 00000009751 não é válido.
# O CPF 00000009752 não é válido.
# O CPF 00000009753 não é válido.
# O CPF 00000009754 não é válido.
# O CPF 00000009755 não é válido.
# O CPF 00000009756 não é válido.
# O CPF 00000009757 não é válido.
# O CPF 00000009758 não é válido.
# O CPF 00000009759 não é válido.
# O CPF 00000009760 não é válido.
# O CPF 00000009761 não é válido.
# O CPF 00000009762 não é válido.
# O CPF 00000009763 não é válido.
# O CPF 00000009764 não é válido.
# O CPF 00000009765 não é válido.
# O CPF 00000009766 não é válido.
# O CPF 00000009767 não é válido.
# O CPF 00000009768 não é válido.
# O CPF 00000009769 não é válido.
# O CPF 00000009770 não é válido.
# O CPF 00000009771 não é válido.
# O CPF 00000009772 não é válido.
# O CPF 00000009773 não é válido.
# O CPF 00000009774 não é válido.
# O CPF 00000009775 não é válido.
# O CPF 00000009776 não é válido.
# O CPF 00000009777 não é válido.
# O CPF 00000009778 não é válido.
# O CPF 00000009779 não é válido.
# O CPF 00000009780 não é válido.
# O CPF 00000009781 não é válido.
# O CPF 00000009782 não é válido.
# O CPF 00000009783 não é válido.
# O CPF 00000009784 não é válido.
# O CPF 00000009785 não é válido.
# O CPF 00000009786 não é válido.
# O CPF 00000009787 não é válido.
# O CPF 00000009788 não é válido.
# O CPF 00000009789 não é válido.
# O CPF 00000009790 não é válido.
# O CPF 00000009791 não é válido.
# O CPF 00000009792 não é válido.
# O CPF 00000009793 não é válido.
# O CPF 00000009794 não é válido.
# O CPF 00000009795 não é válido.
# O CPF 00000009796 não é válido.
# O CPF 00000009797 não é válido.
# O CPF 00000009798 não é válido.
# O CPF 00000009799 não é válido.
# O CPF 00000009800 não é válido.
# O CPF 00000009801 não é válido.
# O CPF 00000009802 não é válido.
# O CPF 00000009803 não é válido.
# O CPF 00000009804 não é válido.
# O CPF 00000009805 não é válido.
# O CPF 00000009806 não é válido.
# O CPF 00000009807 não é válido.
# O CPF 00000009808 não é válido.
# O CPF 00000009809 não é válido.
# O CPF 00000009810 não é válido.
# O CPF 00000009811 não é válido.
# O CPF 00000009812 não é válido.
# O CPF 00000009813 não é válido.
# O CPF 00000009814 é válido.
# O CPF 00000009815 não é válido.
# O CPF 00000009816 não é válido.
# O CPF 00000009817 não é válido.
# O CPF 00000009818 não é válido.
# O CPF 00000009819 não é válido.
# O CPF 00000009820 não é válido.
# O CPF 00000009821 não é válido.
# O CPF 00000009822 não é válido.
# O CPF 00000009823 não é válido.
# O CPF 00000009824 não é válido.
# O CPF 00000009825 não é válido.
# O CPF 00000009826 não é válido.
# O CPF 00000009827 não é válido.
# O CPF 00000009828 não é válido.
# O CPF 00000009829 não é válido.
# O CPF 00000009830 não é válido.
# O CPF 00000009831 não é válido.
# O CPF 00000009832 não é válido.
# O CPF 00000009833 não é válido.
# O CPF 00000009834 não é válido.
# O CPF 00000009835 não é válido.
# O CPF 00000009836 não é válido.
# O CPF 00000009837 não é válido.
# O CPF 00000009838 não é válido.
# O CPF 00000009839 não é válido.
# O CPF 00000009840 não é válido.
# O CPF 00000009841 não é válido.
# O CPF 00000009842 não é válido.
# O CPF 00000009843 não é válido.
# O CPF 00000009844 não é válido.
# O CPF 00000009845 não é válido.
# O CPF 00000009846 não é válido.
# O CPF 00000009847 não é válido.
# O CPF 00000009848 não é válido.
# O CPF 00000009849 não é válido.
# O CPF 00000009850 não é válido.
# O CPF 00000009851 não é válido.
# O CPF 00000009852 não é válido.
# O CPF 00000009853 não é válido.
# O CPF 00000009854 não é válido.
# O CPF 00000009855 não é válido.
# O CPF 00000009856 não é válido.
# O CPF 00000009857 não é válido.
# O CPF 00000009858 não é válido.
# O CPF 00000009859 não é válido.
# O CPF 00000009860 não é válido.
# O CPF 00000009861 não é válido.
# O CPF 00000009862 não é válido.
# O CPF 00000009863 não é válido.
# O CPF 00000009864 não é válido.
# O CPF 00000009865 não é válido.
# O CPF 00000009866 não é válido.
# O CPF 00000009867 não é válido.
# O CPF 00000009868 não é válido.
# O CPF 00000009869 não é válido.
# O CPF 00000009870 não é válido.
# O CPF 00000009871 não é válido.
# O CPF 00000009872 não é válido.
# O CPF 00000009873 não é válido.
# O CPF 00000009874 não é válido.
# O CPF 00000009875 não é válido.
# O CPF 00000009876 não é válido.
# O CPF 00000009877 não é válido.
# O CPF 00000009878 não é válido.
# O CPF 00000009879 não é válido.
# O CPF 00000009880 não é válido.
# O CPF 00000009881 não é válido.
# O CPF 00000009882 não é válido.
# O CPF 00000009883 não é válido.
# O CPF 00000009884 não é válido.
# O CPF 00000009885 não é válido.
# O CPF 00000009886 não é válido.
# O CPF 00000009887 não é válido.
# O CPF 00000009888 não é válido.
# O CPF 00000009889 não é válido.
# O CPF 00000009890 não é válido.
# O CPF 00000009891 não é válido.
# O CPF 00000009892 não é válido.
# O CPF 00000009893 não é válido.
# O CPF 00000009894 não é válido.
# O CPF 00000009895 não é válido.
# O CPF 00000009896 não é válido.
# O CPF 00000009897 não é válido.
# O CPF 00000009898 não é válido.
# O CPF 00000009899 não é válido.
# O CPF 00000009900 não é válido.
# O CPF 00000009901 não é válido.
# O CPF 00000009902 não é válido.
# O CPF 00000009903 não é válido.
# O CPF 00000009904 não é válido.
# O CPF 00000009905 não é válido.
# O CPF 00000009906 não é válido.
# O CPF 00000009907 não é válido.
# O CPF 00000009908 não é válido.
# O CPF 00000009909 não é válido.
# O CPF 00000009910 não é válido.
# O CPF 00000009911 não é válido.
# O CPF 00000009912 não é válido.
# O CPF 00000009913 não é válido.
# O CPF 00000009914 não é válido.
# O CPF 00000009915 não é válido.
# O CPF 00000009916 não é válido.
# O CPF 00000009917 não é válido.
# O CPF 00000009918 não é válido.
# O CPF 00000009919 não é válido.
# O CPF 00000009920 não é válido.
# O CPF 00000009921 não é válido.
# O CPF 00000009922 não é válido.
# O CPF 00000009923 não é válido.
# O CPF 00000009924 não é válido.
# O CPF 00000009925 não é válido.
# O CPF 00000009926 não é válido.
# O CPF 00000009927 não é válido.
# O CPF 00000009928 não é válido.
# O CPF 00000009929 não é válido.
# O CPF 00000009930 não é válido.
# O CPF 00000009931 não é válido.
# O CPF 00000009932 não é válido.
# O CPF 00000009933 não é válido.
# O CPF 00000009934 não é válido.
# O CPF 00000009935 não é válido.
# O CPF 00000009936 não é válido.
# O CPF 00000009937 não é válido.
# O CPF 00000009938 não é válido.
# O CPF 00000009939 não é válido.
# O CPF 00000009940 não é válido.
# O CPF 00000009941 não é válido.
# O CPF 00000009942 não é válido.
# O CPF 00000009943 não é válido.
# O CPF 00000009944 não é válido.
# O CPF 00000009945 não é válido.
# O CPF 00000009946 não é válido.
# O CPF 00000009947 não é válido.
# O CPF 00000009948 não é válido.
# O CPF 00000009949 não é válido.
# O CPF 00000009950 não é válido.
# O CPF 00000009951 não é válido.
# O CPF 00000009952 não é válido.
# O CPF 00000009953 não é válido.
# O CPF 00000009954 não é válido.
# O CPF 00000009955 não é válido.
# O CPF 00000009956 não é válido.
# O CPF 00000009957 não é válido.
# O CPF 00000009958 não é válido.
# O CPF 00000009959 não é válido.
# O CPF 00000009960 não é válido.
# O CPF 00000009961 não é válido.
# O CPF 00000009962 não é válido.
# O CPF 00000009963 não é válido.
# O CPF 00000009964 não é válido.
# O CPF 00000009965 não é válido.
# O CPF 00000009966 não é válido.
# O CPF 00000009967 não é válido.
# O CPF 00000009968 não é válido.
# O CPF 00000009969 não é válido.
# O CPF 00000009970 não é válido.
# O CPF 00000009971 não é válido.
# O CPF 00000009972 não é válido.
# O CPF 00000009973 não é válido.
# O CPF 00000009974 não é válido.
# O CPF 00000009975 não é válido.
# O CPF 00000009976 não é válido.
# O CPF 00000009977 não é válido.
# O CPF 00000009978 não é válido.
# O CPF 00000009979 não é válido.
# O CPF 00000009980 não é válido.
# O CPF 00000009981 não é válido.
# O CPF 00000009982 não é válido.
# O CPF 00000009983 não é válido.
# O CPF 00000009984 não é válido.
# O CPF 00000009985 não é válido.
# O CPF 00000009986 não é válido.
# O CPF 00000009987 não é válido.
# O CPF 00000009988 não é válido.
# O CPF 00000009989 não é válido.
# O CPF 00000009990 não é válido.
# O CPF 00000009991 não é válido.
# O CPF 00000009992 não é válido.
# O CPF 00000009993 não é válido.
# O CPF 00000009994 não é válido.
# O CPF 00000009995 não é válido.
# O CPF 00000009996 não é válido.
# O CPF 00000009997 não é válido.
# O CPF 00000009998 não é válido.
# O CPF 00000009999 não é válido.

# %%
tempo_validar_cpf = end_time - start_time
print("Tempo total funcao validar_cpf:", end_time - start_time, "segundos")
# Out:
# Tempo total funcao validar_cpf: 0.04711294174194336 segundos

# %%
start_time = time.time()
_ = [validacao_cpf(cpf) for cpf in cpfs]   
end_time = time.time()
# Out:
# O CPF 00000000000 não é válido.
# O CPF 00000000001 não é válido.
# O CPF 00000000002 não é válido.
# O CPF 00000000003 não é válido.
# O CPF 00000000004 não é válido.
# O CPF 00000000005 não é válido.
# O CPF 00000000006 não é válido.
# O CPF 00000000007 não é válido.
# O CPF 00000000008 não é válido.
# O CPF 00000000009 não é válido.
# O CPF 00000000010 não é válido.
# O CPF 00000000011 não é válido.
# O CPF 00000000012 não é válido.
# O CPF 00000000013 não é válido.
# O CPF 00000000014 não é válido.
# O CPF 00000000015 não é válido.
# O CPF 00000000016 não é válido.
# O CPF 00000000017 não é válido.
# O CPF 00000000018 não é válido.
# O CPF 00000000019 não é válido.
# O CPF 00000000020 não é válido.
# O CPF 00000000021 não é válido.
# O CPF 00000000022 não é válido.
# O CPF 00000000023 não é válido.
# O CPF 00000000024 não é válido.
# O CPF 00000000025 não é válido.
# O CPF 00000000026 não é válido.
# O CPF 00000000027 não é válido.
# O CPF 00000000028 não é válido.
# O CPF 00000000029 não é válido.
# O CPF 00000000030 não é válido.
# O CPF 00000000031 não é válido.
# O CPF 00000000032 não é válido.
# O CPF 00000000033 não é válido.
# O CPF 00000000034 não é válido.
# O CPF 00000000035 não é válido.
# O CPF 00000000036 não é válido.
# O CPF 00000000037 não é válido.
# O CPF 00000000038 não é válido.
# O CPF 00000000039 não é válido.
# O CPF 00000000040 não é válido.
# O CPF 00000000041 não é válido.
# O CPF 00000000042 não é válido.
# O CPF 00000000043 não é válido.
# O CPF 00000000044 não é válido.
# O CPF 00000000045 não é válido.
# O CPF 00000000046 não é válido.
# O CPF 00000000047 não é válido.
# O CPF 00000000048 não é válido.
# O CPF 00000000049 não é válido.
# O CPF 00000000050 não é válido.
# O CPF 00000000051 não é válido.
# O CPF 00000000052 não é válido.
# O CPF 00000000053 não é válido.
# O CPF 00000000054 não é válido.
# O CPF 00000000055 não é válido.
# O CPF 00000000056 não é válido.
# O CPF 00000000057 não é válido.
# O CPF 00000000058 não é válido.
# O CPF 00000000059 não é válido.
# O CPF 00000000060 não é válido.
# O CPF 00000000061 não é válido.
# O CPF 00000000062 não é válido.
# O CPF 00000000063 não é válido.
# O CPF 00000000064 não é válido.
# O CPF 00000000065 não é válido.
# O CPF 00000000066 não é válido.
# O CPF 00000000067 não é válido.
# O CPF 00000000068 não é válido.
# O CPF 00000000069 não é válido.
# O CPF 00000000070 não é válido.
# O CPF 00000000071 não é válido.
# O CPF 00000000072 não é válido.
# O CPF 00000000073 não é válido.
# O CPF 00000000074 não é válido.
# O CPF 00000000075 não é válido.
# O CPF 00000000076 não é válido.
# O CPF 00000000077 não é válido.
# O CPF 00000000078 não é válido.
# O CPF 00000000079 não é válido.
# O CPF 00000000080 não é válido.
# O CPF 00000000081 não é válido.
# O CPF 00000000082 não é válido.
# O CPF 00000000083 não é válido.
# O CPF 00000000084 não é válido.
# O CPF 00000000085 não é válido.
# O CPF 00000000086 não é válido.
# O CPF 00000000087 não é válido.
# O CPF 00000000088 não é válido.
# O CPF 00000000089 não é válido.
# O CPF 00000000090 não é válido.
# O CPF 00000000091 não é válido.
# O CPF 00000000092 não é válido.
# O CPF 00000000093 não é válido.
# O CPF 00000000094 não é válido.
# O CPF 00000000095 não é válido.
# O CPF 00000000096 não é válido.
# O CPF 00000000097 não é válido.
# O CPF 00000000098 não é válido.
# O CPF 00000000099 não é válido.
# O CPF 00000000100 não é válido.
# O CPF 00000000101 não é válido.
# O CPF 00000000102 não é válido.
# O CPF 00000000103 não é válido.
# O CPF 00000000104 não é válido.
# O CPF 00000000105 não é válido.
# O CPF 00000000106 não é válido.
# O CPF 00000000107 não é válido.
# O CPF 00000000108 não é válido.
# O CPF 00000000109 não é válido.
# O CPF 00000000110 não é válido.
# O CPF 00000000111 não é válido.
# O CPF 00000000112 não é válido.
# O CPF 00000000113 não é válido.
# O CPF 00000000114 não é válido.
# O CPF 00000000115 não é válido.
# O CPF 00000000116 não é válido.
# O CPF 00000000117 não é válido.
# O CPF 00000000118 não é válido.
# O CPF 00000000119 não é válido.
# O CPF 00000000120 não é válido.
# O CPF 00000000121 não é válido.
# O CPF 00000000122 não é válido.
# O CPF 00000000123 não é válido.
# O CPF 00000000124 não é válido.
# O CPF 00000000125 não é válido.
# O CPF 00000000126 não é válido.
# O CPF 00000000127 não é válido.
# O CPF 00000000128 não é válido.
# O CPF 00000000129 não é válido.
# O CPF 00000000130 não é válido.
# O CPF 00000000131 não é válido.
# O CPF 00000000132 não é válido.
# O CPF 00000000133 não é válido.
# O CPF 00000000134 não é válido.
# O CPF 00000000135 não é válido.
# O CPF 00000000136 não é válido.
# O CPF 00000000137 não é válido.
# O CPF 00000000138 não é válido.
# O CPF 00000000139 não é válido.
# O CPF 00000000140 não é válido.
# O CPF 00000000141 não é válido.
# O CPF 00000000142 não é válido.
# O CPF 00000000143 não é válido.
# O CPF 00000000144 não é válido.
# O CPF 00000000145 não é válido.
# O CPF 00000000146 não é válido.
# O CPF 00000000147 não é válido.
# O CPF 00000000148 não é válido.
# O CPF 00000000149 não é válido.
# O CPF 00000000150 não é válido.
# O CPF 00000000151 não é válido.
# O CPF 00000000152 não é válido.
# O CPF 00000000153 não é válido.
# O CPF 00000000154 não é válido.
# O CPF 00000000155 não é válido.
# O CPF 00000000156 não é válido.
# O CPF 00000000157 não é válido.
# O CPF 00000000158 não é válido.
# O CPF 00000000159 não é válido.
# O CPF 00000000160 não é válido.
# O CPF 00000000161 não é válido.
# O CPF 00000000162 não é válido.
# O CPF 00000000163 não é válido.
# O CPF 00000000164 não é válido.
# O CPF 00000000165 não é válido.
# O CPF 00000000166 não é válido.
# O CPF 00000000167 não é válido.
# O CPF 00000000168 não é válido.
# O CPF 00000000169 não é válido.
# O CPF 00000000170 não é válido.
# O CPF 00000000171 não é válido.
# O CPF 00000000172 não é válido.
# O CPF 00000000173 não é válido.
# O CPF 00000000174 não é válido.
# O CPF 00000000175 não é válido.
# O CPF 00000000176 não é válido.
# O CPF 00000000177 não é válido.
# O CPF 00000000178 não é válido.
# O CPF 00000000179 não é válido.
# O CPF 00000000180 não é válido.
# O CPF 00000000181 não é válido.
# O CPF 00000000182 não é válido.
# O CPF 00000000183 não é válido.
# O CPF 00000000184 não é válido.
# O CPF 00000000185 não é válido.
# O CPF 00000000186 não é válido.
# O CPF 00000000187 não é válido.
# O CPF 00000000188 não é válido.
# O CPF 00000000189 não é válido.
# O CPF 00000000190 não é válido.
# O CPF 00000000191 é válido.
# O CPF 00000000192 não é válido.
# O CPF 00000000193 não é válido.
# O CPF 00000000194 não é válido.
# O CPF 00000000195 não é válido.
# O CPF 00000000196 não é válido.
# O CPF 00000000197 não é válido.
# O CPF 00000000198 não é válido.
# O CPF 00000000199 não é válido.
# O CPF 00000000200 não é válido.
# O CPF 00000000201 não é válido.
# O CPF 00000000202 não é válido.
# O CPF 00000000203 não é válido.
# O CPF 00000000204 não é válido.
# O CPF 00000000205 não é válido.
# O CPF 00000000206 não é válido.
# O CPF 00000000207 não é válido.
# O CPF 00000000208 não é válido.
# O CPF 00000000209 não é válido.
# O CPF 00000000210 não é válido.
# O CPF 00000000211 não é válido.
# O CPF 00000000212 não é válido.
# O CPF 00000000213 não é válido.
# O CPF 00000000214 não é válido.
# O CPF 00000000215 não é válido.
# O CPF 00000000216 não é válido.
# O CPF 00000000217 não é válido.
# O CPF 00000000218 não é válido.
# O CPF 00000000219 não é válido.
# O CPF 00000000220 não é válido.
# O CPF 00000000221 não é válido.
# O CPF 00000000222 não é válido.
# O CPF 00000000223 não é válido.
# O CPF 00000000224 não é válido.
# O CPF 00000000225 não é válido.
# O CPF 00000000226 não é válido.
# O CPF 00000000227 não é válido.
# O CPF 00000000228 não é válido.
# O CPF 00000000229 não é válido.
# O CPF 00000000230 não é válido.
# O CPF 00000000231 não é válido.
# O CPF 00000000232 não é válido.
# O CPF 00000000233 não é válido.
# O CPF 00000000234 não é válido.
# O CPF 00000000235 não é válido.
# O CPF 00000000236 não é válido.
# O CPF 00000000237 não é válido.
# O CPF 00000000238 não é válido.
# O CPF 00000000239 não é válido.
# O CPF 00000000240 não é válido.
# O CPF 00000000241 não é válido.
# O CPF 00000000242 não é válido.
# O CPF 00000000243 não é válido.
# O CPF 00000000244 não é válido.
# O CPF 00000000245 não é válido.
# O CPF 00000000246 não é válido.
# O CPF 00000000247 não é válido.
# O CPF 00000000248 não é válido.
# O CPF 00000000249 não é válido.
# O CPF 00000000250 não é válido.
# O CPF 00000000251 não é válido.
# O CPF 00000000252 não é válido.
# O CPF 00000000253 não é válido.
# O CPF 00000000254 não é válido.
# O CPF 00000000255 não é válido.
# O CPF 00000000256 não é válido.
# O CPF 00000000257 não é válido.
# O CPF 00000000258 não é válido.
# O CPF 00000000259 não é válido.
# O CPF 00000000260 não é válido.
# O CPF 00000000261 não é válido.
# O CPF 00000000262 não é válido.
# O CPF 00000000263 não é válido.
# O CPF 00000000264 não é válido.
# O CPF 00000000265 não é válido.
# O CPF 00000000266 não é válido.
# O CPF 00000000267 não é válido.
# O CPF 00000000268 não é válido.
# O CPF 00000000269 não é válido.
# O CPF 00000000270 não é válido.
# O CPF 00000000271 não é válido.
# O CPF 00000000272 é válido.
# O CPF 00000000273 não é válido.
# O CPF 00000000274 não é válido.
# O CPF 00000000275 não é válido.
# O CPF 00000000276 não é válido.
# O CPF 00000000277 não é válido.
# O CPF 00000000278 não é válido.
# O CPF 00000000279 não é válido.
# O CPF 00000000280 não é válido.
# O CPF 00000000281 não é válido.
# O CPF 00000000282 não é válido.
# O CPF 00000000283 não é válido.
# O CPF 00000000284 não é válido.
# O CPF 00000000285 não é válido.
# O CPF 00000000286 não é válido.
# O CPF 00000000287 não é válido.
# O CPF 00000000288 não é válido.
# O CPF 00000000289 não é válido.
# O CPF 00000000290 não é válido.
# O CPF 00000000291 não é válido.
# O CPF 00000000292 não é válido.
# O CPF 00000000293 não é válido.
# O CPF 00000000294 não é válido.
# O CPF 00000000295 não é válido.
# O CPF 00000000296 não é válido.
# O CPF 00000000297 não é válido.
# O CPF 00000000298 não é válido.
# O CPF 00000000299 não é válido.
# O CPF 00000000300 não é válido.
# O CPF 00000000301 não é válido.
# O CPF 00000000302 não é válido.
# O CPF 00000000303 não é válido.
# O CPF 00000000304 não é válido.
# O CPF 00000000305 não é válido.
# O CPF 00000000306 não é válido.
# O CPF 00000000307 não é válido.
# O CPF 00000000308 não é válido.
# O CPF 00000000309 não é válido.
# O CPF 00000000310 não é válido.
# O CPF 00000000311 não é válido.
# O CPF 00000000312 não é válido.
# O CPF 00000000313 não é válido.
# O CPF 00000000314 não é válido.
# O CPF 00000000315 não é válido.
# O CPF 00000000316 não é válido.
# O CPF 00000000317 não é válido.
# O CPF 00000000318 não é válido.
# O CPF 00000000319 não é válido.
# O CPF 00000000320 não é válido.
# O CPF 00000000321 não é válido.
# O CPF 00000000322 não é válido.
# O CPF 00000000323 não é válido.
# O CPF 00000000324 não é válido.
# O CPF 00000000325 não é válido.
# O CPF 00000000326 não é válido.
# O CPF 00000000327 não é válido.
# O CPF 00000000328 não é válido.
# O CPF 00000000329 não é válido.
# O CPF 00000000330 não é válido.
# O CPF 00000000331 não é válido.
# O CPF 00000000332 não é válido.
# O CPF 00000000333 não é válido.
# O CPF 00000000334 não é válido.
# O CPF 00000000335 não é válido.
# O CPF 00000000336 não é válido.
# O CPF 00000000337 não é válido.
# O CPF 00000000338 não é válido.
# O CPF 00000000339 não é válido.
# O CPF 00000000340 não é válido.
# O CPF 00000000341 não é válido.
# O CPF 00000000342 não é válido.
# O CPF 00000000343 não é válido.
# O CPF 00000000344 não é válido.
# O CPF 00000000345 não é válido.
# O CPF 00000000346 não é válido.
# O CPF 00000000347 não é válido.
# O CPF 00000000348 não é válido.
# O CPF 00000000349 não é válido.
# O CPF 00000000350 não é válido.
# O CPF 00000000351 não é válido.
# O CPF 00000000352 não é válido.
# O CPF 00000000353 é válido.
# O CPF 00000000354 não é válido.
# O CPF 00000000355 não é válido.
# O CPF 00000000356 não é válido.
# O CPF 00000000357 não é válido.
# O CPF 00000000358 não é válido.
# O CPF 00000000359 não é válido.
# O CPF 00000000360 não é válido.
# O CPF 00000000361 não é válido.
# O CPF 00000000362 não é válido.
# O CPF 00000000363 não é válido.
# O CPF 00000000364 não é válido.
# O CPF 00000000365 não é válido.
# O CPF 00000000366 não é válido.
# O CPF 00000000367 não é válido.
# O CPF 00000000368 não é válido.
# O CPF 00000000369 não é válido.
# O CPF 00000000370 não é válido.
# O CPF 00000000371 não é válido.
# O CPF 00000000372 não é válido.
# O CPF 00000000373 não é válido.
# O CPF 00000000374 não é válido.
# O CPF 00000000375 não é válido.
# O CPF 00000000376 não é válido.
# O CPF 00000000377 não é válido.
# O CPF 00000000378 não é válido.
# O CPF 00000000379 não é válido.
# O CPF 00000000380 não é válido.
# O CPF 00000000381 não é válido.
# O CPF 00000000382 não é válido.
# O CPF 00000000383 não é válido.
# O CPF 00000000384 não é válido.
# O CPF 00000000385 não é válido.
# O CPF 00000000386 não é válido.
# O CPF 00000000387 não é válido.
# O CPF 00000000388 não é válido.
# O CPF 00000000389 não é válido.
# O CPF 00000000390 não é válido.
# O CPF 00000000391 não é válido.
# O CPF 00000000392 não é válido.
# O CPF 00000000393 não é válido.
# O CPF 00000000394 não é válido.
# O CPF 00000000395 não é válido.
# O CPF 00000000396 não é válido.
# O CPF 00000000397 não é válido.
# O CPF 00000000398 não é válido.
# O CPF 00000000399 não é válido.
# O CPF 00000000400 não é válido.
# O CPF 00000000401 não é válido.
# O CPF 00000000402 não é válido.
# O CPF 00000000403 não é válido.
# O CPF 00000000404 não é válido.
# O CPF 00000000405 não é válido.
# O CPF 00000000406 não é válido.
# O CPF 00000000407 não é válido.
# O CPF 00000000408 não é válido.
# O CPF 00000000409 não é válido.
# O CPF 00000000410 não é válido.
# O CPF 00000000411 não é válido.
# O CPF 00000000412 não é válido.
# O CPF 00000000413 não é válido.
# O CPF 00000000414 não é válido.
# O CPF 00000000415 não é válido.
# O CPF 00000000416 não é válido.
# O CPF 00000000417 não é válido.
# O CPF 00000000418 não é válido.
# O CPF 00000000419 não é válido.
# O CPF 00000000420 não é válido.
# O CPF 00000000421 não é válido.
# O CPF 00000000422 não é válido.
# O CPF 00000000423 não é válido.
# O CPF 00000000424 não é válido.
# O CPF 00000000425 não é válido.
# O CPF 00000000426 não é válido.
# O CPF 00000000427 não é válido.
# O CPF 00000000428 não é válido.
# O CPF 00000000429 não é válido.
# O CPF 00000000430 não é válido.
# O CPF 00000000431 não é válido.
# O CPF 00000000432 não é válido.
# O CPF 00000000433 não é válido.
# O CPF 00000000434 é válido.
# O CPF 00000000435 não é válido.
# O CPF 00000000436 não é válido.
# O CPF 00000000437 não é válido.
# O CPF 00000000438 não é válido.
# O CPF 00000000439 não é válido.
# O CPF 00000000440 não é válido.
# O CPF 00000000441 não é válido.
# O CPF 00000000442 não é válido.
# O CPF 00000000443 não é válido.
# O CPF 00000000444 não é válido.
# O CPF 00000000445 não é válido.
# O CPF 00000000446 não é válido.
# O CPF 00000000447 não é válido.
# O CPF 00000000448 não é válido.
# O CPF 00000000449 não é válido.
# O CPF 00000000450 não é válido.
# O CPF 00000000451 não é válido.
# O CPF 00000000452 não é válido.
# O CPF 00000000453 não é válido.
# O CPF 00000000454 não é válido.
# O CPF 00000000455 não é válido.
# O CPF 00000000456 não é válido.
# O CPF 00000000457 não é válido.
# O CPF 00000000458 não é válido.
# O CPF 00000000459 não é válido.
# O CPF 00000000460 não é válido.
# O CPF 00000000461 não é válido.
# O CPF 00000000462 não é válido.
# O CPF 00000000463 não é válido.
# O CPF 00000000464 não é válido.
# O CPF 00000000465 não é válido.
# O CPF 00000000466 não é válido.
# O CPF 00000000467 não é válido.
# O CPF 00000000468 não é válido.
# O CPF 00000000469 não é válido.
# O CPF 00000000470 não é válido.
# O CPF 00000000471 não é válido.
# O CPF 00000000472 não é válido.
# O CPF 00000000473 não é válido.
# O CPF 00000000474 não é válido.
# O CPF 00000000475 não é válido.
# O CPF 00000000476 não é válido.
# O CPF 00000000477 não é válido.
# O CPF 00000000478 não é válido.
# O CPF 00000000479 não é válido.
# O CPF 00000000480 não é válido.
# O CPF 00000000481 não é válido.
# O CPF 00000000482 não é válido.
# O CPF 00000000483 não é válido.
# O CPF 00000000484 não é válido.
# O CPF 00000000485 não é válido.
# O CPF 00000000486 não é válido.
# O CPF 00000000487 não é válido.
# O CPF 00000000488 não é válido.
# O CPF 00000000489 não é válido.
# O CPF 00000000490 não é válido.
# O CPF 00000000491 não é válido.
# O CPF 00000000492 não é válido.
# O CPF 00000000493 não é válido.
# O CPF 00000000494 não é válido.
# O CPF 00000000495 não é válido.
# O CPF 00000000496 não é válido.
# O CPF 00000000497 não é válido.
# O CPF 00000000498 não é válido.
# O CPF 00000000499 não é válido.
# O CPF 00000000500 não é válido.
# O CPF 00000000501 não é válido.
# O CPF 00000000502 não é válido.
# O CPF 00000000503 não é válido.
# O CPF 00000000504 não é válido.
# O CPF 00000000505 não é válido.
# O CPF 00000000506 não é válido.
# O CPF 00000000507 não é válido.
# O CPF 00000000508 não é válido.
# O CPF 00000000509 não é válido.
# O CPF 00000000510 não é válido.
# O CPF 00000000511 não é válido.
# O CPF 00000000512 não é válido.
# O CPF 00000000513 não é válido.
# O CPF 00000000514 não é válido.
# O CPF 00000000515 é válido.
# O CPF 00000000516 não é válido.
# O CPF 00000000517 não é válido.
# O CPF 00000000518 não é válido.
# O CPF 00000000519 não é válido.
# O CPF 00000000520 não é válido.
# O CPF 00000000521 não é válido.
# O CPF 00000000522 não é válido.
# O CPF 00000000523 não é válido.
# O CPF 00000000524 não é válido.
# O CPF 00000000525 não é válido.
# O CPF 00000000526 não é válido.
# O CPF 00000000527 não é válido.
# O CPF 00000000528 não é válido.
# O CPF 00000000529 não é válido.
# O CPF 00000000530 não é válido.
# O CPF 00000000531 não é válido.
# O CPF 00000000532 não é válido.
# O CPF 00000000533 não é válido.
# O CPF 00000000534 não é válido.
# O CPF 00000000535 não é válido.
# O CPF 00000000536 não é válido.
# O CPF 00000000537 não é válido.
# O CPF 00000000538 não é válido.
# O CPF 00000000539 não é válido.
# O CPF 00000000540 não é válido.
# O CPF 00000000541 não é válido.
# O CPF 00000000542 não é válido.
# O CPF 00000000543 não é válido.
# O CPF 00000000544 não é válido.
# O CPF 00000000545 não é válido.
# O CPF 00000000546 não é válido.
# O CPF 00000000547 não é válido.
# O CPF 00000000548 não é válido.
# O CPF 00000000549 não é válido.
# O CPF 00000000550 não é válido.
# O CPF 00000000551 não é válido.
# O CPF 00000000552 não é válido.
# O CPF 00000000553 não é válido.
# O CPF 00000000554 não é válido.
# O CPF 00000000555 não é válido.
# O CPF 00000000556 não é válido.
# O CPF 00000000557 não é válido.
# O CPF 00000000558 não é válido.
# O CPF 00000000559 não é válido.
# O CPF 00000000560 não é válido.
# O CPF 00000000561 não é válido.
# O CPF 00000000562 não é válido.
# O CPF 00000000563 não é válido.
# O CPF 00000000564 não é válido.
# O CPF 00000000565 não é válido.
# O CPF 00000000566 não é válido.
# O CPF 00000000567 não é válido.
# O CPF 00000000568 não é válido.
# O CPF 00000000569 não é válido.
# O CPF 00000000570 não é válido.
# O CPF 00000000571 não é válido.
# O CPF 00000000572 não é válido.
# O CPF 00000000573 não é válido.
# O CPF 00000000574 não é válido.
# O CPF 00000000575 não é válido.
# O CPF 00000000576 não é válido.
# O CPF 00000000577 não é válido.
# O CPF 00000000578 não é válido.
# O CPF 00000000579 não é válido.
# O CPF 00000000580 não é válido.
# O CPF 00000000581 não é válido.
# O CPF 00000000582 não é válido.
# O CPF 00000000583 não é válido.
# O CPF 00000000584 não é válido.
# O CPF 00000000585 não é válido.
# O CPF 00000000586 não é válido.
# O CPF 00000000587 não é válido.
# O CPF 00000000588 não é válido.
# O CPF 00000000589 não é válido.
# O CPF 00000000590 não é válido.
# O CPF 00000000591 não é válido.
# O CPF 00000000592 não é válido.
# O CPF 00000000593 não é válido.
# O CPF 00000000594 não é válido.
# O CPF 00000000595 não é válido.
# O CPF 00000000596 não é válido.
# O CPF 00000000597 não é válido.
# O CPF 00000000598 não é válido.
# O CPF 00000000599 não é válido.
# O CPF 00000000600 não é válido.
# O CPF 00000000601 não é válido.
# O CPF 00000000602 não é válido.
# O CPF 00000000603 não é válido.
# O CPF 00000000604 não é válido.
# O CPF 00000000605 não é válido.
# O CPF 00000000606 não é válido.
# O CPF 00000000607 não é válido.
# O CPF 00000000608 não é válido.
# O CPF 00000000609 não é válido.
# O CPF 00000000610 não é válido.
# O CPF 00000000611 não é válido.
# O CPF 00000000612 não é válido.
# O CPF 00000000613 não é válido.
# O CPF 00000000614 não é válido.
# O CPF 00000000615 não é válido.
# O CPF 00000000616 não é válido.
# O CPF 00000000617 não é válido.
# O CPF 00000000618 não é válido.
# O CPF 00000000619 não é válido.
# O CPF 00000000620 não é válido.
# O CPF 00000000621 não é válido.
# O CPF 00000000622 não é válido.
# O CPF 00000000623 não é válido.
# O CPF 00000000624 não é válido.
# O CPF 00000000625 não é válido.
# O CPF 00000000626 não é válido.
# O CPF 00000000627 não é válido.
# O CPF 00000000628 não é válido.
# O CPF 00000000629 não é válido.
# O CPF 00000000630 não é válido.
# O CPF 00000000631 não é válido.
# O CPF 00000000632 não é válido.
# O CPF 00000000633 não é válido.
# O CPF 00000000634 não é válido.
# O CPF 00000000635 não é válido.
# O CPF 00000000636 não é válido.
# O CPF 00000000637 não é válido.
# O CPF 00000000638 não é válido.
# O CPF 00000000639 não é válido.
# O CPF 00000000640 não é válido.
# O CPF 00000000641 não é válido.
# O CPF 00000000642 não é válido.
# O CPF 00000000643 não é válido.
# O CPF 00000000644 não é válido.
# O CPF 00000000645 não é válido.
# O CPF 00000000646 não é válido.
# O CPF 00000000647 não é válido.
# O CPF 00000000648 não é válido.
# O CPF 00000000649 não é válido.
# O CPF 00000000650 não é válido.
# O CPF 00000000651 não é válido.
# O CPF 00000000652 não é válido.
# O CPF 00000000653 não é válido.
# O CPF 00000000654 não é válido.
# O CPF 00000000655 não é válido.
# O CPF 00000000656 não é válido.
# O CPF 00000000657 não é válido.
# O CPF 00000000658 não é válido.
# O CPF 00000000659 não é válido.
# O CPF 00000000660 não é válido.
# O CPF 00000000661 não é válido.
# O CPF 00000000662 não é válido.
# O CPF 00000000663 não é válido.
# O CPF 00000000664 não é válido.
# O CPF 00000000665 não é válido.
# O CPF 00000000666 não é válido.
# O CPF 00000000667 não é válido.
# O CPF 00000000668 não é válido.
# O CPF 00000000669 não é válido.
# O CPF 00000000670 não é válido.
# O CPF 00000000671 não é válido.
# O CPF 00000000672 não é válido.
# O CPF 00000000673 não é válido.
# O CPF 00000000674 não é válido.
# O CPF 00000000675 não é válido.
# O CPF 00000000676 não é válido.
# O CPF 00000000677 não é válido.
# O CPF 00000000678 não é válido.
# O CPF 00000000679 não é válido.
# O CPF 00000000680 não é válido.
# O CPF 00000000681 não é válido.
# O CPF 00000000682 não é válido.
# O CPF 00000000683 não é válido.
# O CPF 00000000684 não é válido.
# O CPF 00000000685 não é válido.
# O CPF 00000000686 não é válido.
# O CPF 00000000687 não é válido.
# O CPF 00000000688 não é válido.
# O CPF 00000000689 não é válido.
# O CPF 00000000690 não é válido.
# O CPF 00000000691 não é válido.
# O CPF 00000000692 não é válido.
# O CPF 00000000693 não é válido.
# O CPF 00000000694 não é válido.
# O CPF 00000000695 não é válido.
# O CPF 00000000696 não é válido.
# O CPF 00000000697 não é válido.
# O CPF 00000000698 não é válido.
# O CPF 00000000699 não é válido.
# O CPF 00000000700 não é válido.
# O CPF 00000000701 não é válido.
# O CPF 00000000702 não é válido.
# O CPF 00000000703 não é válido.
# O CPF 00000000704 não é válido.
# O CPF 00000000705 não é válido.
# O CPF 00000000706 não é válido.
# O CPF 00000000707 não é válido.
# O CPF 00000000708 não é válido.
# O CPF 00000000709 não é válido.
# O CPF 00000000710 não é válido.
# O CPF 00000000711 não é válido.
# O CPF 00000000712 não é válido.
# O CPF 00000000713 não é válido.
# O CPF 00000000714 não é válido.
# O CPF 00000000715 não é válido.
# O CPF 00000000716 não é válido.
# O CPF 00000000717 não é válido.
# O CPF 00000000718 não é válido.
# O CPF 00000000719 não é válido.
# O CPF 00000000720 não é válido.
# O CPF 00000000721 não é válido.
# O CPF 00000000722 não é válido.
# O CPF 00000000723 não é válido.
# O CPF 00000000724 não é válido.
# O CPF 00000000725 não é válido.
# O CPF 00000000726 não é válido.
# O CPF 00000000727 não é válido.
# O CPF 00000000728 não é válido.
# O CPF 00000000729 não é válido.
# O CPF 00000000730 não é válido.
# O CPF 00000000731 não é válido.
# O CPF 00000000732 não é válido.
# O CPF 00000000733 não é válido.
# O CPF 00000000734 não é válido.
# O CPF 00000000735 não é válido.
# O CPF 00000000736 não é válido.
# O CPF 00000000737 não é válido.
# O CPF 00000000738 não é válido.
# O CPF 00000000739 não é válido.
# O CPF 00000000740 não é válido.
# O CPF 00000000741 não é válido.
# O CPF 00000000742 não é válido.
# O CPF 00000000743 não é válido.
# O CPF 00000000744 não é válido.
# O CPF 00000000745 não é válido.
# O CPF 00000000746 não é válido.
# O CPF 00000000747 não é válido.
# O CPF 00000000748 não é válido.
# O CPF 00000000749 não é válido.
# O CPF 00000000750 não é válido.
# O CPF 00000000751 não é válido.
# O CPF 00000000752 não é válido.
# O CPF 00000000753 não é válido.
# O CPF 00000000754 não é válido.
# O CPF 00000000755 não é válido.
# O CPF 00000000756 não é válido.
# O CPF 00000000757 não é válido.
# O CPF 00000000758 não é válido.
# O CPF 00000000759 não é válido.
# O CPF 00000000760 não é válido.
# O CPF 00000000761 não é válido.
# O CPF 00000000762 não é válido.
# O CPF 00000000763 não é válido.
# O CPF 00000000764 não é válido.
# O CPF 00000000765 não é válido.
# O CPF 00000000766 não é válido.
# O CPF 00000000767 não é válido.
# O CPF 00000000768 não é válido.
# O CPF 00000000769 não é válido.
# O CPF 00000000770 não é válido.
# O CPF 00000000771 não é válido.
# O CPF 00000000772 não é válido.
# O CPF 00000000773 não é válido.
# O CPF 00000000774 não é válido.
# O CPF 00000000775 não é válido.
# O CPF 00000000776 não é válido.
# O CPF 00000000777 não é válido.
# O CPF 00000000778 não é válido.
# O CPF 00000000779 não é válido.
# O CPF 00000000780 não é válido.
# O CPF 00000000781 não é válido.
# O CPF 00000000782 não é válido.
# O CPF 00000000783 não é válido.
# O CPF 00000000784 não é válido.
# O CPF 00000000785 não é válido.
# O CPF 00000000786 não é válido.
# O CPF 00000000787 é válido.
# O CPF 00000000788 não é válido.
# O CPF 00000000789 não é válido.
# O CPF 00000000790 não é válido.
# O CPF 00000000791 não é válido.
# O CPF 00000000792 não é válido.
# O CPF 00000000793 não é válido.
# O CPF 00000000794 não é válido.
# O CPF 00000000795 não é válido.
# O CPF 00000000796 não é válido.
# O CPF 00000000797 não é válido.
# O CPF 00000000798 não é válido.
# O CPF 00000000799 não é válido.
# O CPF 00000000800 não é válido.
# O CPF 00000000801 não é válido.
# O CPF 00000000802 não é válido.
# O CPF 00000000803 não é válido.
# O CPF 00000000804 não é válido.
# O CPF 00000000805 não é válido.
# O CPF 00000000806 não é válido.
# O CPF 00000000807 não é válido.
# O CPF 00000000808 não é válido.
# O CPF 00000000809 não é válido.
# O CPF 00000000810 não é válido.
# O CPF 00000000811 não é válido.
# O CPF 00000000812 não é válido.
# O CPF 00000000813 não é válido.
# O CPF 00000000814 não é válido.
# O CPF 00000000815 não é válido.
# O CPF 00000000816 não é válido.
# O CPF 00000000817 não é válido.
# O CPF 00000000818 não é válido.
# O CPF 00000000819 não é válido.
# O CPF 00000000820 não é válido.
# O CPF 00000000821 não é válido.
# O CPF 00000000822 não é válido.
# O CPF 00000000823 não é válido.
# O CPF 00000000824 não é válido.
# O CPF 00000000825 não é válido.
# O CPF 00000000826 não é válido.
# O CPF 00000000827 não é válido.
# O CPF 00000000828 não é válido.
# O CPF 00000000829 não é válido.
# O CPF 00000000830 não é válido.
# O CPF 00000000831 não é válido.
# O CPF 00000000832 não é válido.
# O CPF 00000000833 não é válido.
# O CPF 00000000834 não é válido.
# O CPF 00000000835 não é válido.
# O CPF 00000000836 não é válido.
# O CPF 00000000837 não é válido.
# O CPF 00000000838 não é válido.
# O CPF 00000000839 não é válido.
# O CPF 00000000840 não é válido.
# O CPF 00000000841 não é válido.
# O CPF 00000000842 não é válido.
# O CPF 00000000843 não é válido.
# O CPF 00000000844 não é válido.
# O CPF 00000000845 não é válido.
# O CPF 00000000846 não é válido.
# O CPF 00000000847 não é válido.
# O CPF 00000000848 não é válido.
# O CPF 00000000849 não é válido.
# O CPF 00000000850 não é válido.
# O CPF 00000000851 não é válido.
# O CPF 00000000852 não é válido.
# O CPF 00000000853 não é válido.
# O CPF 00000000854 não é válido.
# O CPF 00000000855 não é válido.
# O CPF 00000000856 não é válido.
# O CPF 00000000857 não é válido.
# O CPF 00000000858 não é válido.
# O CPF 00000000859 não é válido.
# O CPF 00000000860 não é válido.
# O CPF 00000000861 não é válido.
# O CPF 00000000862 não é válido.
# O CPF 00000000863 não é válido.
# O CPF 00000000864 não é válido.
# O CPF 00000000865 não é válido.
# O CPF 00000000866 não é válido.
# O CPF 00000000867 não é válido.
# O CPF 00000000868 é válido.
# O CPF 00000000869 não é válido.
# O CPF 00000000870 não é válido.
# O CPF 00000000871 não é válido.
# O CPF 00000000872 não é válido.
# O CPF 00000000873 não é válido.
# O CPF 00000000874 não é válido.
# O CPF 00000000875 não é válido.
# O CPF 00000000876 não é válido.
# O CPF 00000000877 não é válido.
# O CPF 00000000878 não é válido.
# O CPF 00000000879 não é válido.
# O CPF 00000000880 não é válido.
# O CPF 00000000881 não é válido.
# O CPF 00000000882 não é válido.
# O CPF 00000000883 não é válido.
# O CPF 00000000884 não é válido.
# O CPF 00000000885 não é válido.
# O CPF 00000000886 não é válido.
# O CPF 00000000887 não é válido.
# O CPF 00000000888 não é válido.
# O CPF 00000000889 não é válido.
# O CPF 00000000890 não é válido.
# O CPF 00000000891 não é válido.
# O CPF 00000000892 não é válido.
# O CPF 00000000893 não é válido.
# O CPF 00000000894 não é válido.
# O CPF 00000000895 não é válido.
# O CPF 00000000896 não é válido.
# O CPF 00000000897 não é válido.
# O CPF 00000000898 não é válido.
# O CPF 00000000899 não é válido.
# O CPF 00000000900 não é válido.
# O CPF 00000000901 não é válido.
# O CPF 00000000902 não é válido.
# O CPF 00000000903 não é válido.
# O CPF 00000000904 não é válido.
# O CPF 00000000905 não é válido.
# O CPF 00000000906 não é válido.
# O CPF 00000000907 não é válido.
# O CPF 00000000908 não é válido.
# O CPF 00000000909 não é válido.
# O CPF 00000000910 não é válido.
# O CPF 00000000911 não é válido.
# O CPF 00000000912 não é válido.
# O CPF 00000000913 não é válido.
# O CPF 00000000914 não é válido.
# O CPF 00000000915 não é válido.
# O CPF 00000000916 não é válido.
# O CPF 00000000917 não é válido.
# O CPF 00000000918 não é válido.
# O CPF 00000000919 não é válido.
# O CPF 00000000920 não é válido.
# O CPF 00000000921 não é válido.
# O CPF 00000000922 não é válido.
# O CPF 00000000923 não é válido.
# O CPF 00000000924 não é válido.
# O CPF 00000000925 não é válido.
# O CPF 00000000926 não é válido.
# O CPF 00000000927 não é válido.
# O CPF 00000000928 não é válido.
# O CPF 00000000929 não é válido.
# O CPF 00000000930 não é válido.
# O CPF 00000000931 não é válido.
# O CPF 00000000932 não é válido.
# O CPF 00000000933 não é válido.
# O CPF 00000000934 não é válido.
# O CPF 00000000935 não é válido.
# O CPF 00000000936 não é válido.
# O CPF 00000000937 não é válido.
# O CPF 00000000938 não é válido.
# O CPF 00000000939 não é válido.
# O CPF 00000000940 não é válido.
# O CPF 00000000941 não é válido.
# O CPF 00000000942 não é válido.
# O CPF 00000000943 não é válido.
# O CPF 00000000944 não é válido.
# O CPF 00000000945 não é válido.
# O CPF 00000000946 não é válido.
# O CPF 00000000947 não é válido.
# O CPF 00000000948 não é válido.
# O CPF 00000000949 é válido.
# O CPF 00000000950 não é válido.
# O CPF 00000000951 não é válido.
# O CPF 00000000952 não é válido.
# O CPF 00000000953 não é válido.
# O CPF 00000000954 não é válido.
# O CPF 00000000955 não é válido.
# O CPF 00000000956 não é válido.
# O CPF 00000000957 não é válido.
# O CPF 00000000958 não é válido.
# O CPF 00000000959 não é válido.
# O CPF 00000000960 não é válido.
# O CPF 00000000961 não é válido.
# O CPF 00000000962 não é válido.
# O CPF 00000000963 não é válido.
# O CPF 00000000964 não é válido.
# O CPF 00000000965 não é válido.
# O CPF 00000000966 não é válido.
# O CPF 00000000967 não é válido.
# O CPF 00000000968 não é válido.
# O CPF 00000000969 não é válido.
# O CPF 00000000970 não é válido.
# O CPF 00000000971 não é válido.
# O CPF 00000000972 não é válido.
# O CPF 00000000973 não é válido.
# O CPF 00000000974 não é válido.
# O CPF 00000000975 não é válido.
# O CPF 00000000976 não é válido.
# O CPF 00000000977 não é válido.
# O CPF 00000000978 não é válido.
# O CPF 00000000979 não é válido.
# O CPF 00000000980 não é válido.
# O CPF 00000000981 não é válido.
# O CPF 00000000982 não é válido.
# O CPF 00000000983 não é válido.
# O CPF 00000000984 não é válido.
# O CPF 00000000985 não é válido.
# O CPF 00000000986 não é válido.
# O CPF 00000000987 não é válido.
# O CPF 00000000988 não é válido.
# O CPF 00000000989 não é válido.
# O CPF 00000000990 não é válido.
# O CPF 00000000991 não é válido.
# O CPF 00000000992 não é válido.
# O CPF 00000000993 não é válido.
# O CPF 00000000994 não é válido.
# O CPF 00000000995 não é válido.
# O CPF 00000000996 não é válido.
# O CPF 00000000997 não é válido.
# O CPF 00000000998 não é válido.
# O CPF 00000000999 não é válido.
# O CPF 00000001000 não é válido.
# O CPF 00000001001 não é válido.
# O CPF 00000001002 não é válido.
# O CPF 00000001003 não é válido.
# O CPF 00000001004 não é válido.
# O CPF 00000001005 não é válido.
# O CPF 00000001006 não é válido.
# O CPF 00000001007 não é válido.
# O CPF 00000001008 não é válido.
# O CPF 00000001009 não é válido.
# O CPF 00000001010 não é válido.
# O CPF 00000001011 não é válido.
# O CPF 00000001012 não é válido.
# O CPF 00000001013 não é válido.
# O CPF 00000001014 não é válido.
# O CPF 00000001015 não é válido.
# O CPF 00000001016 não é válido.
# O CPF 00000001017 não é válido.
# O CPF 00000001018 não é válido.
# O CPF 00000001019 não é válido.
# O CPF 00000001020 não é válido.
# O CPF 00000001021 não é válido.
# O CPF 00000001022 não é válido.
# O CPF 00000001023 não é válido.
# O CPF 00000001024 não é válido.
# O CPF 00000001025 não é válido.
# O CPF 00000001026 não é válido.
# O CPF 00000001027 não é válido.
# O CPF 00000001028 não é válido.
# O CPF 00000001029 não é válido.
# O CPF 00000001030 não é válido.
# O CPF 00000001031 não é válido.
# O CPF 00000001032 não é válido.
# O CPF 00000001033 não é válido.
# O CPF 00000001034 não é válido.
# O CPF 00000001035 não é válido.
# O CPF 00000001036 não é válido.
# O CPF 00000001037 não é válido.
# O CPF 00000001038 não é válido.
# O CPF 00000001039 não é válido.
# O CPF 00000001040 não é válido.
# O CPF 00000001041 não é válido.
# O CPF 00000001042 não é válido.
# O CPF 00000001043 não é válido.
# O CPF 00000001044 não é válido.
# O CPF 00000001045 não é válido.
# O CPF 00000001046 não é válido.
# O CPF 00000001047 não é válido.
# O CPF 00000001048 não é válido.
# O CPF 00000001049 não é válido.
# O CPF 00000001050 não é válido.
# O CPF 00000001051 não é válido.
# O CPF 00000001052 não é válido.
# O CPF 00000001053 não é válido.
# O CPF 00000001054 não é válido.
# O CPF 00000001055 não é válido.
# O CPF 00000001056 não é válido.
# O CPF 00000001057 não é válido.
# O CPF 00000001058 não é válido.
# O CPF 00000001059 não é válido.
# O CPF 00000001060 não é válido.
# O CPF 00000001061 não é válido.
# O CPF 00000001062 não é válido.
# O CPF 00000001063 não é válido.
# O CPF 00000001064 não é válido.
# O CPF 00000001065 não é válido.
# O CPF 00000001066 não é válido.
# O CPF 00000001067 não é válido.
# O CPF 00000001068 não é válido.
# O CPF 00000001069 não é válido.
# O CPF 00000001070 não é válido.
# O CPF 00000001071 não é válido.
# O CPF 00000001072 não é válido.
# O CPF 00000001073 não é válido.
# O CPF 00000001074 não é válido.
# O CPF 00000001075 não é válido.
# O CPF 00000001076 não é válido.
# O CPF 00000001077 não é válido.
# O CPF 00000001078 não é válido.
# O CPF 00000001079 não é válido.
# O CPF 00000001080 não é válido.
# O CPF 00000001081 não é válido.
# O CPF 00000001082 é válido.
# O CPF 00000001083 não é válido.
# O CPF 00000001084 não é válido.
# O CPF 00000001085 não é válido.
# O CPF 00000001086 não é válido.
# O CPF 00000001087 não é válido.
# O CPF 00000001088 não é válido.
# O CPF 00000001089 não é válido.
# O CPF 00000001090 não é válido.
# O CPF 00000001091 não é válido.
# O CPF 00000001092 não é válido.
# O CPF 00000001093 não é válido.
# O CPF 00000001094 não é válido.
# O CPF 00000001095 não é válido.
# O CPF 00000001096 não é válido.
# O CPF 00000001097 não é válido.
# O CPF 00000001098 não é válido.
# O CPF 00000001099 não é válido.
# O CPF 00000001100 não é válido.
# O CPF 00000001101 não é válido.
# O CPF 00000001102 não é válido.
# O CPF 00000001103 não é válido.
# O CPF 00000001104 não é válido.
# O CPF 00000001105 não é válido.
# O CPF 00000001106 não é válido.
# O CPF 00000001107 não é válido.
# O CPF 00000001108 não é válido.
# O CPF 00000001109 não é válido.
# O CPF 00000001110 não é válido.
# O CPF 00000001111 não é válido.
# O CPF 00000001112 não é válido.
# O CPF 00000001113 não é válido.
# O CPF 00000001114 não é válido.
# O CPF 00000001115 não é válido.
# O CPF 00000001116 não é válido.
# O CPF 00000001117 não é válido.
# O CPF 00000001118 não é válido.
# O CPF 00000001119 não é válido.
# O CPF 00000001120 não é válido.
# O CPF 00000001121 não é válido.
# O CPF 00000001122 não é válido.
# O CPF 00000001123 não é válido.
# O CPF 00000001124 não é válido.
# O CPF 00000001125 não é válido.
# O CPF 00000001126 não é válido.
# O CPF 00000001127 não é válido.
# O CPF 00000001128 não é válido.
# O CPF 00000001129 não é válido.
# O CPF 00000001130 não é válido.
# O CPF 00000001131 não é válido.
# O CPF 00000001132 não é válido.
# O CPF 00000001133 não é válido.
# O CPF 00000001134 não é válido.
# O CPF 00000001135 não é válido.
# O CPF 00000001136 não é válido.
# O CPF 00000001137 não é válido.
# O CPF 00000001138 não é válido.
# O CPF 00000001139 não é válido.
# O CPF 00000001140 não é válido.
# O CPF 00000001141 não é válido.
# O CPF 00000001142 não é válido.
# O CPF 00000001143 não é válido.
# O CPF 00000001144 não é válido.
# O CPF 00000001145 não é válido.
# O CPF 00000001146 não é válido.
# O CPF 00000001147 não é válido.
# O CPF 00000001148 não é válido.
# O CPF 00000001149 não é válido.
# O CPF 00000001150 não é válido.
# O CPF 00000001151 não é válido.
# O CPF 00000001152 não é válido.
# O CPF 00000001153 não é válido.
# O CPF 00000001154 não é válido.
# O CPF 00000001155 não é válido.
# O CPF 00000001156 não é válido.
# O CPF 00000001157 não é válido.
# O CPF 00000001158 não é válido.
# O CPF 00000001159 não é válido.
# O CPF 00000001160 não é válido.
# O CPF 00000001161 não é válido.
# O CPF 00000001162 não é válido.
# O CPF 00000001163 é válido.
# O CPF 00000001164 não é válido.
# O CPF 00000001165 não é válido.
# O CPF 00000001166 não é válido.
# O CPF 00000001167 não é válido.
# O CPF 00000001168 não é válido.
# O CPF 00000001169 não é válido.
# O CPF 00000001170 não é válido.
# O CPF 00000001171 não é válido.
# O CPF 00000001172 não é válido.
# O CPF 00000001173 não é válido.
# O CPF 00000001174 não é válido.
# O CPF 00000001175 não é válido.
# O CPF 00000001176 não é válido.
# O CPF 00000001177 não é válido.
# O CPF 00000001178 não é válido.
# O CPF 00000001179 não é válido.
# O CPF 00000001180 não é válido.
# O CPF 00000001181 não é válido.
# O CPF 00000001182 não é válido.
# O CPF 00000001183 não é válido.
# O CPF 00000001184 não é válido.
# O CPF 00000001185 não é válido.
# O CPF 00000001186 não é válido.
# O CPF 00000001187 não é válido.
# O CPF 00000001188 não é válido.
# O CPF 00000001189 não é válido.
# O CPF 00000001190 não é válido.
# O CPF 00000001191 não é válido.
# O CPF 00000001192 não é válido.
# O CPF 00000001193 não é válido.
# O CPF 00000001194 não é válido.
# O CPF 00000001195 não é válido.
# O CPF 00000001196 não é válido.
# O CPF 00000001197 não é válido.
# O CPF 00000001198 não é válido.
# O CPF 00000001199 não é válido.
# O CPF 00000001200 não é válido.
# O CPF 00000001201 não é válido.
# O CPF 00000001202 não é válido.
# O CPF 00000001203 não é válido.
# O CPF 00000001204 não é válido.
# O CPF 00000001205 não é válido.
# O CPF 00000001206 não é válido.
# O CPF 00000001207 não é válido.
# O CPF 00000001208 não é válido.
# O CPF 00000001209 não é válido.
# O CPF 00000001210 não é válido.
# O CPF 00000001211 não é válido.
# O CPF 00000001212 não é válido.
# O CPF 00000001213 não é válido.
# O CPF 00000001214 não é válido.
# O CPF 00000001215 não é válido.
# O CPF 00000001216 não é válido.
# O CPF 00000001217 não é válido.
# O CPF 00000001218 não é válido.
# O CPF 00000001219 não é válido.
# O CPF 00000001220 não é válido.
# O CPF 00000001221 não é válido.
# O CPF 00000001222 não é válido.
# O CPF 00000001223 não é válido.
# O CPF 00000001224 não é válido.
# O CPF 00000001225 não é válido.
# O CPF 00000001226 não é válido.
# O CPF 00000001227 não é válido.
# O CPF 00000001228 não é válido.
# O CPF 00000001229 não é válido.
# O CPF 00000001230 não é válido.
# O CPF 00000001231 não é válido.
# O CPF 00000001232 não é válido.
# O CPF 00000001233 não é válido.
# O CPF 00000001234 não é válido.
# O CPF 00000001235 não é válido.
# O CPF 00000001236 não é válido.
# O CPF 00000001237 não é válido.
# O CPF 00000001238 não é válido.
# O CPF 00000001239 não é válido.
# O CPF 00000001240 não é válido.
# O CPF 00000001241 não é válido.
# O CPF 00000001242 não é válido.
# O CPF 00000001243 não é válido.
# O CPF 00000001244 é válido.
# O CPF 00000001245 não é válido.
# O CPF 00000001246 não é válido.
# O CPF 00000001247 não é válido.
# O CPF 00000001248 não é válido.
# O CPF 00000001249 não é válido.
# O CPF 00000001250 não é válido.
# O CPF 00000001251 não é válido.
# O CPF 00000001252 não é válido.
# O CPF 00000001253 não é válido.
# O CPF 00000001254 não é válido.
# O CPF 00000001255 não é válido.
# O CPF 00000001256 não é válido.
# O CPF 00000001257 não é válido.
# O CPF 00000001258 não é válido.
# O CPF 00000001259 não é válido.
# O CPF 00000001260 não é válido.
# O CPF 00000001261 não é válido.
# O CPF 00000001262 não é válido.
# O CPF 00000001263 não é válido.
# O CPF 00000001264 não é válido.
# O CPF 00000001265 não é válido.
# O CPF 00000001266 não é válido.
# O CPF 00000001267 não é válido.
# O CPF 00000001268 não é válido.
# O CPF 00000001269 não é válido.
# O CPF 00000001270 não é válido.
# O CPF 00000001271 não é válido.
# O CPF 00000001272 não é válido.
# O CPF 00000001273 não é válido.
# O CPF 00000001274 não é válido.
# O CPF 00000001275 não é válido.
# O CPF 00000001276 não é válido.
# O CPF 00000001277 não é válido.
# O CPF 00000001278 não é válido.
# O CPF 00000001279 não é válido.
# O CPF 00000001280 não é válido.
# O CPF 00000001281 não é válido.
# O CPF 00000001282 não é válido.
# O CPF 00000001283 não é válido.
# O CPF 00000001284 não é válido.
# O CPF 00000001285 não é válido.
# O CPF 00000001286 não é válido.
# O CPF 00000001287 não é válido.
# O CPF 00000001288 não é válido.
# O CPF 00000001289 não é válido.
# O CPF 00000001290 não é válido.
# O CPF 00000001291 não é válido.
# O CPF 00000001292 não é válido.
# O CPF 00000001293 não é válido.
# O CPF 00000001294 não é válido.
# O CPF 00000001295 não é válido.
# O CPF 00000001296 não é válido.
# O CPF 00000001297 não é válido.
# O CPF 00000001298 não é válido.
# O CPF 00000001299 não é válido.
# O CPF 00000001300 não é válido.
# O CPF 00000001301 não é válido.
# O CPF 00000001302 não é válido.
# O CPF 00000001303 não é válido.
# O CPF 00000001304 não é válido.
# O CPF 00000001305 não é válido.
# O CPF 00000001306 não é válido.
# O CPF 00000001307 não é válido.
# O CPF 00000001308 não é válido.
# O CPF 00000001309 não é válido.
# O CPF 00000001310 não é válido.
# O CPF 00000001311 não é válido.
# O CPF 00000001312 não é válido.
# O CPF 00000001313 não é válido.
# O CPF 00000001314 não é válido.
# O CPF 00000001315 não é válido.
# O CPF 00000001316 não é válido.
# O CPF 00000001317 não é válido.
# O CPF 00000001318 não é válido.
# O CPF 00000001319 não é válido.
# O CPF 00000001320 não é válido.
# O CPF 00000001321 não é válido.
# O CPF 00000001322 não é válido.
# O CPF 00000001323 não é válido.
# O CPF 00000001324 não é válido.
# O CPF 00000001325 é válido.
# O CPF 00000001326 não é válido.
# O CPF 00000001327 não é válido.
# O CPF 00000001328 não é válido.
# O CPF 00000001329 não é válido.
# O CPF 00000001330 não é válido.
# O CPF 00000001331 não é válido.
# O CPF 00000001332 não é válido.
# O CPF 00000001333 não é válido.
# O CPF 00000001334 não é válido.
# O CPF 00000001335 não é válido.
# O CPF 00000001336 não é válido.
# O CPF 00000001337 não é válido.
# O CPF 00000001338 não é válido.
# O CPF 00000001339 não é válido.
# O CPF 00000001340 não é válido.
# O CPF 00000001341 não é válido.
# O CPF 00000001342 não é válido.
# O CPF 00000001343 não é válido.
# O CPF 00000001344 não é válido.
# O CPF 00000001345 não é válido.
# O CPF 00000001346 não é válido.
# O CPF 00000001347 não é válido.
# O CPF 00000001348 não é válido.
# O CPF 00000001349 não é válido.
# O CPF 00000001350 não é válido.
# O CPF 00000001351 não é válido.
# O CPF 00000001352 não é válido.
# O CPF 00000001353 não é válido.
# O CPF 00000001354 não é válido.
# O CPF 00000001355 não é válido.
# O CPF 00000001356 não é válido.
# O CPF 00000001357 não é válido.
# O CPF 00000001358 não é válido.
# O CPF 00000001359 não é válido.
# O CPF 00000001360 não é válido.
# O CPF 00000001361 não é válido.
# O CPF 00000001362 não é válido.
# O CPF 00000001363 não é válido.
# O CPF 00000001364 não é válido.
# O CPF 00000001365 não é válido.
# O CPF 00000001366 não é válido.
# O CPF 00000001367 não é válido.
# O CPF 00000001368 não é válido.
# O CPF 00000001369 não é válido.
# O CPF 00000001370 não é válido.
# O CPF 00000001371 não é válido.
# O CPF 00000001372 não é válido.
# O CPF 00000001373 não é válido.
# O CPF 00000001374 não é válido.
# O CPF 00000001375 não é válido.
# O CPF 00000001376 não é válido.
# O CPF 00000001377 não é válido.
# O CPF 00000001378 não é válido.
# O CPF 00000001379 não é válido.
# O CPF 00000001380 não é válido.
# O CPF 00000001381 não é válido.
# O CPF 00000001382 não é válido.
# O CPF 00000001383 não é válido.
# O CPF 00000001384 não é válido.
# O CPF 00000001385 não é válido.
# O CPF 00000001386 não é válido.
# O CPF 00000001387 não é válido.
# O CPF 00000001388 não é válido.
# O CPF 00000001389 não é válido.
# O CPF 00000001390 não é válido.
# O CPF 00000001391 não é válido.
# O CPF 00000001392 não é válido.
# O CPF 00000001393 não é válido.
# O CPF 00000001394 não é válido.
# O CPF 00000001395 não é válido.
# O CPF 00000001396 não é válido.
# O CPF 00000001397 não é válido.
# O CPF 00000001398 não é válido.
# O CPF 00000001399 não é válido.
# O CPF 00000001400 não é válido.
# O CPF 00000001401 não é válido.
# O CPF 00000001402 não é válido.
# O CPF 00000001403 não é válido.
# O CPF 00000001404 não é válido.
# O CPF 00000001405 não é válido.
# O CPF 00000001406 é válido.
# O CPF 00000001407 não é válido.
# O CPF 00000001408 não é válido.
# O CPF 00000001409 não é válido.
# O CPF 00000001410 não é válido.
# O CPF 00000001411 não é válido.
# O CPF 00000001412 não é válido.
# O CPF 00000001413 não é válido.
# O CPF 00000001414 não é válido.
# O CPF 00000001415 não é válido.
# O CPF 00000001416 não é válido.
# O CPF 00000001417 não é válido.
# O CPF 00000001418 não é válido.
# O CPF 00000001419 não é válido.
# O CPF 00000001420 não é válido.
# O CPF 00000001421 não é válido.
# O CPF 00000001422 não é válido.
# O CPF 00000001423 não é válido.
# O CPF 00000001424 não é válido.
# O CPF 00000001425 não é válido.
# O CPF 00000001426 não é válido.
# O CPF 00000001427 não é válido.
# O CPF 00000001428 não é válido.
# O CPF 00000001429 não é válido.
# O CPF 00000001430 não é válido.
# O CPF 00000001431 não é válido.
# O CPF 00000001432 não é válido.
# O CPF 00000001433 não é válido.
# O CPF 00000001434 não é válido.
# O CPF 00000001435 não é válido.
# O CPF 00000001436 não é válido.
# O CPF 00000001437 não é válido.
# O CPF 00000001438 não é válido.
# O CPF 00000001439 não é válido.
# O CPF 00000001440 não é válido.
# O CPF 00000001441 não é válido.
# O CPF 00000001442 não é válido.
# O CPF 00000001443 não é válido.
# O CPF 00000001444 não é válido.
# O CPF 00000001445 não é válido.
# O CPF 00000001446 não é válido.
# O CPF 00000001447 não é válido.
# O CPF 00000001448 não é válido.
# O CPF 00000001449 não é válido.
# O CPF 00000001450 não é válido.
# O CPF 00000001451 não é válido.
# O CPF 00000001452 não é válido.
# O CPF 00000001453 não é válido.
# O CPF 00000001454 não é válido.
# O CPF 00000001455 não é válido.
# O CPF 00000001456 não é válido.
# O CPF 00000001457 não é válido.
# O CPF 00000001458 não é válido.
# O CPF 00000001459 não é válido.
# O CPF 00000001460 não é válido.
# O CPF 00000001461 não é válido.
# O CPF 00000001462 não é válido.
# O CPF 00000001463 não é válido.
# O CPF 00000001464 não é válido.
# O CPF 00000001465 não é válido.
# O CPF 00000001466 não é válido.
# O CPF 00000001467 não é válido.
# O CPF 00000001468 não é válido.
# O CPF 00000001469 não é válido.
# O CPF 00000001470 não é válido.
# O CPF 00000001471 não é válido.
# O CPF 00000001472 não é válido.
# O CPF 00000001473 não é válido.
# O CPF 00000001474 não é válido.
# O CPF 00000001475 não é válido.
# O CPF 00000001476 não é válido.
# O CPF 00000001477 não é válido.
# O CPF 00000001478 não é válido.
# O CPF 00000001479 não é válido.
# O CPF 00000001480 não é válido.
# O CPF 00000001481 não é válido.
# O CPF 00000001482 não é válido.
# O CPF 00000001483 não é válido.
# O CPF 00000001484 não é válido.
# O CPF 00000001485 não é válido.
# O CPF 00000001486 não é válido.
# O CPF 00000001487 não é válido.
# O CPF 00000001488 não é válido.
# O CPF 00000001489 não é válido.
# O CPF 00000001490 não é válido.
# O CPF 00000001491 não é válido.
# O CPF 00000001492 não é válido.
# O CPF 00000001493 não é válido.
# O CPF 00000001494 não é válido.
# O CPF 00000001495 não é válido.
# O CPF 00000001496 não é válido.
# O CPF 00000001497 não é válido.
# O CPF 00000001498 não é válido.
# O CPF 00000001499 não é válido.
# O CPF 00000001500 não é válido.
# ...
# O CPF 00000009500 não é válido.
# O CPF 00000009501 não é válido.
# O CPF 00000009502 não é válido.
# O CPF 00000009503 não é válido.
# O CPF 00000009504 não é válido.
# O CPF 00000009505 não é válido.
# O CPF 00000009506 não é válido.
# O CPF 00000009507 não é válido.
# O CPF 00000009508 não é válido.
# O CPF 00000009509 não é válido.
# O CPF 00000009510 não é válido.
# O CPF 00000009511 não é válido.
# O CPF 00000009512 não é válido.
# O CPF 00000009513 não é válido.
# O CPF 00000009514 não é válido.
# O CPF 00000009515 não é válido.
# O CPF 00000009516 não é válido.
# O CPF 00000009517 não é válido.
# O CPF 00000009518 não é válido.
# O CPF 00000009519 não é válido.
# O CPF 00000009520 não é válido.
# O CPF 00000009521 não é válido.
# O CPF 00000009522 não é válido.
# O CPF 00000009523 não é válido.
# O CPF 00000009524 não é válido.
# O CPF 00000009525 não é válido.
# O CPF 00000009526 não é válido.
# O CPF 00000009527 não é válido.
# O CPF 00000009528 não é válido.
# O CPF 00000009529 não é válido.
# O CPF 00000009530 não é válido.
# O CPF 00000009531 não é válido.
# O CPF 00000009532 não é válido.
# O CPF 00000009533 não é válido.
# O CPF 00000009534 não é válido.
# O CPF 00000009535 não é válido.
# O CPF 00000009536 não é válido.
# O CPF 00000009537 não é válido.
# O CPF 00000009538 não é válido.
# O CPF 00000009539 não é válido.
# O CPF 00000009540 não é válido.
# O CPF 00000009541 não é válido.
# O CPF 00000009542 não é válido.
# O CPF 00000009543 não é válido.
# O CPF 00000009544 não é válido.
# O CPF 00000009545 não é válido.
# O CPF 00000009546 não é válido.
# O CPF 00000009547 não é válido.
# O CPF 00000009548 não é válido.
# O CPF 00000009549 não é válido.
# O CPF 00000009550 não é válido.
# O CPF 00000009551 não é válido.
# O CPF 00000009552 não é válido.
# O CPF 00000009553 não é válido.
# O CPF 00000009554 não é válido.
# O CPF 00000009555 não é válido.
# O CPF 00000009556 não é válido.
# O CPF 00000009557 não é válido.
# O CPF 00000009558 não é válido.
# O CPF 00000009559 não é válido.
# O CPF 00000009560 não é válido.
# O CPF 00000009561 não é válido.
# O CPF 00000009562 não é válido.
# O CPF 00000009563 não é válido.
# O CPF 00000009564 não é válido.
# O CPF 00000009565 não é válido.
# O CPF 00000009566 não é válido.
# O CPF 00000009567 não é válido.
# O CPF 00000009568 não é válido.
# O CPF 00000009569 não é válido.
# O CPF 00000009570 não é válido.
# O CPF 00000009571 é válido.
# O CPF 00000009572 não é válido.
# O CPF 00000009573 não é válido.
# O CPF 00000009574 não é válido.
# O CPF 00000009575 não é válido.
# O CPF 00000009576 não é válido.
# O CPF 00000009577 não é válido.
# O CPF 00000009578 não é válido.
# O CPF 00000009579 não é válido.
# O CPF 00000009580 não é válido.
# O CPF 00000009581 não é válido.
# O CPF 00000009582 não é válido.
# O CPF 00000009583 não é válido.
# O CPF 00000009584 não é válido.
# O CPF 00000009585 não é válido.
# O CPF 00000009586 não é válido.
# O CPF 00000009587 não é válido.
# O CPF 00000009588 não é válido.
# O CPF 00000009589 não é válido.
# O CPF 00000009590 não é válido.
# O CPF 00000009591 não é válido.
# O CPF 00000009592 não é válido.
# O CPF 00000009593 não é válido.
# O CPF 00000009594 não é válido.
# O CPF 00000009595 não é válido.
# O CPF 00000009596 não é válido.
# O CPF 00000009597 não é válido.
# O CPF 00000009598 não é válido.
# O CPF 00000009599 não é válido.
# O CPF 00000009600 não é válido.
# O CPF 00000009601 não é válido.
# O CPF 00000009602 não é válido.
# O CPF 00000009603 não é válido.
# O CPF 00000009604 não é válido.
# O CPF 00000009605 não é válido.
# O CPF 00000009606 não é válido.
# O CPF 00000009607 não é válido.
# O CPF 00000009608 não é válido.
# O CPF 00000009609 não é válido.
# O CPF 00000009610 não é válido.
# O CPF 00000009611 não é válido.
# O CPF 00000009612 não é válido.
# O CPF 00000009613 não é válido.
# O CPF 00000009614 não é válido.
# O CPF 00000009615 não é válido.
# O CPF 00000009616 não é válido.
# O CPF 00000009617 não é válido.
# O CPF 00000009618 não é válido.
# O CPF 00000009619 não é válido.
# O CPF 00000009620 não é válido.
# O CPF 00000009621 não é válido.
# O CPF 00000009622 não é válido.
# O CPF 00000009623 não é válido.
# O CPF 00000009624 não é válido.
# O CPF 00000009625 não é válido.
# O CPF 00000009626 não é válido.
# O CPF 00000009627 não é válido.
# O CPF 00000009628 não é válido.
# O CPF 00000009629 não é válido.
# O CPF 00000009630 não é válido.
# O CPF 00000009631 não é válido.
# O CPF 00000009632 não é válido.
# O CPF 00000009633 não é válido.
# O CPF 00000009634 não é válido.
# O CPF 00000009635 não é válido.
# O CPF 00000009636 não é válido.
# O CPF 00000009637 não é válido.
# O CPF 00000009638 não é válido.
# O CPF 00000009639 não é válido.
# O CPF 00000009640 não é válido.
# O CPF 00000009641 não é válido.
# O CPF 00000009642 não é válido.
# O CPF 00000009643 não é válido.
# O CPF 00000009644 não é válido.
# O CPF 00000009645 não é válido.
# O CPF 00000009646 não é válido.
# O CPF 00000009647 não é válido.
# O CPF 00000009648 não é válido.
# O CPF 00000009649 não é válido.
# O CPF 00000009650 não é válido.
# O CPF 00000009651 não é válido.
# O CPF 00000009652 é válido.
# O CPF 00000009653 não é válido.
# O CPF 00000009654 não é válido.
# O CPF 00000009655 não é válido.
# O CPF 00000009656 não é válido.
# O CPF 00000009657 não é válido.
# O CPF 00000009658 não é válido.
# O CPF 00000009659 não é válido.
# O CPF 00000009660 não é válido.
# O CPF 00000009661 não é válido.
# O CPF 00000009662 não é válido.
# O CPF 00000009663 não é válido.
# O CPF 00000009664 não é válido.
# O CPF 00000009665 não é válido.
# O CPF 00000009666 não é válido.
# O CPF 00000009667 não é válido.
# O CPF 00000009668 não é válido.
# O CPF 00000009669 não é válido.
# O CPF 00000009670 não é válido.
# O CPF 00000009671 não é válido.
# O CPF 00000009672 não é válido.
# O CPF 00000009673 não é válido.
# O CPF 00000009674 não é válido.
# O CPF 00000009675 não é válido.
# O CPF 00000009676 não é válido.
# O CPF 00000009677 não é válido.
# O CPF 00000009678 não é válido.
# O CPF 00000009679 não é válido.
# O CPF 00000009680 não é válido.
# O CPF 00000009681 não é válido.
# O CPF 00000009682 não é válido.
# O CPF 00000009683 não é válido.
# O CPF 00000009684 não é válido.
# O CPF 00000009685 não é válido.
# O CPF 00000009686 não é válido.
# O CPF 00000009687 não é válido.
# O CPF 00000009688 não é válido.
# O CPF 00000009689 não é válido.
# O CPF 00000009690 não é válido.
# O CPF 00000009691 não é válido.
# O CPF 00000009692 não é válido.
# O CPF 00000009693 não é válido.
# O CPF 00000009694 não é válido.
# O CPF 00000009695 não é válido.
# O CPF 00000009696 não é válido.
# O CPF 00000009697 não é válido.
# O CPF 00000009698 não é válido.
# O CPF 00000009699 não é válido.
# O CPF 00000009700 não é válido.
# O CPF 00000009701 não é válido.
# O CPF 00000009702 não é válido.
# O CPF 00000009703 não é válido.
# O CPF 00000009704 não é válido.
# O CPF 00000009705 não é válido.
# O CPF 00000009706 não é válido.
# O CPF 00000009707 não é válido.
# O CPF 00000009708 não é válido.
# O CPF 00000009709 não é válido.
# O CPF 00000009710 não é válido.
# O CPF 00000009711 não é válido.
# O CPF 00000009712 não é válido.
# O CPF 00000009713 não é válido.
# O CPF 00000009714 não é válido.
# O CPF 00000009715 não é válido.
# O CPF 00000009716 não é válido.
# O CPF 00000009717 não é válido.
# O CPF 00000009718 não é válido.
# O CPF 00000009719 não é válido.
# O CPF 00000009720 não é válido.
# O CPF 00000009721 não é válido.
# O CPF 00000009722 não é válido.
# O CPF 00000009723 não é válido.
# O CPF 00000009724 não é válido.
# O CPF 00000009725 não é válido.
# O CPF 00000009726 não é válido.
# O CPF 00000009727 não é válido.
# O CPF 00000009728 não é válido.
# O CPF 00000009729 não é válido.
# O CPF 00000009730 não é válido.
# O CPF 00000009731 não é válido.
# O CPF 00000009732 não é válido.
# O CPF 00000009733 é válido.
# O CPF 00000009734 não é válido.
# O CPF 00000009735 não é válido.
# O CPF 00000009736 não é válido.
# O CPF 00000009737 não é válido.
# O CPF 00000009738 não é válido.
# O CPF 00000009739 não é válido.
# O CPF 00000009740 não é válido.
# O CPF 00000009741 não é válido.
# O CPF 00000009742 não é válido.
# O CPF 00000009743 não é válido.
# O CPF 00000009744 não é válido.
# O CPF 00000009745 não é válido.
# O CPF 00000009746 não é válido.
# O CPF 00000009747 não é válido.
# O CPF 00000009748 não é válido.
# O CPF 00000009749 não é válido.
# O CPF 00000009750 não é válido.
# O CPF 00000009751 não é válido.
# O CPF 00000009752 não é válido.
# O CPF 00000009753 não é válido.
# O CPF 00000009754 não é válido.
# O CPF 00000009755 não é válido.
# O CPF 00000009756 não é válido.
# O CPF 00000009757 não é válido.
# O CPF 00000009758 não é válido.
# O CPF 00000009759 não é válido.
# O CPF 00000009760 não é válido.
# O CPF 00000009761 não é válido.
# O CPF 00000009762 não é válido.
# O CPF 00000009763 não é válido.
# O CPF 00000009764 não é válido.
# O CPF 00000009765 não é válido.
# O CPF 00000009766 não é válido.
# O CPF 00000009767 não é válido.
# O CPF 00000009768 não é válido.
# O CPF 00000009769 não é válido.
# O CPF 00000009770 não é válido.
# O CPF 00000009771 não é válido.
# O CPF 00000009772 não é válido.
# O CPF 00000009773 não é válido.
# O CPF 00000009774 não é válido.
# O CPF 00000009775 não é válido.
# O CPF 00000009776 não é válido.
# O CPF 00000009777 não é válido.
# O CPF 00000009778 não é válido.
# O CPF 00000009779 não é válido.
# O CPF 00000009780 não é válido.
# O CPF 00000009781 não é válido.
# O CPF 00000009782 não é válido.
# O CPF 00000009783 não é válido.
# O CPF 00000009784 não é válido.
# O CPF 00000009785 não é válido.
# O CPF 00000009786 não é válido.
# O CPF 00000009787 não é válido.
# O CPF 00000009788 não é válido.
# O CPF 00000009789 não é válido.
# O CPF 00000009790 não é válido.
# O CPF 00000009791 não é válido.
# O CPF 00000009792 não é válido.
# O CPF 00000009793 não é válido.
# O CPF 00000009794 não é válido.
# O CPF 00000009795 não é válido.
# O CPF 00000009796 não é válido.
# O CPF 00000009797 não é válido.
# O CPF 00000009798 não é válido.
# O CPF 00000009799 não é válido.
# O CPF 00000009800 não é válido.
# O CPF 00000009801 não é válido.
# O CPF 00000009802 não é válido.
# O CPF 00000009803 não é válido.
# O CPF 00000009804 não é válido.
# O CPF 00000009805 não é válido.
# O CPF 00000009806 não é válido.
# O CPF 00000009807 não é válido.
# O CPF 00000009808 não é válido.
# O CPF 00000009809 não é válido.
# O CPF 00000009810 não é válido.
# O CPF 00000009811 não é válido.
# O CPF 00000009812 não é válido.
# O CPF 00000009813 não é válido.
# O CPF 00000009814 é válido.
# O CPF 00000009815 não é válido.
# O CPF 00000009816 não é válido.
# O CPF 00000009817 não é válido.
# O CPF 00000009818 não é válido.
# O CPF 00000009819 não é válido.
# O CPF 00000009820 não é válido.
# O CPF 00000009821 não é válido.
# O CPF 00000009822 não é válido.
# O CPF 00000009823 não é válido.
# O CPF 00000009824 não é válido.
# O CPF 00000009825 não é válido.
# O CPF 00000009826 não é válido.
# O CPF 00000009827 não é válido.
# O CPF 00000009828 não é válido.
# O CPF 00000009829 não é válido.
# O CPF 00000009830 não é válido.
# O CPF 00000009831 não é válido.
# O CPF 00000009832 não é válido.
# O CPF 00000009833 não é válido.
# O CPF 00000009834 não é válido.
# O CPF 00000009835 não é válido.
# O CPF 00000009836 não é válido.
# O CPF 00000009837 não é válido.
# O CPF 00000009838 não é válido.
# O CPF 00000009839 não é válido.
# O CPF 00000009840 não é válido.
# O CPF 00000009841 não é válido.
# O CPF 00000009842 não é válido.
# O CPF 00000009843 não é válido.
# O CPF 00000009844 não é válido.
# O CPF 00000009845 não é válido.
# O CPF 00000009846 não é válido.
# O CPF 00000009847 não é válido.
# O CPF 00000009848 não é válido.
# O CPF 00000009849 não é válido.
# O CPF 00000009850 não é válido.
# O CPF 00000009851 não é válido.
# O CPF 00000009852 não é válido.
# O CPF 00000009853 não é válido.
# O CPF 00000009854 não é válido.
# O CPF 00000009855 não é válido.
# O CPF 00000009856 não é válido.
# O CPF 00000009857 não é válido.
# O CPF 00000009858 não é válido.
# O CPF 00000009859 não é válido.
# O CPF 00000009860 não é válido.
# O CPF 00000009861 não é válido.
# O CPF 00000009862 não é válido.
# O CPF 00000009863 não é válido.
# O CPF 00000009864 não é válido.
# O CPF 00000009865 não é válido.
# O CPF 00000009866 não é válido.
# O CPF 00000009867 não é válido.
# O CPF 00000009868 não é válido.
# O CPF 00000009869 não é válido.
# O CPF 00000009870 não é válido.
# O CPF 00000009871 não é válido.
# O CPF 00000009872 não é válido.
# O CPF 00000009873 não é válido.
# O CPF 00000009874 não é válido.
# O CPF 00000009875 não é válido.
# O CPF 00000009876 não é válido.
# O CPF 00000009877 não é válido.
# O CPF 00000009878 não é válido.
# O CPF 00000009879 não é válido.
# O CPF 00000009880 não é válido.
# O CPF 00000009881 não é válido.
# O CPF 00000009882 não é válido.
# O CPF 00000009883 não é válido.
# O CPF 00000009884 não é válido.
# O CPF 00000009885 não é válido.
# O CPF 00000009886 não é válido.
# O CPF 00000009887 não é válido.
# O CPF 00000009888 não é válido.
# O CPF 00000009889 não é válido.
# O CPF 00000009890 não é válido.
# O CPF 00000009891 não é válido.
# O CPF 00000009892 não é válido.
# O CPF 00000009893 não é válido.
# O CPF 00000009894 não é válido.
# O CPF 00000009895 não é válido.
# O CPF 00000009896 não é válido.
# O CPF 00000009897 não é válido.
# O CPF 00000009898 não é válido.
# O CPF 00000009899 não é válido.
# O CPF 00000009900 não é válido.
# O CPF 00000009901 não é válido.
# O CPF 00000009902 não é válido.
# O CPF 00000009903 não é válido.
# O CPF 00000009904 não é válido.
# O CPF 00000009905 não é válido.
# O CPF 00000009906 não é válido.
# O CPF 00000009907 não é válido.
# O CPF 00000009908 não é válido.
# O CPF 00000009909 não é válido.
# O CPF 00000009910 não é válido.
# O CPF 00000009911 não é válido.
# O CPF 00000009912 não é válido.
# O CPF 00000009913 não é válido.
# O CPF 00000009914 não é válido.
# O CPF 00000009915 não é válido.
# O CPF 00000009916 não é válido.
# O CPF 00000009917 não é válido.
# O CPF 00000009918 não é válido.
# O CPF 00000009919 não é válido.
# O CPF 00000009920 não é válido.
# O CPF 00000009921 não é válido.
# O CPF 00000009922 não é válido.
# O CPF 00000009923 não é válido.
# O CPF 00000009924 não é válido.
# O CPF 00000009925 não é válido.
# O CPF 00000009926 não é válido.
# O CPF 00000009927 não é válido.
# O CPF 00000009928 não é válido.
# O CPF 00000009929 não é válido.
# O CPF 00000009930 não é válido.
# O CPF 00000009931 não é válido.
# O CPF 00000009932 não é válido.
# O CPF 00000009933 não é válido.
# O CPF 00000009934 não é válido.
# O CPF 00000009935 não é válido.
# O CPF 00000009936 não é válido.
# O CPF 00000009937 não é válido.
# O CPF 00000009938 não é válido.
# O CPF 00000009939 não é válido.
# O CPF 00000009940 não é válido.
# O CPF 00000009941 não é válido.
# O CPF 00000009942 não é válido.
# O CPF 00000009943 não é válido.
# O CPF 00000009944 não é válido.
# O CPF 00000009945 não é válido.
# O CPF 00000009946 não é válido.
# O CPF 00000009947 não é válido.
# O CPF 00000009948 não é válido.
# O CPF 00000009949 não é válido.
# O CPF 00000009950 não é válido.
# O CPF 00000009951 não é válido.
# O CPF 00000009952 não é válido.
# O CPF 00000009953 não é válido.
# O CPF 00000009954 não é válido.
# O CPF 00000009955 não é válido.
# O CPF 00000009956 não é válido.
# O CPF 00000009957 não é válido.
# O CPF 00000009958 não é válido.
# O CPF 00000009959 não é válido.
# O CPF 00000009960 não é válido.
# O CPF 00000009961 não é válido.
# O CPF 00000009962 não é válido.
# O CPF 00000009963 não é válido.
# O CPF 00000009964 não é válido.
# O CPF 00000009965 não é válido.
# O CPF 00000009966 não é válido.
# O CPF 00000009967 não é válido.
# O CPF 00000009968 não é válido.
# O CPF 00000009969 não é válido.
# O CPF 00000009970 não é válido.
# O CPF 00000009971 não é válido.
# O CPF 00000009972 não é válido.
# O CPF 00000009973 não é válido.
# O CPF 00000009974 não é válido.
# O CPF 00000009975 não é válido.
# O CPF 00000009976 não é válido.
# O CPF 00000009977 não é válido.
# O CPF 00000009978 não é válido.
# O CPF 00000009979 não é válido.
# O CPF 00000009980 não é válido.
# O CPF 00000009981 não é válido.
# O CPF 00000009982 não é válido.
# O CPF 00000009983 não é válido.
# O CPF 00000009984 não é válido.
# O CPF 00000009985 não é válido.
# O CPF 00000009986 não é válido.
# O CPF 00000009987 não é válido.
# O CPF 00000009988 não é válido.
# O CPF 00000009989 não é válido.
# O CPF 00000009990 não é válido.
# O CPF 00000009991 não é válido.
# O CPF 00000009992 não é válido.
# O CPF 00000009993 não é válido.
# O CPF 00000009994 não é válido.
# O CPF 00000009995 não é válido.
# O CPF 00000009996 não é válido.
# O CPF 00000009997 não é válido.
# O CPF 00000009998 não é válido.
# O CPF 00000009999 não é válido.

# %%
tempo_validacao_cpf = end_time - start_time 
print("Tempo total funcao validacao_cpf:", end_time - start_time, "segundos")
# Out:
# Tempo total funcao validacao_cpf: 0.05499911308288574 segundos

# %%
import time
from tqdm import tqdm
start_time = time.time()
_ = [validar_cpf2(cpf) for cpf in cpfs]   
end_time = time.time()
# Out:
# O CPF 00000000000 não é válido.
# O CPF 00000000001 não é válido.
# O CPF 00000000002 não é válido.
# O CPF 00000000003 não é válido.
# O CPF 00000000004 não é válido.
# O CPF 00000000005 não é válido.
# O CPF 00000000006 não é válido.
# O CPF 00000000007 não é válido.
# O CPF 00000000008 não é válido.
# O CPF 00000000009 não é válido.
# O CPF 00000000010 não é válido.
# O CPF 00000000011 não é válido.
# O CPF 00000000012 não é válido.
# O CPF 00000000013 não é válido.
# O CPF 00000000014 não é válido.
# O CPF 00000000015 não é válido.
# O CPF 00000000016 não é válido.
# O CPF 00000000017 não é válido.
# O CPF 00000000018 não é válido.
# O CPF 00000000019 não é válido.
# O CPF 00000000020 não é válido.
# O CPF 00000000021 não é válido.
# O CPF 00000000022 não é válido.
# O CPF 00000000023 não é válido.
# O CPF 00000000024 não é válido.
# O CPF 00000000025 não é válido.
# O CPF 00000000026 não é válido.
# O CPF 00000000027 não é válido.
# O CPF 00000000028 não é válido.
# O CPF 00000000029 não é válido.
# O CPF 00000000030 não é válido.
# O CPF 00000000031 não é válido.
# O CPF 00000000032 não é válido.
# O CPF 00000000033 não é válido.
# O CPF 00000000034 não é válido.
# O CPF 00000000035 não é válido.
# O CPF 00000000036 não é válido.
# O CPF 00000000037 não é válido.
# O CPF 00000000038 não é válido.
# O CPF 00000000039 não é válido.
# O CPF 00000000040 não é válido.
# O CPF 00000000041 não é válido.
# O CPF 00000000042 não é válido.
# O CPF 00000000043 não é válido.
# O CPF 00000000044 não é válido.
# O CPF 00000000045 não é válido.
# O CPF 00000000046 não é válido.
# O CPF 00000000047 não é válido.
# O CPF 00000000048 não é válido.
# O CPF 00000000049 não é válido.
# O CPF 00000000050 não é válido.
# O CPF 00000000051 não é válido.
# O CPF 00000000052 não é válido.
# O CPF 00000000053 não é válido.
# O CPF 00000000054 não é válido.
# O CPF 00000000055 não é válido.
# O CPF 00000000056 não é válido.
# O CPF 00000000057 não é válido.
# O CPF 00000000058 não é válido.
# O CPF 00000000059 não é válido.
# O CPF 00000000060 não é válido.
# O CPF 00000000061 não é válido.
# O CPF 00000000062 não é válido.
# O CPF 00000000063 não é válido.
# O CPF 00000000064 não é válido.
# O CPF 00000000065 não é válido.
# O CPF 00000000066 não é válido.
# O CPF 00000000067 não é válido.
# O CPF 00000000068 não é válido.
# O CPF 00000000069 não é válido.
# O CPF 00000000070 não é válido.
# O CPF 00000000071 não é válido.
# O CPF 00000000072 não é válido.
# O CPF 00000000073 não é válido.
# O CPF 00000000074 não é válido.
# O CPF 00000000075 não é válido.
# O CPF 00000000076 não é válido.
# O CPF 00000000077 não é válido.
# O CPF 00000000078 não é válido.
# O CPF 00000000079 não é válido.
# O CPF 00000000080 não é válido.
# O CPF 00000000081 não é válido.
# O CPF 00000000082 não é válido.
# O CPF 00000000083 não é válido.
# O CPF 00000000084 não é válido.
# O CPF 00000000085 não é válido.
# O CPF 00000000086 não é válido.
# O CPF 00000000087 não é válido.
# O CPF 00000000088 não é válido.
# O CPF 00000000089 não é válido.
# O CPF 00000000090 não é válido.
# O CPF 00000000091 não é válido.
# O CPF 00000000092 não é válido.
# O CPF 00000000093 não é válido.
# O CPF 00000000094 não é válido.
# O CPF 00000000095 não é válido.
# O CPF 00000000096 não é válido.
# O CPF 00000000097 não é válido.
# O CPF 00000000098 não é válido.
# O CPF 00000000099 não é válido.
# O CPF 00000000100 não é válido.
# O CPF 00000000101 não é válido.
# O CPF 00000000102 não é válido.
# O CPF 00000000103 não é válido.
# O CPF 00000000104 não é válido.
# O CPF 00000000105 não é válido.
# O CPF 00000000106 não é válido.
# O CPF 00000000107 não é válido.
# O CPF 00000000108 não é válido.
# O CPF 00000000109 não é válido.
# O CPF 00000000110 não é válido.
# O CPF 00000000111 não é válido.
# O CPF 00000000112 não é válido.
# O CPF 00000000113 não é válido.
# O CPF 00000000114 não é válido.
# O CPF 00000000115 não é válido.
# O CPF 00000000116 não é válido.
# O CPF 00000000117 não é válido.
# O CPF 00000000118 não é válido.
# O CPF 00000000119 não é válido.
# O CPF 00000000120 não é válido.
# O CPF 00000000121 não é válido.
# O CPF 00000000122 não é válido.
# O CPF 00000000123 não é válido.
# O CPF 00000000124 não é válido.
# O CPF 00000000125 não é válido.
# O CPF 00000000126 não é válido.
# O CPF 00000000127 não é válido.
# O CPF 00000000128 não é válido.
# O CPF 00000000129 não é válido.
# O CPF 00000000130 não é válido.
# O CPF 00000000131 não é válido.
# O CPF 00000000132 não é válido.
# O CPF 00000000133 não é válido.
# O CPF 00000000134 não é válido.
# O CPF 00000000135 não é válido.
# O CPF 00000000136 não é válido.
# O CPF 00000000137 não é válido.
# O CPF 00000000138 não é válido.
# O CPF 00000000139 não é válido.
# O CPF 00000000140 não é válido.
# O CPF 00000000141 não é válido.
# O CPF 00000000142 não é válido.
# O CPF 00000000143 não é válido.
# O CPF 00000000144 não é válido.
# O CPF 00000000145 não é válido.
# O CPF 00000000146 não é válido.
# O CPF 00000000147 não é válido.
# O CPF 00000000148 não é válido.
# O CPF 00000000149 não é válido.
# O CPF 00000000150 não é válido.
# O CPF 00000000151 não é válido.
# O CPF 00000000152 não é válido.
# O CPF 00000000153 não é válido.
# O CPF 00000000154 não é válido.
# O CPF 00000000155 não é válido.
# O CPF 00000000156 não é válido.
# O CPF 00000000157 não é válido.
# O CPF 00000000158 não é válido.
# O CPF 00000000159 não é válido.
# O CPF 00000000160 não é válido.
# O CPF 00000000161 não é válido.
# O CPF 00000000162 não é válido.
# O CPF 00000000163 não é válido.
# O CPF 00000000164 não é válido.
# O CPF 00000000165 não é válido.
# O CPF 00000000166 não é válido.
# O CPF 00000000167 não é válido.
# O CPF 00000000168 não é válido.
# O CPF 00000000169 não é válido.
# O CPF 00000000170 não é válido.
# O CPF 00000000171 não é válido.
# O CPF 00000000172 não é válido.
# O CPF 00000000173 não é válido.
# O CPF 00000000174 não é válido.
# O CPF 00000000175 não é válido.
# O CPF 00000000176 não é válido.
# O CPF 00000000177 não é válido.
# O CPF 00000000178 não é válido.
# O CPF 00000000179 não é válido.
# O CPF 00000000180 não é válido.
# O CPF 00000000181 não é válido.
# O CPF 00000000182 não é válido.
# O CPF 00000000183 não é válido.
# O CPF 00000000184 não é válido.
# O CPF 00000000185 não é válido.
# O CPF 00000000186 não é válido.
# O CPF 00000000187 não é válido.
# O CPF 00000000188 não é válido.
# O CPF 00000000189 não é válido.
# O CPF 00000000190 não é válido.
# O CPF 00000000191 é válido.
# O CPF 00000000192 não é válido.
# O CPF 00000000193 não é válido.
# O CPF 00000000194 não é válido.
# O CPF 00000000195 não é válido.
# O CPF 00000000196 não é válido.
# O CPF 00000000197 não é válido.
# O CPF 00000000198 não é válido.
# O CPF 00000000199 não é válido.
# O CPF 00000000200 não é válido.
# O CPF 00000000201 não é válido.
# O CPF 00000000202 não é válido.
# O CPF 00000000203 não é válido.
# O CPF 00000000204 não é válido.
# O CPF 00000000205 não é válido.
# O CPF 00000000206 não é válido.
# O CPF 00000000207 não é válido.
# O CPF 00000000208 não é válido.
# O CPF 00000000209 não é válido.
# O CPF 00000000210 não é válido.
# O CPF 00000000211 não é válido.
# O CPF 00000000212 não é válido.
# O CPF 00000000213 não é válido.
# O CPF 00000000214 não é válido.
# O CPF 00000000215 não é válido.
# O CPF 00000000216 não é válido.
# O CPF 00000000217 não é válido.
# O CPF 00000000218 não é válido.
# O CPF 00000000219 não é válido.
# O CPF 00000000220 não é válido.
# O CPF 00000000221 não é válido.
# O CPF 00000000222 não é válido.
# O CPF 00000000223 não é válido.
# O CPF 00000000224 não é válido.
# O CPF 00000000225 não é válido.
# O CPF 00000000226 não é válido.
# O CPF 00000000227 não é válido.
# O CPF 00000000228 não é válido.
# O CPF 00000000229 não é válido.
# O CPF 00000000230 não é válido.
# O CPF 00000000231 não é válido.
# O CPF 00000000232 não é válido.
# O CPF 00000000233 não é válido.
# O CPF 00000000234 não é válido.
# O CPF 00000000235 não é válido.
# O CPF 00000000236 não é válido.
# O CPF 00000000237 não é válido.
# O CPF 00000000238 não é válido.
# O CPF 00000000239 não é válido.
# O CPF 00000000240 não é válido.
# O CPF 00000000241 não é válido.
# O CPF 00000000242 não é válido.
# O CPF 00000000243 não é válido.
# O CPF 00000000244 não é válido.
# O CPF 00000000245 não é válido.
# O CPF 00000000246 não é válido.
# O CPF 00000000247 não é válido.
# O CPF 00000000248 não é válido.
# O CPF 00000000249 não é válido.
# O CPF 00000000250 não é válido.
# O CPF 00000000251 não é válido.
# O CPF 00000000252 não é válido.
# O CPF 00000000253 não é válido.
# O CPF 00000000254 não é válido.
# O CPF 00000000255 não é válido.
# O CPF 00000000256 não é válido.
# O CPF 00000000257 não é válido.
# O CPF 00000000258 não é válido.
# O CPF 00000000259 não é válido.
# O CPF 00000000260 não é válido.
# O CPF 00000000261 não é válido.
# O CPF 00000000262 não é válido.
# O CPF 00000000263 não é válido.
# O CPF 00000000264 não é válido.
# O CPF 00000000265 não é válido.
# O CPF 00000000266 não é válido.
# O CPF 00000000267 não é válido.
# O CPF 00000000268 não é válido.
# O CPF 00000000269 não é válido.
# O CPF 00000000270 não é válido.
# O CPF 00000000271 não é válido.
# O CPF 00000000272 é válido.
# O CPF 00000000273 não é válido.
# O CPF 00000000274 não é válido.
# O CPF 00000000275 não é válido.
# O CPF 00000000276 não é válido.
# O CPF 00000000277 não é válido.
# O CPF 00000000278 não é válido.
# O CPF 00000000279 não é válido.
# O CPF 00000000280 não é válido.
# O CPF 00000000281 não é válido.
# O CPF 00000000282 não é válido.
# O CPF 00000000283 não é válido.
# O CPF 00000000284 não é válido.
# O CPF 00000000285 não é válido.
# O CPF 00000000286 não é válido.
# O CPF 00000000287 não é válido.
# O CPF 00000000288 não é válido.
# O CPF 00000000289 não é válido.
# O CPF 00000000290 não é válido.
# O CPF 00000000291 não é válido.
# O CPF 00000000292 não é válido.
# O CPF 00000000293 não é válido.
# O CPF 00000000294 não é válido.
# O CPF 00000000295 não é válido.
# O CPF 00000000296 não é válido.
# O CPF 00000000297 não é válido.
# O CPF 00000000298 não é válido.
# O CPF 00000000299 não é válido.
# O CPF 00000000300 não é válido.
# O CPF 00000000301 não é válido.
# O CPF 00000000302 não é válido.
# O CPF 00000000303 não é válido.
# O CPF 00000000304 não é válido.
# O CPF 00000000305 não é válido.
# O CPF 00000000306 não é válido.
# O CPF 00000000307 não é válido.
# O CPF 00000000308 não é válido.
# O CPF 00000000309 não é válido.
# O CPF 00000000310 não é válido.
# O CPF 00000000311 não é válido.
# O CPF 00000000312 não é válido.
# O CPF 00000000313 não é válido.
# O CPF 00000000314 não é válido.
# O CPF 00000000315 não é válido.
# O CPF 00000000316 não é válido.
# O CPF 00000000317 não é válido.
# O CPF 00000000318 não é válido.
# O CPF 00000000319 não é válido.
# O CPF 00000000320 não é válido.
# O CPF 00000000321 não é válido.
# O CPF 00000000322 não é válido.
# O CPF 00000000323 não é válido.
# O CPF 00000000324 não é válido.
# O CPF 00000000325 não é válido.
# O CPF 00000000326 não é válido.
# O CPF 00000000327 não é válido.
# O CPF 00000000328 não é válido.
# O CPF 00000000329 não é válido.
# O CPF 00000000330 não é válido.
# O CPF 00000000331 não é válido.
# O CPF 00000000332 não é válido.
# O CPF 00000000333 não é válido.
# O CPF 00000000334 não é válido.
# O CPF 00000000335 não é válido.
# O CPF 00000000336 não é válido.
# O CPF 00000000337 não é válido.
# O CPF 00000000338 não é válido.
# O CPF 00000000339 não é válido.
# O CPF 00000000340 não é válido.
# O CPF 00000000341 não é válido.
# O CPF 00000000342 não é válido.
# O CPF 00000000343 não é válido.
# O CPF 00000000344 não é válido.
# O CPF 00000000345 não é válido.
# O CPF 00000000346 não é válido.
# O CPF 00000000347 não é válido.
# O CPF 00000000348 não é válido.
# O CPF 00000000349 não é válido.
# O CPF 00000000350 não é válido.
# O CPF 00000000351 não é válido.
# O CPF 00000000352 não é válido.
# O CPF 00000000353 é válido.
# O CPF 00000000354 não é válido.
# O CPF 00000000355 não é válido.
# O CPF 00000000356 não é válido.
# O CPF 00000000357 não é válido.
# O CPF 00000000358 não é válido.
# O CPF 00000000359 não é válido.
# O CPF 00000000360 não é válido.
# O CPF 00000000361 não é válido.
# O CPF 00000000362 não é válido.
# O CPF 00000000363 não é válido.
# O CPF 00000000364 não é válido.
# O CPF 00000000365 não é válido.
# O CPF 00000000366 não é válido.
# O CPF 00000000367 não é válido.
# O CPF 00000000368 não é válido.
# O CPF 00000000369 não é válido.
# O CPF 00000000370 não é válido.
# O CPF 00000000371 não é válido.
# O CPF 00000000372 não é válido.
# O CPF 00000000373 não é válido.
# O CPF 00000000374 não é válido.
# O CPF 00000000375 não é válido.
# O CPF 00000000376 não é válido.
# O CPF 00000000377 não é válido.
# O CPF 00000000378 não é válido.
# O CPF 00000000379 não é válido.
# O CPF 00000000380 não é válido.
# O CPF 00000000381 não é válido.
# O CPF 00000000382 não é válido.
# O CPF 00000000383 não é válido.
# O CPF 00000000384 não é válido.
# O CPF 00000000385 não é válido.
# O CPF 00000000386 não é válido.
# O CPF 00000000387 não é válido.
# O CPF 00000000388 não é válido.
# O CPF 00000000389 não é válido.
# O CPF 00000000390 não é válido.
# O CPF 00000000391 não é válido.
# O CPF 00000000392 não é válido.
# O CPF 00000000393 não é válido.
# O CPF 00000000394 não é válido.
# O CPF 00000000395 não é válido.
# O CPF 00000000396 não é válido.
# O CPF 00000000397 não é válido.
# O CPF 00000000398 não é válido.
# O CPF 00000000399 não é válido.
# O CPF 00000000400 não é válido.
# O CPF 00000000401 não é válido.
# O CPF 00000000402 não é válido.
# O CPF 00000000403 não é válido.
# O CPF 00000000404 não é válido.
# O CPF 00000000405 não é válido.
# O CPF 00000000406 não é válido.
# O CPF 00000000407 não é válido.
# O CPF 00000000408 não é válido.
# O CPF 00000000409 não é válido.
# O CPF 00000000410 não é válido.
# O CPF 00000000411 não é válido.
# O CPF 00000000412 não é válido.
# O CPF 00000000413 não é válido.
# O CPF 00000000414 não é válido.
# O CPF 00000000415 não é válido.
# O CPF 00000000416 não é válido.
# O CPF 00000000417 não é válido.
# O CPF 00000000418 não é válido.
# O CPF 00000000419 não é válido.
# O CPF 00000000420 não é válido.
# O CPF 00000000421 não é válido.
# O CPF 00000000422 não é válido.
# O CPF 00000000423 não é válido.
# O CPF 00000000424 não é válido.
# O CPF 00000000425 não é válido.
# O CPF 00000000426 não é válido.
# O CPF 00000000427 não é válido.
# O CPF 00000000428 não é válido.
# O CPF 00000000429 não é válido.
# O CPF 00000000430 não é válido.
# O CPF 00000000431 não é válido.
# O CPF 00000000432 não é válido.
# O CPF 00000000433 não é válido.
# O CPF 00000000434 é válido.
# O CPF 00000000435 não é válido.
# O CPF 00000000436 não é válido.
# O CPF 00000000437 não é válido.
# O CPF 00000000438 não é válido.
# O CPF 00000000439 não é válido.
# O CPF 00000000440 não é válido.
# O CPF 00000000441 não é válido.
# O CPF 00000000442 não é válido.
# O CPF 00000000443 não é válido.
# O CPF 00000000444 não é válido.
# O CPF 00000000445 não é válido.
# O CPF 00000000446 não é válido.
# O CPF 00000000447 não é válido.
# O CPF 00000000448 não é válido.
# O CPF 00000000449 não é válido.
# O CPF 00000000450 não é válido.
# O CPF 00000000451 não é válido.
# O CPF 00000000452 não é válido.
# O CPF 00000000453 não é válido.
# O CPF 00000000454 não é válido.
# O CPF 00000000455 não é válido.
# O CPF 00000000456 não é válido.
# O CPF 00000000457 não é válido.
# O CPF 00000000458 não é válido.
# O CPF 00000000459 não é válido.
# O CPF 00000000460 não é válido.
# O CPF 00000000461 não é válido.
# O CPF 00000000462 não é válido.
# O CPF 00000000463 não é válido.
# O CPF 00000000464 não é válido.
# O CPF 00000000465 não é válido.
# O CPF 00000000466 não é válido.
# O CPF 00000000467 não é válido.
# O CPF 00000000468 não é válido.
# O CPF 00000000469 não é válido.
# O CPF 00000000470 não é válido.
# O CPF 00000000471 não é válido.
# O CPF 00000000472 não é válido.
# O CPF 00000000473 não é válido.
# O CPF 00000000474 não é válido.
# O CPF 00000000475 não é válido.
# O CPF 00000000476 não é válido.
# O CPF 00000000477 não é válido.
# O CPF 00000000478 não é válido.
# O CPF 00000000479 não é válido.
# O CPF 00000000480 não é válido.
# O CPF 00000000481 não é válido.
# O CPF 00000000482 não é válido.
# O CPF 00000000483 não é válido.
# O CPF 00000000484 não é válido.
# O CPF 00000000485 não é válido.
# O CPF 00000000486 não é válido.
# O CPF 00000000487 não é válido.
# O CPF 00000000488 não é válido.
# O CPF 00000000489 não é válido.
# O CPF 00000000490 não é válido.
# O CPF 00000000491 não é válido.
# O CPF 00000000492 não é válido.
# O CPF 00000000493 não é válido.
# O CPF 00000000494 não é válido.
# O CPF 00000000495 não é válido.
# O CPF 00000000496 não é válido.
# O CPF 00000000497 não é válido.
# O CPF 00000000498 não é válido.
# O CPF 00000000499 não é válido.
# O CPF 00000000500 não é válido.
# O CPF 00000000501 não é válido.
# O CPF 00000000502 não é válido.
# O CPF 00000000503 não é válido.
# O CPF 00000000504 não é válido.
# O CPF 00000000505 não é válido.
# O CPF 00000000506 não é válido.
# O CPF 00000000507 não é válido.
# O CPF 00000000508 não é válido.
# O CPF 00000000509 não é válido.
# O CPF 00000000510 não é válido.
# O CPF 00000000511 não é válido.
# O CPF 00000000512 não é válido.
# O CPF 00000000513 não é válido.
# O CPF 00000000514 não é válido.
# O CPF 00000000515 é válido.
# O CPF 00000000516 não é válido.
# O CPF 00000000517 não é válido.
# O CPF 00000000518 não é válido.
# O CPF 00000000519 não é válido.
# O CPF 00000000520 não é válido.
# O CPF 00000000521 não é válido.
# O CPF 00000000522 não é válido.
# O CPF 00000000523 não é válido.
# O CPF 00000000524 não é válido.
# O CPF 00000000525 não é válido.
# O CPF 00000000526 não é válido.
# O CPF 00000000527 não é válido.
# O CPF 00000000528 não é válido.
# O CPF 00000000529 não é válido.
# O CPF 00000000530 não é válido.
# O CPF 00000000531 não é válido.
# O CPF 00000000532 não é válido.
# O CPF 00000000533 não é válido.
# O CPF 00000000534 não é válido.
# O CPF 00000000535 não é válido.
# O CPF 00000000536 não é válido.
# O CPF 00000000537 não é válido.
# O CPF 00000000538 não é válido.
# O CPF 00000000539 não é válido.
# O CPF 00000000540 não é válido.
# O CPF 00000000541 não é válido.
# O CPF 00000000542 não é válido.
# O CPF 00000000543 não é válido.
# O CPF 00000000544 não é válido.
# O CPF 00000000545 não é válido.
# O CPF 00000000546 não é válido.
# O CPF 00000000547 não é válido.
# O CPF 00000000548 não é válido.
# O CPF 00000000549 não é válido.
# O CPF 00000000550 não é válido.
# O CPF 00000000551 não é válido.
# O CPF 00000000552 não é válido.
# O CPF 00000000553 não é válido.
# O CPF 00000000554 não é válido.
# O CPF 00000000555 não é válido.
# O CPF 00000000556 não é válido.
# O CPF 00000000557 não é válido.
# O CPF 00000000558 não é válido.
# O CPF 00000000559 não é válido.
# O CPF 00000000560 não é válido.
# O CPF 00000000561 não é válido.
# O CPF 00000000562 não é válido.
# O CPF 00000000563 não é válido.
# O CPF 00000000564 não é válido.
# O CPF 00000000565 não é válido.
# O CPF 00000000566 não é válido.
# O CPF 00000000567 não é válido.
# O CPF 00000000568 não é válido.
# O CPF 00000000569 não é válido.
# O CPF 00000000570 não é válido.
# O CPF 00000000571 não é válido.
# O CPF 00000000572 não é válido.
# O CPF 00000000573 não é válido.
# O CPF 00000000574 não é válido.
# O CPF 00000000575 não é válido.
# O CPF 00000000576 não é válido.
# O CPF 00000000577 não é válido.
# O CPF 00000000578 não é válido.
# O CPF 00000000579 não é válido.
# O CPF 00000000580 não é válido.
# O CPF 00000000581 não é válido.
# O CPF 00000000582 não é válido.
# O CPF 00000000583 não é válido.
# O CPF 00000000584 não é válido.
# O CPF 00000000585 não é válido.
# O CPF 00000000586 não é válido.
# O CPF 00000000587 não é válido.
# O CPF 00000000588 não é válido.
# O CPF 00000000589 não é válido.
# O CPF 00000000590 não é válido.
# O CPF 00000000591 não é válido.
# O CPF 00000000592 não é válido.
# O CPF 00000000593 não é válido.
# O CPF 00000000594 não é válido.
# O CPF 00000000595 não é válido.
# O CPF 00000000596 não é válido.
# O CPF 00000000597 não é válido.
# O CPF 00000000598 não é válido.
# O CPF 00000000599 não é válido.
# O CPF 00000000600 não é válido.
# O CPF 00000000601 não é válido.
# O CPF 00000000602 não é válido.
# O CPF 00000000603 não é válido.
# O CPF 00000000604 não é válido.
# O CPF 00000000605 não é válido.
# O CPF 00000000606 não é válido.
# O CPF 00000000607 não é válido.
# O CPF 00000000608 não é válido.
# O CPF 00000000609 não é válido.
# O CPF 00000000610 não é válido.
# O CPF 00000000611 não é válido.
# O CPF 00000000612 não é válido.
# O CPF 00000000613 não é válido.
# O CPF 00000000614 não é válido.
# O CPF 00000000615 não é válido.
# O CPF 00000000616 não é válido.
# O CPF 00000000617 não é válido.
# O CPF 00000000618 não é válido.
# O CPF 00000000619 não é válido.
# O CPF 00000000620 não é válido.
# O CPF 00000000621 não é válido.
# O CPF 00000000622 não é válido.
# O CPF 00000000623 não é válido.
# O CPF 00000000624 não é válido.
# O CPF 00000000625 não é válido.
# O CPF 00000000626 não é válido.
# O CPF 00000000627 não é válido.
# O CPF 00000000628 não é válido.
# O CPF 00000000629 não é válido.
# O CPF 00000000630 não é válido.
# O CPF 00000000631 não é válido.
# O CPF 00000000632 não é válido.
# O CPF 00000000633 não é válido.
# O CPF 00000000634 não é válido.
# O CPF 00000000635 não é válido.
# O CPF 00000000636 não é válido.
# O CPF 00000000637 não é válido.
# O CPF 00000000638 não é válido.
# O CPF 00000000639 não é válido.
# O CPF 00000000640 não é válido.
# O CPF 00000000641 não é válido.
# O CPF 00000000642 não é válido.
# O CPF 00000000643 não é válido.
# O CPF 00000000644 não é válido.
# O CPF 00000000645 não é válido.
# O CPF 00000000646 não é válido.
# O CPF 00000000647 não é válido.
# O CPF 00000000648 não é válido.
# O CPF 00000000649 não é válido.
# O CPF 00000000650 não é válido.
# O CPF 00000000651 não é válido.
# O CPF 00000000652 não é válido.
# O CPF 00000000653 não é válido.
# O CPF 00000000654 não é válido.
# O CPF 00000000655 não é válido.
# O CPF 00000000656 não é válido.
# O CPF 00000000657 não é válido.
# O CPF 00000000658 não é válido.
# O CPF 00000000659 não é válido.
# O CPF 00000000660 não é válido.
# O CPF 00000000661 não é válido.
# O CPF 00000000662 não é válido.
# O CPF 00000000663 não é válido.
# O CPF 00000000664 não é válido.
# O CPF 00000000665 não é válido.
# O CPF 00000000666 não é válido.
# O CPF 00000000667 não é válido.
# O CPF 00000000668 não é válido.
# O CPF 00000000669 não é válido.
# O CPF 00000000670 não é válido.
# O CPF 00000000671 não é válido.
# O CPF 00000000672 não é válido.
# O CPF 00000000673 não é válido.
# O CPF 00000000674 não é válido.
# O CPF 00000000675 não é válido.
# O CPF 00000000676 não é válido.
# O CPF 00000000677 não é válido.
# O CPF 00000000678 não é válido.
# O CPF 00000000679 não é válido.
# O CPF 00000000680 não é válido.
# O CPF 00000000681 não é válido.
# O CPF 00000000682 não é válido.
# O CPF 00000000683 não é válido.
# O CPF 00000000684 não é válido.
# O CPF 00000000685 não é válido.
# O CPF 00000000686 não é válido.
# O CPF 00000000687 não é válido.
# O CPF 00000000688 não é válido.
# O CPF 00000000689 não é válido.
# O CPF 00000000690 não é válido.
# O CPF 00000000691 não é válido.
# O CPF 00000000692 não é válido.
# O CPF 00000000693 não é válido.
# O CPF 00000000694 não é válido.
# O CPF 00000000695 não é válido.
# O CPF 00000000696 não é válido.
# O CPF 00000000697 não é válido.
# O CPF 00000000698 não é válido.
# O CPF 00000000699 não é válido.
# O CPF 00000000700 não é válido.
# O CPF 00000000701 não é válido.
# O CPF 00000000702 não é válido.
# O CPF 00000000703 não é válido.
# O CPF 00000000704 não é válido.
# O CPF 00000000705 não é válido.
# O CPF 00000000706 não é válido.
# O CPF 00000000707 não é válido.
# O CPF 00000000708 não é válido.
# O CPF 00000000709 não é válido.
# O CPF 00000000710 não é válido.
# O CPF 00000000711 não é válido.
# O CPF 00000000712 não é válido.
# O CPF 00000000713 não é válido.
# O CPF 00000000714 não é válido.
# O CPF 00000000715 não é válido.
# O CPF 00000000716 não é válido.
# O CPF 00000000717 não é válido.
# O CPF 00000000718 não é válido.
# O CPF 00000000719 não é válido.
# O CPF 00000000720 não é válido.
# O CPF 00000000721 não é válido.
# O CPF 00000000722 não é válido.
# O CPF 00000000723 não é válido.
# O CPF 00000000724 não é válido.
# O CPF 00000000725 não é válido.
# O CPF 00000000726 não é válido.
# O CPF 00000000727 não é válido.
# O CPF 00000000728 não é válido.
# O CPF 00000000729 não é válido.
# O CPF 00000000730 não é válido.
# O CPF 00000000731 não é válido.
# O CPF 00000000732 não é válido.
# O CPF 00000000733 não é válido.
# O CPF 00000000734 não é válido.
# O CPF 00000000735 não é válido.
# O CPF 00000000736 não é válido.
# O CPF 00000000737 não é válido.
# O CPF 00000000738 não é válido.
# O CPF 00000000739 não é válido.
# O CPF 00000000740 não é válido.
# O CPF 00000000741 não é válido.
# O CPF 00000000742 não é válido.
# O CPF 00000000743 não é válido.
# O CPF 00000000744 não é válido.
# O CPF 00000000745 não é válido.
# O CPF 00000000746 não é válido.
# O CPF 00000000747 não é válido.
# O CPF 00000000748 não é válido.
# O CPF 00000000749 não é válido.
# O CPF 00000000750 não é válido.
# O CPF 00000000751 não é válido.
# O CPF 00000000752 não é válido.
# O CPF 00000000753 não é válido.
# O CPF 00000000754 não é válido.
# O CPF 00000000755 não é válido.
# O CPF 00000000756 não é válido.
# O CPF 00000000757 não é válido.
# O CPF 00000000758 não é válido.
# O CPF 00000000759 não é válido.
# O CPF 00000000760 não é válido.
# O CPF 00000000761 não é válido.
# O CPF 00000000762 não é válido.
# O CPF 00000000763 não é válido.
# O CPF 00000000764 não é válido.
# O CPF 00000000765 não é válido.
# O CPF 00000000766 não é válido.
# O CPF 00000000767 não é válido.
# O CPF 00000000768 não é válido.
# O CPF 00000000769 não é válido.
# O CPF 00000000770 não é válido.
# O CPF 00000000771 não é válido.
# O CPF 00000000772 não é válido.
# O CPF 00000000773 não é válido.
# O CPF 00000000774 não é válido.
# O CPF 00000000775 não é válido.
# O CPF 00000000776 não é válido.
# O CPF 00000000777 não é válido.
# O CPF 00000000778 não é válido.
# O CPF 00000000779 não é válido.
# O CPF 00000000780 não é válido.
# O CPF 00000000781 não é válido.
# O CPF 00000000782 não é válido.
# O CPF 00000000783 não é válido.
# O CPF 00000000784 não é válido.
# O CPF 00000000785 não é válido.
# O CPF 00000000786 não é válido.
# O CPF 00000000787 é válido.
# O CPF 00000000788 não é válido.
# O CPF 00000000789 não é válido.
# O CPF 00000000790 não é válido.
# O CPF 00000000791 não é válido.
# O CPF 00000000792 não é válido.
# O CPF 00000000793 não é válido.
# O CPF 00000000794 não é válido.
# O CPF 00000000795 não é válido.
# O CPF 00000000796 não é válido.
# O CPF 00000000797 não é válido.
# O CPF 00000000798 não é válido.
# O CPF 00000000799 não é válido.
# O CPF 00000000800 não é válido.
# O CPF 00000000801 não é válido.
# O CPF 00000000802 não é válido.
# O CPF 00000000803 não é válido.
# O CPF 00000000804 não é válido.
# O CPF 00000000805 não é válido.
# O CPF 00000000806 não é válido.
# O CPF 00000000807 não é válido.
# O CPF 00000000808 não é válido.
# O CPF 00000000809 não é válido.
# O CPF 00000000810 não é válido.
# O CPF 00000000811 não é válido.
# O CPF 00000000812 não é válido.
# O CPF 00000000813 não é válido.
# O CPF 00000000814 não é válido.
# O CPF 00000000815 não é válido.
# O CPF 00000000816 não é válido.
# O CPF 00000000817 não é válido.
# O CPF 00000000818 não é válido.
# O CPF 00000000819 não é válido.
# O CPF 00000000820 não é válido.
# O CPF 00000000821 não é válido.
# O CPF 00000000822 não é válido.
# O CPF 00000000823 não é válido.
# O CPF 00000000824 não é válido.
# O CPF 00000000825 não é válido.
# O CPF 00000000826 não é válido.
# O CPF 00000000827 não é válido.
# O CPF 00000000828 não é válido.
# O CPF 00000000829 não é válido.
# O CPF 00000000830 não é válido.
# O CPF 00000000831 não é válido.
# O CPF 00000000832 não é válido.
# O CPF 00000000833 não é válido.
# O CPF 00000000834 não é válido.
# O CPF 00000000835 não é válido.
# O CPF 00000000836 não é válido.
# O CPF 00000000837 não é válido.
# O CPF 00000000838 não é válido.
# O CPF 00000000839 não é válido.
# O CPF 00000000840 não é válido.
# O CPF 00000000841 não é válido.
# O CPF 00000000842 não é válido.
# O CPF 00000000843 não é válido.
# O CPF 00000000844 não é válido.
# O CPF 00000000845 não é válido.
# O CPF 00000000846 não é válido.
# O CPF 00000000847 não é válido.
# O CPF 00000000848 não é válido.
# O CPF 00000000849 não é válido.
# O CPF 00000000850 não é válido.
# O CPF 00000000851 não é válido.
# O CPF 00000000852 não é válido.
# O CPF 00000000853 não é válido.
# O CPF 00000000854 não é válido.
# O CPF 00000000855 não é válido.
# O CPF 00000000856 não é válido.
# O CPF 00000000857 não é válido.
# O CPF 00000000858 não é válido.
# O CPF 00000000859 não é válido.
# O CPF 00000000860 não é válido.
# O CPF 00000000861 não é válido.
# O CPF 00000000862 não é válido.
# O CPF 00000000863 não é válido.
# O CPF 00000000864 não é válido.
# O CPF 00000000865 não é válido.
# O CPF 00000000866 não é válido.
# O CPF 00000000867 não é válido.
# O CPF 00000000868 é válido.
# O CPF 00000000869 não é válido.
# O CPF 00000000870 não é válido.
# O CPF 00000000871 não é válido.
# O CPF 00000000872 não é válido.
# O CPF 00000000873 não é válido.
# O CPF 00000000874 não é válido.
# O CPF 00000000875 não é válido.
# O CPF 00000000876 não é válido.
# O CPF 00000000877 não é válido.
# O CPF 00000000878 não é válido.
# O CPF 00000000879 não é válido.
# O CPF 00000000880 não é válido.
# O CPF 00000000881 não é válido.
# O CPF 00000000882 não é válido.
# O CPF 00000000883 não é válido.
# O CPF 00000000884 não é válido.
# O CPF 00000000885 não é válido.
# O CPF 00000000886 não é válido.
# O CPF 00000000887 não é válido.
# O CPF 00000000888 não é válido.
# O CPF 00000000889 não é válido.
# O CPF 00000000890 não é válido.
# O CPF 00000000891 não é válido.
# O CPF 00000000892 não é válido.
# O CPF 00000000893 não é válido.
# O CPF 00000000894 não é válido.
# O CPF 00000000895 não é válido.
# O CPF 00000000896 não é válido.
# O CPF 00000000897 não é válido.
# O CPF 00000000898 não é válido.
# O CPF 00000000899 não é válido.
# O CPF 00000000900 não é válido.
# O CPF 00000000901 não é válido.
# O CPF 00000000902 não é válido.
# O CPF 00000000903 não é válido.
# O CPF 00000000904 não é válido.
# O CPF 00000000905 não é válido.
# O CPF 00000000906 não é válido.
# O CPF 00000000907 não é válido.
# O CPF 00000000908 não é válido.
# O CPF 00000000909 não é válido.
# O CPF 00000000910 não é válido.
# O CPF 00000000911 não é válido.
# O CPF 00000000912 não é válido.
# O CPF 00000000913 não é válido.
# O CPF 00000000914 não é válido.
# O CPF 00000000915 não é válido.
# O CPF 00000000916 não é válido.
# O CPF 00000000917 não é válido.
# O CPF 00000000918 não é válido.
# O CPF 00000000919 não é válido.
# O CPF 00000000920 não é válido.
# O CPF 00000000921 não é válido.
# O CPF 00000000922 não é válido.
# O CPF 00000000923 não é válido.
# O CPF 00000000924 não é válido.
# O CPF 00000000925 não é válido.
# O CPF 00000000926 não é válido.
# O CPF 00000000927 não é válido.
# O CPF 00000000928 não é válido.
# O CPF 00000000929 não é válido.
# O CPF 00000000930 não é válido.
# O CPF 00000000931 não é válido.
# O CPF 00000000932 não é válido.
# O CPF 00000000933 não é válido.
# O CPF 00000000934 não é válido.
# O CPF 00000000935 não é válido.
# O CPF 00000000936 não é válido.
# O CPF 00000000937 não é válido.
# O CPF 00000000938 não é válido.
# O CPF 00000000939 não é válido.
# O CPF 00000000940 não é válido.
# O CPF 00000000941 não é válido.
# O CPF 00000000942 não é válido.
# O CPF 00000000943 não é válido.
# O CPF 00000000944 não é válido.
# O CPF 00000000945 não é válido.
# O CPF 00000000946 não é válido.
# O CPF 00000000947 não é válido.
# O CPF 00000000948 não é válido.
# O CPF 00000000949 é válido.
# O CPF 00000000950 não é válido.
# O CPF 00000000951 não é válido.
# O CPF 00000000952 não é válido.
# O CPF 00000000953 não é válido.
# O CPF 00000000954 não é válido.
# O CPF 00000000955 não é válido.
# O CPF 00000000956 não é válido.
# O CPF 00000000957 não é válido.
# O CPF 00000000958 não é válido.
# O CPF 00000000959 não é válido.
# O CPF 00000000960 não é válido.
# O CPF 00000000961 não é válido.
# O CPF 00000000962 não é válido.
# O CPF 00000000963 não é válido.
# O CPF 00000000964 não é válido.
# O CPF 00000000965 não é válido.
# O CPF 00000000966 não é válido.
# O CPF 00000000967 não é válido.
# O CPF 00000000968 não é válido.
# O CPF 00000000969 não é válido.
# O CPF 00000000970 não é válido.
# O CPF 00000000971 não é válido.
# O CPF 00000000972 não é válido.
# O CPF 00000000973 não é válido.
# O CPF 00000000974 não é válido.
# O CPF 00000000975 não é válido.
# O CPF 00000000976 não é válido.
# O CPF 00000000977 não é válido.
# O CPF 00000000978 não é válido.
# O CPF 00000000979 não é válido.
# O CPF 00000000980 não é válido.
# O CPF 00000000981 não é válido.
# O CPF 00000000982 não é válido.
# O CPF 00000000983 não é válido.
# O CPF 00000000984 não é válido.
# O CPF 00000000985 não é válido.
# O CPF 00000000986 não é válido.
# O CPF 00000000987 não é válido.
# O CPF 00000000988 não é válido.
# O CPF 00000000989 não é válido.
# O CPF 00000000990 não é válido.
# O CPF 00000000991 não é válido.
# O CPF 00000000992 não é válido.
# O CPF 00000000993 não é válido.
# O CPF 00000000994 não é válido.
# O CPF 00000000995 não é válido.
# O CPF 00000000996 não é válido.
# O CPF 00000000997 não é válido.
# O CPF 00000000998 não é válido.
# O CPF 00000000999 não é válido.
# O CPF 00000001000 não é válido.
# O CPF 00000001001 não é válido.
# O CPF 00000001002 não é válido.
# O CPF 00000001003 não é válido.
# O CPF 00000001004 não é válido.
# O CPF 00000001005 não é válido.
# O CPF 00000001006 não é válido.
# O CPF 00000001007 não é válido.
# O CPF 00000001008 não é válido.
# O CPF 00000001009 não é válido.
# O CPF 00000001010 não é válido.
# O CPF 00000001011 não é válido.
# O CPF 00000001012 não é válido.
# O CPF 00000001013 não é válido.
# O CPF 00000001014 não é válido.
# O CPF 00000001015 não é válido.
# O CPF 00000001016 não é válido.
# O CPF 00000001017 não é válido.
# O CPF 00000001018 não é válido.
# O CPF 00000001019 não é válido.
# O CPF 00000001020 não é válido.
# O CPF 00000001021 não é válido.
# O CPF 00000001022 não é válido.
# O CPF 00000001023 não é válido.
# O CPF 00000001024 não é válido.
# O CPF 00000001025 não é válido.
# O CPF 00000001026 não é válido.
# O CPF 00000001027 não é válido.
# O CPF 00000001028 não é válido.
# O CPF 00000001029 não é válido.
# O CPF 00000001030 não é válido.
# O CPF 00000001031 não é válido.
# O CPF 00000001032 não é válido.
# O CPF 00000001033 não é válido.
# O CPF 00000001034 não é válido.
# O CPF 00000001035 não é válido.
# O CPF 00000001036 não é válido.
# O CPF 00000001037 não é válido.
# O CPF 00000001038 não é válido.
# O CPF 00000001039 não é válido.
# O CPF 00000001040 não é válido.
# O CPF 00000001041 não é válido.
# O CPF 00000001042 não é válido.
# O CPF 00000001043 não é válido.
# O CPF 00000001044 não é válido.
# O CPF 00000001045 não é válido.
# O CPF 00000001046 não é válido.
# O CPF 00000001047 não é válido.
# O CPF 00000001048 não é válido.
# O CPF 00000001049 não é válido.
# O CPF 00000001050 não é válido.
# O CPF 00000001051 não é válido.
# O CPF 00000001052 não é válido.
# O CPF 00000001053 não é válido.
# O CPF 00000001054 não é válido.
# O CPF 00000001055 não é válido.
# O CPF 00000001056 não é válido.
# O CPF 00000001057 não é válido.
# O CPF 00000001058 não é válido.
# O CPF 00000001059 não é válido.
# O CPF 00000001060 não é válido.
# O CPF 00000001061 não é válido.
# O CPF 00000001062 não é válido.
# O CPF 00000001063 não é válido.
# O CPF 00000001064 não é válido.
# O CPF 00000001065 não é válido.
# O CPF 00000001066 não é válido.
# O CPF 00000001067 não é válido.
# O CPF 00000001068 não é válido.
# O CPF 00000001069 não é válido.
# O CPF 00000001070 não é válido.
# O CPF 00000001071 não é válido.
# O CPF 00000001072 não é válido.
# O CPF 00000001073 não é válido.
# O CPF 00000001074 não é válido.
# O CPF 00000001075 não é válido.
# O CPF 00000001076 não é válido.
# O CPF 00000001077 não é válido.
# O CPF 00000001078 não é válido.
# O CPF 00000001079 não é válido.
# O CPF 00000001080 não é válido.
# O CPF 00000001081 não é válido.
# O CPF 00000001082 é válido.
# O CPF 00000001083 não é válido.
# O CPF 00000001084 não é válido.
# O CPF 00000001085 não é válido.
# O CPF 00000001086 não é válido.
# O CPF 00000001087 não é válido.
# O CPF 00000001088 não é válido.
# O CPF 00000001089 não é válido.
# O CPF 00000001090 não é válido.
# O CPF 00000001091 não é válido.
# O CPF 00000001092 não é válido.
# O CPF 00000001093 não é válido.
# O CPF 00000001094 não é válido.
# O CPF 00000001095 não é válido.
# O CPF 00000001096 não é válido.
# O CPF 00000001097 não é válido.
# O CPF 00000001098 não é válido.
# O CPF 00000001099 não é válido.
# O CPF 00000001100 não é válido.
# O CPF 00000001101 não é válido.
# O CPF 00000001102 não é válido.
# O CPF 00000001103 não é válido.
# O CPF 00000001104 não é válido.
# O CPF 00000001105 não é válido.
# O CPF 00000001106 não é válido.
# O CPF 00000001107 não é válido.
# O CPF 00000001108 não é válido.
# O CPF 00000001109 não é válido.
# O CPF 00000001110 não é válido.
# O CPF 00000001111 não é válido.
# O CPF 00000001112 não é válido.
# O CPF 00000001113 não é válido.
# O CPF 00000001114 não é válido.
# O CPF 00000001115 não é válido.
# O CPF 00000001116 não é válido.
# O CPF 00000001117 não é válido.
# O CPF 00000001118 não é válido.
# O CPF 00000001119 não é válido.
# O CPF 00000001120 não é válido.
# O CPF 00000001121 não é válido.
# O CPF 00000001122 não é válido.
# O CPF 00000001123 não é válido.
# O CPF 00000001124 não é válido.
# O CPF 00000001125 não é válido.
# O CPF 00000001126 não é válido.
# O CPF 00000001127 não é válido.
# O CPF 00000001128 não é válido.
# O CPF 00000001129 não é válido.
# O CPF 00000001130 não é válido.
# O CPF 00000001131 não é válido.
# O CPF 00000001132 não é válido.
# O CPF 00000001133 não é válido.
# O CPF 00000001134 não é válido.
# O CPF 00000001135 não é válido.
# O CPF 00000001136 não é válido.
# O CPF 00000001137 não é válido.
# O CPF 00000001138 não é válido.
# O CPF 00000001139 não é válido.
# O CPF 00000001140 não é válido.
# O CPF 00000001141 não é válido.
# O CPF 00000001142 não é válido.
# O CPF 00000001143 não é válido.
# O CPF 00000001144 não é válido.
# O CPF 00000001145 não é válido.
# O CPF 00000001146 não é válido.
# O CPF 00000001147 não é válido.
# O CPF 00000001148 não é válido.
# O CPF 00000001149 não é válido.
# O CPF 00000001150 não é válido.
# O CPF 00000001151 não é válido.
# O CPF 00000001152 não é válido.
# O CPF 00000001153 não é válido.
# O CPF 00000001154 não é válido.
# O CPF 00000001155 não é válido.
# O CPF 00000001156 não é válido.
# O CPF 00000001157 não é válido.
# O CPF 00000001158 não é válido.
# O CPF 00000001159 não é válido.
# O CPF 00000001160 não é válido.
# O CPF 00000001161 não é válido.
# O CPF 00000001162 não é válido.
# O CPF 00000001163 é válido.
# O CPF 00000001164 não é válido.
# O CPF 00000001165 não é válido.
# O CPF 00000001166 não é válido.
# O CPF 00000001167 não é válido.
# O CPF 00000001168 não é válido.
# O CPF 00000001169 não é válido.
# O CPF 00000001170 não é válido.
# O CPF 00000001171 não é válido.
# O CPF 00000001172 não é válido.
# O CPF 00000001173 não é válido.
# O CPF 00000001174 não é válido.
# O CPF 00000001175 não é válido.
# O CPF 00000001176 não é válido.
# O CPF 00000001177 não é válido.
# O CPF 00000001178 não é válido.
# O CPF 00000001179 não é válido.
# O CPF 00000001180 não é válido.
# O CPF 00000001181 não é válido.
# O CPF 00000001182 não é válido.
# O CPF 00000001183 não é válido.
# O CPF 00000001184 não é válido.
# O CPF 00000001185 não é válido.
# O CPF 00000001186 não é válido.
# O CPF 00000001187 não é válido.
# O CPF 00000001188 não é válido.
# O CPF 00000001189 não é válido.
# O CPF 00000001190 não é válido.
# O CPF 00000001191 não é válido.
# O CPF 00000001192 não é válido.
# O CPF 00000001193 não é válido.
# O CPF 00000001194 não é válido.
# O CPF 00000001195 não é válido.
# O CPF 00000001196 não é válido.
# O CPF 00000001197 não é válido.
# O CPF 00000001198 não é válido.
# O CPF 00000001199 não é válido.
# O CPF 00000001200 não é válido.
# O CPF 00000001201 não é válido.
# O CPF 00000001202 não é válido.
# O CPF 00000001203 não é válido.
# O CPF 00000001204 não é válido.
# O CPF 00000001205 não é válido.
# O CPF 00000001206 não é válido.
# O CPF 00000001207 não é válido.
# O CPF 00000001208 não é válido.
# O CPF 00000001209 não é válido.
# O CPF 00000001210 não é válido.
# O CPF 00000001211 não é válido.
# O CPF 00000001212 não é válido.
# O CPF 00000001213 não é válido.
# O CPF 00000001214 não é válido.
# O CPF 00000001215 não é válido.
# O CPF 00000001216 não é válido.
# O CPF 00000001217 não é válido.
# O CPF 00000001218 não é válido.
# O CPF 00000001219 não é válido.
# O CPF 00000001220 não é válido.
# O CPF 00000001221 não é válido.
# O CPF 00000001222 não é válido.
# O CPF 00000001223 não é válido.
# O CPF 00000001224 não é válido.
# O CPF 00000001225 não é válido.
# O CPF 00000001226 não é válido.
# O CPF 00000001227 não é válido.
# O CPF 00000001228 não é válido.
# O CPF 00000001229 não é válido.
# O CPF 00000001230 não é válido.
# O CPF 00000001231 não é válido.
# O CPF 00000001232 não é válido.
# O CPF 00000001233 não é válido.
# O CPF 00000001234 não é válido.
# O CPF 00000001235 não é válido.
# O CPF 00000001236 não é válido.
# O CPF 00000001237 não é válido.
# O CPF 00000001238 não é válido.
# O CPF 00000001239 não é válido.
# O CPF 00000001240 não é válido.
# O CPF 00000001241 não é válido.
# O CPF 00000001242 não é válido.
# O CPF 00000001243 não é válido.
# O CPF 00000001244 é válido.
# O CPF 00000001245 não é válido.
# O CPF 00000001246 não é válido.
# O CPF 00000001247 não é válido.
# O CPF 00000001248 não é válido.
# O CPF 00000001249 não é válido.
# O CPF 00000001250 não é válido.
# O CPF 00000001251 não é válido.
# O CPF 00000001252 não é válido.
# O CPF 00000001253 não é válido.
# O CPF 00000001254 não é válido.
# O CPF 00000001255 não é válido.
# O CPF 00000001256 não é válido.
# O CPF 00000001257 não é válido.
# O CPF 00000001258 não é válido.
# O CPF 00000001259 não é válido.
# O CPF 00000001260 não é válido.
# O CPF 00000001261 não é válido.
# O CPF 00000001262 não é válido.
# O CPF 00000001263 não é válido.
# O CPF 00000001264 não é válido.
# O CPF 00000001265 não é válido.
# O CPF 00000001266 não é válido.
# O CPF 00000001267 não é válido.
# O CPF 00000001268 não é válido.
# O CPF 00000001269 não é válido.
# O CPF 00000001270 não é válido.
# O CPF 00000001271 não é válido.
# O CPF 00000001272 não é válido.
# O CPF 00000001273 não é válido.
# O CPF 00000001274 não é válido.
# O CPF 00000001275 não é válido.
# O CPF 00000001276 não é válido.
# O CPF 00000001277 não é válido.
# O CPF 00000001278 não é válido.
# O CPF 00000001279 não é válido.
# O CPF 00000001280 não é válido.
# O CPF 00000001281 não é válido.
# O CPF 00000001282 não é válido.
# O CPF 00000001283 não é válido.
# O CPF 00000001284 não é válido.
# O CPF 00000001285 não é válido.
# O CPF 00000001286 não é válido.
# O CPF 00000001287 não é válido.
# O CPF 00000001288 não é válido.
# O CPF 00000001289 não é válido.
# O CPF 00000001290 não é válido.
# O CPF 00000001291 não é válido.
# O CPF 00000001292 não é válido.
# O CPF 00000001293 não é válido.
# O CPF 00000001294 não é válido.
# O CPF 00000001295 não é válido.
# O CPF 00000001296 não é válido.
# O CPF 00000001297 não é válido.
# O CPF 00000001298 não é válido.
# O CPF 00000001299 não é válido.
# O CPF 00000001300 não é válido.
# O CPF 00000001301 não é válido.
# O CPF 00000001302 não é válido.
# O CPF 00000001303 não é válido.
# O CPF 00000001304 não é válido.
# O CPF 00000001305 não é válido.
# O CPF 00000001306 não é válido.
# O CPF 00000001307 não é válido.
# O CPF 00000001308 não é válido.
# O CPF 00000001309 não é válido.
# O CPF 00000001310 não é válido.
# O CPF 00000001311 não é válido.
# O CPF 00000001312 não é válido.
# O CPF 00000001313 não é válido.
# O CPF 00000001314 não é válido.
# O CPF 00000001315 não é válido.
# O CPF 00000001316 não é válido.
# O CPF 00000001317 não é válido.
# O CPF 00000001318 não é válido.
# O CPF 00000001319 não é válido.
# O CPF 00000001320 não é válido.
# O CPF 00000001321 não é válido.
# O CPF 00000001322 não é válido.
# O CPF 00000001323 não é válido.
# O CPF 00000001324 não é válido.
# O CPF 00000001325 é válido.
# O CPF 00000001326 não é válido.
# O CPF 00000001327 não é válido.
# O CPF 00000001328 não é válido.
# O CPF 00000001329 não é válido.
# O CPF 00000001330 não é válido.
# O CPF 00000001331 não é válido.
# O CPF 00000001332 não é válido.
# O CPF 00000001333 não é válido.
# O CPF 00000001334 não é válido.
# O CPF 00000001335 não é válido.
# O CPF 00000001336 não é válido.
# O CPF 00000001337 não é válido.
# O CPF 00000001338 não é válido.
# O CPF 00000001339 não é válido.
# O CPF 00000001340 não é válido.
# O CPF 00000001341 não é válido.
# O CPF 00000001342 não é válido.
# O CPF 00000001343 não é válido.
# O CPF 00000001344 não é válido.
# O CPF 00000001345 não é válido.
# O CPF 00000001346 não é válido.
# O CPF 00000001347 não é válido.
# O CPF 00000001348 não é válido.
# O CPF 00000001349 não é válido.
# O CPF 00000001350 não é válido.
# O CPF 00000001351 não é válido.
# O CPF 00000001352 não é válido.
# O CPF 00000001353 não é válido.
# O CPF 00000001354 não é válido.
# O CPF 00000001355 não é válido.
# O CPF 00000001356 não é válido.
# O CPF 00000001357 não é válido.
# O CPF 00000001358 não é válido.
# O CPF 00000001359 não é válido.
# O CPF 00000001360 não é válido.
# O CPF 00000001361 não é válido.
# O CPF 00000001362 não é válido.
# O CPF 00000001363 não é válido.
# O CPF 00000001364 não é válido.
# O CPF 00000001365 não é válido.
# O CPF 00000001366 não é válido.
# O CPF 00000001367 não é válido.
# O CPF 00000001368 não é válido.
# O CPF 00000001369 não é válido.
# O CPF 00000001370 não é válido.
# O CPF 00000001371 não é válido.
# O CPF 00000001372 não é válido.
# O CPF 00000001373 não é válido.
# O CPF 00000001374 não é válido.
# O CPF 00000001375 não é válido.
# O CPF 00000001376 não é válido.
# O CPF 00000001377 não é válido.
# O CPF 00000001378 não é válido.
# O CPF 00000001379 não é válido.
# O CPF 00000001380 não é válido.
# O CPF 00000001381 não é válido.
# O CPF 00000001382 não é válido.
# O CPF 00000001383 não é válido.
# O CPF 00000001384 não é válido.
# O CPF 00000001385 não é válido.
# O CPF 00000001386 não é válido.
# O CPF 00000001387 não é válido.
# O CPF 00000001388 não é válido.
# O CPF 00000001389 não é válido.
# O CPF 00000001390 não é válido.
# O CPF 00000001391 não é válido.
# O CPF 00000001392 não é válido.
# O CPF 00000001393 não é válido.
# O CPF 00000001394 não é válido.
# O CPF 00000001395 não é válido.
# O CPF 00000001396 não é válido.
# O CPF 00000001397 não é válido.
# O CPF 00000001398 não é válido.
# O CPF 00000001399 não é válido.
# O CPF 00000001400 não é válido.
# O CPF 00000001401 não é válido.
# O CPF 00000001402 não é válido.
# O CPF 00000001403 não é válido.
# O CPF 00000001404 não é válido.
# O CPF 00000001405 não é válido.
# O CPF 00000001406 é válido.
# O CPF 00000001407 não é válido.
# O CPF 00000001408 não é válido.
# O CPF 00000001409 não é válido.
# O CPF 00000001410 não é válido.
# O CPF 00000001411 não é válido.
# O CPF 00000001412 não é válido.
# O CPF 00000001413 não é válido.
# O CPF 00000001414 não é válido.
# O CPF 00000001415 não é válido.
# O CPF 00000001416 não é válido.
# O CPF 00000001417 não é válido.
# O CPF 00000001418 não é válido.
# O CPF 00000001419 não é válido.
# O CPF 00000001420 não é válido.
# O CPF 00000001421 não é válido.
# O CPF 00000001422 não é válido.
# O CPF 00000001423 não é válido.
# O CPF 00000001424 não é válido.
# O CPF 00000001425 não é válido.
# O CPF 00000001426 não é válido.
# O CPF 00000001427 não é válido.
# O CPF 00000001428 não é válido.
# O CPF 00000001429 não é válido.
# O CPF 00000001430 não é válido.
# O CPF 00000001431 não é válido.
# O CPF 00000001432 não é válido.
# O CPF 00000001433 não é válido.
# O CPF 00000001434 não é válido.
# O CPF 00000001435 não é válido.
# O CPF 00000001436 não é válido.
# O CPF 00000001437 não é válido.
# O CPF 00000001438 não é válido.
# O CPF 00000001439 não é válido.
# O CPF 00000001440 não é válido.
# O CPF 00000001441 não é válido.
# O CPF 00000001442 não é válido.
# O CPF 00000001443 não é válido.
# O CPF 00000001444 não é válido.
# O CPF 00000001445 não é válido.
# O CPF 00000001446 não é válido.
# O CPF 00000001447 não é válido.
# O CPF 00000001448 não é válido.
# O CPF 00000001449 não é válido.
# O CPF 00000001450 não é válido.
# O CPF 00000001451 não é válido.
# O CPF 00000001452 não é válido.
# O CPF 00000001453 não é válido.
# O CPF 00000001454 não é válido.
# O CPF 00000001455 não é válido.
# O CPF 00000001456 não é válido.
# O CPF 00000001457 não é válido.
# O CPF 00000001458 não é válido.
# O CPF 00000001459 não é válido.
# O CPF 00000001460 não é válido.
# O CPF 00000001461 não é válido.
# O CPF 00000001462 não é válido.
# O CPF 00000001463 não é válido.
# O CPF 00000001464 não é válido.
# O CPF 00000001465 não é válido.
# O CPF 00000001466 não é válido.
# O CPF 00000001467 não é válido.
# O CPF 00000001468 não é válido.
# O CPF 00000001469 não é válido.
# O CPF 00000001470 não é válido.
# O CPF 00000001471 não é válido.
# O CPF 00000001472 não é válido.
# O CPF 00000001473 não é válido.
# O CPF 00000001474 não é válido.
# O CPF 00000001475 não é válido.
# O CPF 00000001476 não é válido.
# O CPF 00000001477 não é válido.
# O CPF 00000001478 não é válido.
# O CPF 00000001479 não é válido.
# O CPF 00000001480 não é válido.
# O CPF 00000001481 não é válido.
# O CPF 00000001482 não é válido.
# O CPF 00000001483 não é válido.
# O CPF 00000001484 não é válido.
# O CPF 00000001485 não é válido.
# O CPF 00000001486 não é válido.
# O CPF 00000001487 não é válido.
# O CPF 00000001488 não é válido.
# O CPF 00000001489 não é válido.
# O CPF 00000001490 não é válido.
# O CPF 00000001491 não é válido.
# O CPF 00000001492 não é válido.
# O CPF 00000001493 não é válido.
# O CPF 00000001494 não é válido.
# O CPF 00000001495 não é válido.
# O CPF 00000001496 não é válido.
# O CPF 00000001497 não é válido.
# O CPF 00000001498 não é válido.
# O CPF 00000001499 não é válido.
# O CPF 00000001500 não é válido.
# ...
# O CPF 00000009500 não é válido.
# O CPF 00000009501 não é válido.
# O CPF 00000009502 não é válido.
# O CPF 00000009503 não é válido.
# O CPF 00000009504 não é válido.
# O CPF 00000009505 não é válido.
# O CPF 00000009506 não é válido.
# O CPF 00000009507 não é válido.
# O CPF 00000009508 não é válido.
# O CPF 00000009509 não é válido.
# O CPF 00000009510 não é válido.
# O CPF 00000009511 não é válido.
# O CPF 00000009512 não é válido.
# O CPF 00000009513 não é válido.
# O CPF 00000009514 não é válido.
# O CPF 00000009515 não é válido.
# O CPF 00000009516 não é válido.
# O CPF 00000009517 não é válido.
# O CPF 00000009518 não é válido.
# O CPF 00000009519 não é válido.
# O CPF 00000009520 não é válido.
# O CPF 00000009521 não é válido.
# O CPF 00000009522 não é válido.
# O CPF 00000009523 não é válido.
# O CPF 00000009524 não é válido.
# O CPF 00000009525 não é válido.
# O CPF 00000009526 não é válido.
# O CPF 00000009527 não é válido.
# O CPF 00000009528 não é válido.
# O CPF 00000009529 não é válido.
# O CPF 00000009530 não é válido.
# O CPF 00000009531 não é válido.
# O CPF 00000009532 não é válido.
# O CPF 00000009533 não é válido.
# O CPF 00000009534 não é válido.
# O CPF 00000009535 não é válido.
# O CPF 00000009536 não é válido.
# O CPF 00000009537 não é válido.
# O CPF 00000009538 não é válido.
# O CPF 00000009539 não é válido.
# O CPF 00000009540 não é válido.
# O CPF 00000009541 não é válido.
# O CPF 00000009542 não é válido.
# O CPF 00000009543 não é válido.
# O CPF 00000009544 não é válido.
# O CPF 00000009545 não é válido.
# O CPF 00000009546 não é válido.
# O CPF 00000009547 não é válido.
# O CPF 00000009548 não é válido.
# O CPF 00000009549 não é válido.
# O CPF 00000009550 não é válido.
# O CPF 00000009551 não é válido.
# O CPF 00000009552 não é válido.
# O CPF 00000009553 não é válido.
# O CPF 00000009554 não é válido.
# O CPF 00000009555 não é válido.
# O CPF 00000009556 não é válido.
# O CPF 00000009557 não é válido.
# O CPF 00000009558 não é válido.
# O CPF 00000009559 não é válido.
# O CPF 00000009560 não é válido.
# O CPF 00000009561 não é válido.
# O CPF 00000009562 não é válido.
# O CPF 00000009563 não é válido.
# O CPF 00000009564 não é válido.
# O CPF 00000009565 não é válido.
# O CPF 00000009566 não é válido.
# O CPF 00000009567 não é válido.
# O CPF 00000009568 não é válido.
# O CPF 00000009569 não é válido.
# O CPF 00000009570 não é válido.
# O CPF 00000009571 é válido.
# O CPF 00000009572 não é válido.
# O CPF 00000009573 não é válido.
# O CPF 00000009574 não é válido.
# O CPF 00000009575 não é válido.
# O CPF 00000009576 não é válido.
# O CPF 00000009577 não é válido.
# O CPF 00000009578 não é válido.
# O CPF 00000009579 não é válido.
# O CPF 00000009580 não é válido.
# O CPF 00000009581 não é válido.
# O CPF 00000009582 não é válido.
# O CPF 00000009583 não é válido.
# O CPF 00000009584 não é válido.
# O CPF 00000009585 não é válido.
# O CPF 00000009586 não é válido.
# O CPF 00000009587 não é válido.
# O CPF 00000009588 não é válido.
# O CPF 00000009589 não é válido.
# O CPF 00000009590 não é válido.
# O CPF 00000009591 não é válido.
# O CPF 00000009592 não é válido.
# O CPF 00000009593 não é válido.
# O CPF 00000009594 não é válido.
# O CPF 00000009595 não é válido.
# O CPF 00000009596 não é válido.
# O CPF 00000009597 não é válido.
# O CPF 00000009598 não é válido.
# O CPF 00000009599 não é válido.
# O CPF 00000009600 não é válido.
# O CPF 00000009601 não é válido.
# O CPF 00000009602 não é válido.
# O CPF 00000009603 não é válido.
# O CPF 00000009604 não é válido.
# O CPF 00000009605 não é válido.
# O CPF 00000009606 não é válido.
# O CPF 00000009607 não é válido.
# O CPF 00000009608 não é válido.
# O CPF 00000009609 não é válido.
# O CPF 00000009610 não é válido.
# O CPF 00000009611 não é válido.
# O CPF 00000009612 não é válido.
# O CPF 00000009613 não é válido.
# O CPF 00000009614 não é válido.
# O CPF 00000009615 não é válido.
# O CPF 00000009616 não é válido.
# O CPF 00000009617 não é válido.
# O CPF 00000009618 não é válido.
# O CPF 00000009619 não é válido.
# O CPF 00000009620 não é válido.
# O CPF 00000009621 não é válido.
# O CPF 00000009622 não é válido.
# O CPF 00000009623 não é válido.
# O CPF 00000009624 não é válido.
# O CPF 00000009625 não é válido.
# O CPF 00000009626 não é válido.
# O CPF 00000009627 não é válido.
# O CPF 00000009628 não é válido.
# O CPF 00000009629 não é válido.
# O CPF 00000009630 não é válido.
# O CPF 00000009631 não é válido.
# O CPF 00000009632 não é válido.
# O CPF 00000009633 não é válido.
# O CPF 00000009634 não é válido.
# O CPF 00000009635 não é válido.
# O CPF 00000009636 não é válido.
# O CPF 00000009637 não é válido.
# O CPF 00000009638 não é válido.
# O CPF 00000009639 não é válido.
# O CPF 00000009640 não é válido.
# O CPF 00000009641 não é válido.
# O CPF 00000009642 não é válido.
# O CPF 00000009643 não é válido.
# O CPF 00000009644 não é válido.
# O CPF 00000009645 não é válido.
# O CPF 00000009646 não é válido.
# O CPF 00000009647 não é válido.
# O CPF 00000009648 não é válido.
# O CPF 00000009649 não é válido.
# O CPF 00000009650 não é válido.
# O CPF 00000009651 não é válido.
# O CPF 00000009652 é válido.
# O CPF 00000009653 não é válido.
# O CPF 00000009654 não é válido.
# O CPF 00000009655 não é válido.
# O CPF 00000009656 não é válido.
# O CPF 00000009657 não é válido.
# O CPF 00000009658 não é válido.
# O CPF 00000009659 não é válido.
# O CPF 00000009660 não é válido.
# O CPF 00000009661 não é válido.
# O CPF 00000009662 não é válido.
# O CPF 00000009663 não é válido.
# O CPF 00000009664 não é válido.
# O CPF 00000009665 não é válido.
# O CPF 00000009666 não é válido.
# O CPF 00000009667 não é válido.
# O CPF 00000009668 não é válido.
# O CPF 00000009669 não é válido.
# O CPF 00000009670 não é válido.
# O CPF 00000009671 não é válido.
# O CPF 00000009672 não é válido.
# O CPF 00000009673 não é válido.
# O CPF 00000009674 não é válido.
# O CPF 00000009675 não é válido.
# O CPF 00000009676 não é válido.
# O CPF 00000009677 não é válido.
# O CPF 00000009678 não é válido.
# O CPF 00000009679 não é válido.
# O CPF 00000009680 não é válido.
# O CPF 00000009681 não é válido.
# O CPF 00000009682 não é válido.
# O CPF 00000009683 não é válido.
# O CPF 00000009684 não é válido.
# O CPF 00000009685 não é válido.
# O CPF 00000009686 não é válido.
# O CPF 00000009687 não é válido.
# O CPF 00000009688 não é válido.
# O CPF 00000009689 não é válido.
# O CPF 00000009690 não é válido.
# O CPF 00000009691 não é válido.
# O CPF 00000009692 não é válido.
# O CPF 00000009693 não é válido.
# O CPF 00000009694 não é válido.
# O CPF 00000009695 não é válido.
# O CPF 00000009696 não é válido.
# O CPF 00000009697 não é válido.
# O CPF 00000009698 não é válido.
# O CPF 00000009699 não é válido.
# O CPF 00000009700 não é válido.
# O CPF 00000009701 não é válido.
# O CPF 00000009702 não é válido.
# O CPF 00000009703 não é válido.
# O CPF 00000009704 não é válido.
# O CPF 00000009705 não é válido.
# O CPF 00000009706 não é válido.
# O CPF 00000009707 não é válido.
# O CPF 00000009708 não é válido.
# O CPF 00000009709 não é válido.
# O CPF 00000009710 não é válido.
# O CPF 00000009711 não é válido.
# O CPF 00000009712 não é válido.
# O CPF 00000009713 não é válido.
# O CPF 00000009714 não é válido.
# O CPF 00000009715 não é válido.
# O CPF 00000009716 não é válido.
# O CPF 00000009717 não é válido.
# O CPF 00000009718 não é válido.
# O CPF 00000009719 não é válido.
# O CPF 00000009720 não é válido.
# O CPF 00000009721 não é válido.
# O CPF 00000009722 não é válido.
# O CPF 00000009723 não é válido.
# O CPF 00000009724 não é válido.
# O CPF 00000009725 não é válido.
# O CPF 00000009726 não é válido.
# O CPF 00000009727 não é válido.
# O CPF 00000009728 não é válido.
# O CPF 00000009729 não é válido.
# O CPF 00000009730 não é válido.
# O CPF 00000009731 não é válido.
# O CPF 00000009732 não é válido.
# O CPF 00000009733 é válido.
# O CPF 00000009734 não é válido.
# O CPF 00000009735 não é válido.
# O CPF 00000009736 não é válido.
# O CPF 00000009737 não é válido.
# O CPF 00000009738 não é válido.
# O CPF 00000009739 não é válido.
# O CPF 00000009740 não é válido.
# O CPF 00000009741 não é válido.
# O CPF 00000009742 não é válido.
# O CPF 00000009743 não é válido.
# O CPF 00000009744 não é válido.
# O CPF 00000009745 não é válido.
# O CPF 00000009746 não é válido.
# O CPF 00000009747 não é válido.
# O CPF 00000009748 não é válido.
# O CPF 00000009749 não é válido.
# O CPF 00000009750 não é válido.
# O CPF 00000009751 não é válido.
# O CPF 00000009752 não é válido.
# O CPF 00000009753 não é válido.
# O CPF 00000009754 não é válido.
# O CPF 00000009755 não é válido.
# O CPF 00000009756 não é válido.
# O CPF 00000009757 não é válido.
# O CPF 00000009758 não é válido.
# O CPF 00000009759 não é válido.
# O CPF 00000009760 não é válido.
# O CPF 00000009761 não é válido.
# O CPF 00000009762 não é válido.
# O CPF 00000009763 não é válido.
# O CPF 00000009764 não é válido.
# O CPF 00000009765 não é válido.
# O CPF 00000009766 não é válido.
# O CPF 00000009767 não é válido.
# O CPF 00000009768 não é válido.
# O CPF 00000009769 não é válido.
# O CPF 00000009770 não é válido.
# O CPF 00000009771 não é válido.
# O CPF 00000009772 não é válido.
# O CPF 00000009773 não é válido.
# O CPF 00000009774 não é válido.
# O CPF 00000009775 não é válido.
# O CPF 00000009776 não é válido.
# O CPF 00000009777 não é válido.
# O CPF 00000009778 não é válido.
# O CPF 00000009779 não é válido.
# O CPF 00000009780 não é válido.
# O CPF 00000009781 não é válido.
# O CPF 00000009782 não é válido.
# O CPF 00000009783 não é válido.
# O CPF 00000009784 não é válido.
# O CPF 00000009785 não é válido.
# O CPF 00000009786 não é válido.
# O CPF 00000009787 não é válido.
# O CPF 00000009788 não é válido.
# O CPF 00000009789 não é válido.
# O CPF 00000009790 não é válido.
# O CPF 00000009791 não é válido.
# O CPF 00000009792 não é válido.
# O CPF 00000009793 não é válido.
# O CPF 00000009794 não é válido.
# O CPF 00000009795 não é válido.
# O CPF 00000009796 não é válido.
# O CPF 00000009797 não é válido.
# O CPF 00000009798 não é válido.
# O CPF 00000009799 não é válido.
# O CPF 00000009800 não é válido.
# O CPF 00000009801 não é válido.
# O CPF 00000009802 não é válido.
# O CPF 00000009803 não é válido.
# O CPF 00000009804 não é válido.
# O CPF 00000009805 não é válido.
# O CPF 00000009806 não é válido.
# O CPF 00000009807 não é válido.
# O CPF 00000009808 não é válido.
# O CPF 00000009809 não é válido.
# O CPF 00000009810 não é válido.
# O CPF 00000009811 não é válido.
# O CPF 00000009812 não é válido.
# O CPF 00000009813 não é válido.
# O CPF 00000009814 é válido.
# O CPF 00000009815 não é válido.
# O CPF 00000009816 não é válido.
# O CPF 00000009817 não é válido.
# O CPF 00000009818 não é válido.
# O CPF 00000009819 não é válido.
# O CPF 00000009820 não é válido.
# O CPF 00000009821 não é válido.
# O CPF 00000009822 não é válido.
# O CPF 00000009823 não é válido.
# O CPF 00000009824 não é válido.
# O CPF 00000009825 não é válido.
# O CPF 00000009826 não é válido.
# O CPF 00000009827 não é válido.
# O CPF 00000009828 não é válido.
# O CPF 00000009829 não é válido.
# O CPF 00000009830 não é válido.
# O CPF 00000009831 não é válido.
# O CPF 00000009832 não é válido.
# O CPF 00000009833 não é válido.
# O CPF 00000009834 não é válido.
# O CPF 00000009835 não é válido.
# O CPF 00000009836 não é válido.
# O CPF 00000009837 não é válido.
# O CPF 00000009838 não é válido.
# O CPF 00000009839 não é válido.
# O CPF 00000009840 não é válido.
# O CPF 00000009841 não é válido.
# O CPF 00000009842 não é válido.
# O CPF 00000009843 não é válido.
# O CPF 00000009844 não é válido.
# O CPF 00000009845 não é válido.
# O CPF 00000009846 não é válido.
# O CPF 00000009847 não é válido.
# O CPF 00000009848 não é válido.
# O CPF 00000009849 não é válido.
# O CPF 00000009850 não é válido.
# O CPF 00000009851 não é válido.
# O CPF 00000009852 não é válido.
# O CPF 00000009853 não é válido.
# O CPF 00000009854 não é válido.
# O CPF 00000009855 não é válido.
# O CPF 00000009856 não é válido.
# O CPF 00000009857 não é válido.
# O CPF 00000009858 não é válido.
# O CPF 00000009859 não é válido.
# O CPF 00000009860 não é válido.
# O CPF 00000009861 não é válido.
# O CPF 00000009862 não é válido.
# O CPF 00000009863 não é válido.
# O CPF 00000009864 não é válido.
# O CPF 00000009865 não é válido.
# O CPF 00000009866 não é válido.
# O CPF 00000009867 não é válido.
# O CPF 00000009868 não é válido.
# O CPF 00000009869 não é válido.
# O CPF 00000009870 não é válido.
# O CPF 00000009871 não é válido.
# O CPF 00000009872 não é válido.
# O CPF 00000009873 não é válido.
# O CPF 00000009874 não é válido.
# O CPF 00000009875 não é válido.
# O CPF 00000009876 não é válido.
# O CPF 00000009877 não é válido.
# O CPF 00000009878 não é válido.
# O CPF 00000009879 não é válido.
# O CPF 00000009880 não é válido.
# O CPF 00000009881 não é válido.
# O CPF 00000009882 não é válido.
# O CPF 00000009883 não é válido.
# O CPF 00000009884 não é válido.
# O CPF 00000009885 não é válido.
# O CPF 00000009886 não é válido.
# O CPF 00000009887 não é válido.
# O CPF 00000009888 não é válido.
# O CPF 00000009889 não é válido.
# O CPF 00000009890 não é válido.
# O CPF 00000009891 não é válido.
# O CPF 00000009892 não é válido.
# O CPF 00000009893 não é válido.
# O CPF 00000009894 não é válido.
# O CPF 00000009895 não é válido.
# O CPF 00000009896 não é válido.
# O CPF 00000009897 não é válido.
# O CPF 00000009898 não é válido.
# O CPF 00000009899 não é válido.
# O CPF 00000009900 não é válido.
# O CPF 00000009901 não é válido.
# O CPF 00000009902 não é válido.
# O CPF 00000009903 não é válido.
# O CPF 00000009904 não é válido.
# O CPF 00000009905 não é válido.
# O CPF 00000009906 não é válido.
# O CPF 00000009907 não é válido.
# O CPF 00000009908 não é válido.
# O CPF 00000009909 não é válido.
# O CPF 00000009910 não é válido.
# O CPF 00000009911 não é válido.
# O CPF 00000009912 não é válido.
# O CPF 00000009913 não é válido.
# O CPF 00000009914 não é válido.
# O CPF 00000009915 não é válido.
# O CPF 00000009916 não é válido.
# O CPF 00000009917 não é válido.
# O CPF 00000009918 não é válido.
# O CPF 00000009919 não é válido.
# O CPF 00000009920 não é válido.
# O CPF 00000009921 não é válido.
# O CPF 00000009922 não é válido.
# O CPF 00000009923 não é válido.
# O CPF 00000009924 não é válido.
# O CPF 00000009925 não é válido.
# O CPF 00000009926 não é válido.
# O CPF 00000009927 não é válido.
# O CPF 00000009928 não é válido.
# O CPF 00000009929 não é válido.
# O CPF 00000009930 não é válido.
# O CPF 00000009931 não é válido.
# O CPF 00000009932 não é válido.
# O CPF 00000009933 não é válido.
# O CPF 00000009934 não é válido.
# O CPF 00000009935 não é válido.
# O CPF 00000009936 não é válido.
# O CPF 00000009937 não é válido.
# O CPF 00000009938 não é válido.
# O CPF 00000009939 não é válido.
# O CPF 00000009940 não é válido.
# O CPF 00000009941 não é válido.
# O CPF 00000009942 não é válido.
# O CPF 00000009943 não é válido.
# O CPF 00000009944 não é válido.
# O CPF 00000009945 não é válido.
# O CPF 00000009946 não é válido.
# O CPF 00000009947 não é válido.
# O CPF 00000009948 não é válido.
# O CPF 00000009949 não é válido.
# O CPF 00000009950 não é válido.
# O CPF 00000009951 não é válido.
# O CPF 00000009952 não é válido.
# O CPF 00000009953 não é válido.
# O CPF 00000009954 não é válido.
# O CPF 00000009955 não é válido.
# O CPF 00000009956 não é válido.
# O CPF 00000009957 não é válido.
# O CPF 00000009958 não é válido.
# O CPF 00000009959 não é válido.
# O CPF 00000009960 não é válido.
# O CPF 00000009961 não é válido.
# O CPF 00000009962 não é válido.
# O CPF 00000009963 não é válido.
# O CPF 00000009964 não é válido.
# O CPF 00000009965 não é válido.
# O CPF 00000009966 não é válido.
# O CPF 00000009967 não é válido.
# O CPF 00000009968 não é válido.
# O CPF 00000009969 não é válido.
# O CPF 00000009970 não é válido.
# O CPF 00000009971 não é válido.
# O CPF 00000009972 não é válido.
# O CPF 00000009973 não é válido.
# O CPF 00000009974 não é válido.
# O CPF 00000009975 não é válido.
# O CPF 00000009976 não é válido.
# O CPF 00000009977 não é válido.
# O CPF 00000009978 não é válido.
# O CPF 00000009979 não é válido.
# O CPF 00000009980 não é válido.
# O CPF 00000009981 não é válido.
# O CPF 00000009982 não é válido.
# O CPF 00000009983 não é válido.
# O CPF 00000009984 não é válido.
# O CPF 00000009985 não é válido.
# O CPF 00000009986 não é válido.
# O CPF 00000009987 não é válido.
# O CPF 00000009988 não é válido.
# O CPF 00000009989 não é válido.
# O CPF 00000009990 não é válido.
# O CPF 00000009991 não é válido.
# O CPF 00000009992 não é válido.
# O CPF 00000009993 não é válido.
# O CPF 00000009994 não é válido.
# O CPF 00000009995 não é válido.
# O CPF 00000009996 não é válido.
# O CPF 00000009997 não é válido.
# O CPF 00000009998 não é válido.
# O CPF 00000009999 não é válido.

# %%
tempo_validar_cpf2 = end_time - start_time
print("Tempo total funcao validar_cpf2:", end_time - start_time, "segundos")
# Out:
# Tempo total funcao validar_cpf2: 0.04699993133544922 segundos

# %%
import time
from tqdm import tqdm
start_time = time.time()
_ = [validar_recurssiva(cpf) for cpf in cpfs]   
end_time = time.time()
# Out:
# O CPF 00000000000 não é válido.
# O CPF 00000000001 não é válido.
# O CPF 00000000002 não é válido.
# O CPF 00000000003 não é válido.
# O CPF 00000000004 não é válido.
# O CPF 00000000005 não é válido.
# O CPF 00000000006 não é válido.
# O CPF 00000000007 não é válido.
# O CPF 00000000008 não é válido.
# O CPF 00000000009 não é válido.
# O CPF 00000000010 não é válido.
# O CPF 00000000011 não é válido.
# O CPF 00000000012 não é válido.
# O CPF 00000000013 não é válido.
# O CPF 00000000014 não é válido.
# O CPF 00000000015 não é válido.
# O CPF 00000000016 não é válido.
# O CPF 00000000017 não é válido.
# O CPF 00000000018 não é válido.
# O CPF 00000000019 não é válido.
# O CPF 00000000020 não é válido.
# O CPF 00000000021 não é válido.
# O CPF 00000000022 não é válido.
# O CPF 00000000023 não é válido.
# O CPF 00000000024 não é válido.
# O CPF 00000000025 não é válido.
# O CPF 00000000026 não é válido.
# O CPF 00000000027 não é válido.
# O CPF 00000000028 não é válido.
# O CPF 00000000029 não é válido.
# O CPF 00000000030 não é válido.
# O CPF 00000000031 não é válido.
# O CPF 00000000032 não é válido.
# O CPF 00000000033 não é válido.
# O CPF 00000000034 não é válido.
# O CPF 00000000035 não é válido.
# O CPF 00000000036 não é válido.
# O CPF 00000000037 não é válido.
# O CPF 00000000038 não é válido.
# O CPF 00000000039 não é válido.
# O CPF 00000000040 não é válido.
# O CPF 00000000041 não é válido.
# O CPF 00000000042 não é válido.
# O CPF 00000000043 não é válido.
# O CPF 00000000044 não é válido.
# O CPF 00000000045 não é válido.
# O CPF 00000000046 não é válido.
# O CPF 00000000047 não é válido.
# O CPF 00000000048 não é válido.
# O CPF 00000000049 não é válido.
# O CPF 00000000050 não é válido.
# O CPF 00000000051 não é válido.
# O CPF 00000000052 não é válido.
# O CPF 00000000053 não é válido.
# O CPF 00000000054 não é válido.
# O CPF 00000000055 não é válido.
# O CPF 00000000056 não é válido.
# O CPF 00000000057 não é válido.
# O CPF 00000000058 não é válido.
# O CPF 00000000059 não é válido.
# O CPF 00000000060 não é válido.
# O CPF 00000000061 não é válido.
# O CPF 00000000062 não é válido.
# O CPF 00000000063 não é válido.
# O CPF 00000000064 não é válido.
# O CPF 00000000065 não é válido.
# O CPF 00000000066 não é válido.
# O CPF 00000000067 não é válido.
# O CPF 00000000068 não é válido.
# O CPF 00000000069 não é válido.
# O CPF 00000000070 não é válido.
# O CPF 00000000071 não é válido.
# O CPF 00000000072 não é válido.
# O CPF 00000000073 não é válido.
# O CPF 00000000074 não é válido.
# O CPF 00000000075 não é válido.
# O CPF 00000000076 não é válido.
# O CPF 00000000077 não é válido.
# O CPF 00000000078 não é válido.
# O CPF 00000000079 não é válido.
# O CPF 00000000080 não é válido.
# O CPF 00000000081 não é válido.
# O CPF 00000000082 não é válido.
# O CPF 00000000083 não é válido.
# O CPF 00000000084 não é válido.
# O CPF 00000000085 não é válido.
# O CPF 00000000086 não é válido.
# O CPF 00000000087 não é válido.
# O CPF 00000000088 não é válido.
# O CPF 00000000089 não é válido.
# O CPF 00000000090 não é válido.
# O CPF 00000000091 não é válido.
# O CPF 00000000092 não é válido.
# O CPF 00000000093 não é válido.
# O CPF 00000000094 não é válido.
# O CPF 00000000095 não é válido.
# O CPF 00000000096 não é válido.
# O CPF 00000000097 não é válido.
# O CPF 00000000098 não é válido.
# O CPF 00000000099 não é válido.
# O CPF 00000000100 não é válido.
# O CPF 00000000101 não é válido.
# O CPF 00000000102 não é válido.
# O CPF 00000000103 não é válido.
# O CPF 00000000104 não é válido.
# O CPF 00000000105 não é válido.
# O CPF 00000000106 não é válido.
# O CPF 00000000107 não é válido.
# O CPF 00000000108 não é válido.
# O CPF 00000000109 não é válido.
# O CPF 00000000110 não é válido.
# O CPF 00000000111 não é válido.
# O CPF 00000000112 não é válido.
# O CPF 00000000113 não é válido.
# O CPF 00000000114 não é válido.
# O CPF 00000000115 não é válido.
# O CPF 00000000116 não é válido.
# O CPF 00000000117 não é válido.
# O CPF 00000000118 não é válido.
# O CPF 00000000119 não é válido.
# O CPF 00000000120 não é válido.
# O CPF 00000000121 não é válido.
# O CPF 00000000122 não é válido.
# O CPF 00000000123 não é válido.
# O CPF 00000000124 não é válido.
# O CPF 00000000125 não é válido.
# O CPF 00000000126 não é válido.
# O CPF 00000000127 não é válido.
# O CPF 00000000128 não é válido.
# O CPF 00000000129 não é válido.
# O CPF 00000000130 não é válido.
# O CPF 00000000131 não é válido.
# O CPF 00000000132 não é válido.
# O CPF 00000000133 não é válido.
# O CPF 00000000134 não é válido.
# O CPF 00000000135 não é válido.
# O CPF 00000000136 não é válido.
# O CPF 00000000137 não é válido.
# O CPF 00000000138 não é válido.
# O CPF 00000000139 não é válido.
# O CPF 00000000140 não é válido.
# O CPF 00000000141 não é válido.
# O CPF 00000000142 não é válido.
# O CPF 00000000143 não é válido.
# O CPF 00000000144 não é válido.
# O CPF 00000000145 não é válido.
# O CPF 00000000146 não é válido.
# O CPF 00000000147 não é válido.
# O CPF 00000000148 não é válido.
# O CPF 00000000149 não é válido.
# O CPF 00000000150 não é válido.
# O CPF 00000000151 não é válido.
# O CPF 00000000152 não é válido.
# O CPF 00000000153 não é válido.
# O CPF 00000000154 não é válido.
# O CPF 00000000155 não é válido.
# O CPF 00000000156 não é válido.
# O CPF 00000000157 não é válido.
# O CPF 00000000158 não é válido.
# O CPF 00000000159 não é válido.
# O CPF 00000000160 não é válido.
# O CPF 00000000161 não é válido.
# O CPF 00000000162 não é válido.
# O CPF 00000000163 não é válido.
# O CPF 00000000164 não é válido.
# O CPF 00000000165 não é válido.
# O CPF 00000000166 não é válido.
# O CPF 00000000167 não é válido.
# O CPF 00000000168 não é válido.
# O CPF 00000000169 não é válido.
# O CPF 00000000170 não é válido.
# O CPF 00000000171 não é válido.
# O CPF 00000000172 não é válido.
# O CPF 00000000173 não é válido.
# O CPF 00000000174 não é válido.
# O CPF 00000000175 não é válido.
# O CPF 00000000176 não é válido.
# O CPF 00000000177 não é válido.
# O CPF 00000000178 não é válido.
# O CPF 00000000179 não é válido.
# O CPF 00000000180 não é válido.
# O CPF 00000000181 não é válido.
# O CPF 00000000182 não é válido.
# O CPF 00000000183 não é válido.
# O CPF 00000000184 não é válido.
# O CPF 00000000185 não é válido.
# O CPF 00000000186 não é válido.
# O CPF 00000000187 não é válido.
# O CPF 00000000188 não é válido.
# O CPF 00000000189 não é válido.
# O CPF 00000000190 não é válido.
# O CPF 00000000191 é válido.
# O CPF 00000000192 não é válido.
# O CPF 00000000193 não é válido.
# O CPF 00000000194 não é válido.
# O CPF 00000000195 não é válido.
# O CPF 00000000196 não é válido.
# O CPF 00000000197 não é válido.
# O CPF 00000000198 não é válido.
# O CPF 00000000199 não é válido.
# O CPF 00000000200 não é válido.
# O CPF 00000000201 não é válido.
# O CPF 00000000202 não é válido.
# O CPF 00000000203 não é válido.
# O CPF 00000000204 não é válido.
# O CPF 00000000205 não é válido.
# O CPF 00000000206 não é válido.
# O CPF 00000000207 não é válido.
# O CPF 00000000208 não é válido.
# O CPF 00000000209 não é válido.
# O CPF 00000000210 não é válido.
# O CPF 00000000211 não é válido.
# O CPF 00000000212 não é válido.
# O CPF 00000000213 não é válido.
# O CPF 00000000214 não é válido.
# O CPF 00000000215 não é válido.
# O CPF 00000000216 não é válido.
# O CPF 00000000217 não é válido.
# O CPF 00000000218 não é válido.
# O CPF 00000000219 não é válido.
# O CPF 00000000220 não é válido.
# O CPF 00000000221 não é válido.
# O CPF 00000000222 não é válido.
# O CPF 00000000223 não é válido.
# O CPF 00000000224 não é válido.
# O CPF 00000000225 não é válido.
# O CPF 00000000226 não é válido.
# O CPF 00000000227 não é válido.
# O CPF 00000000228 não é válido.
# O CPF 00000000229 não é válido.
# O CPF 00000000230 não é válido.
# O CPF 00000000231 não é válido.
# O CPF 00000000232 não é válido.
# O CPF 00000000233 não é válido.
# O CPF 00000000234 não é válido.
# O CPF 00000000235 não é válido.
# O CPF 00000000236 não é válido.
# O CPF 00000000237 não é válido.
# O CPF 00000000238 não é válido.
# O CPF 00000000239 não é válido.
# O CPF 00000000240 não é válido.
# O CPF 00000000241 não é válido.
# O CPF 00000000242 não é válido.
# O CPF 00000000243 não é válido.
# O CPF 00000000244 não é válido.
# O CPF 00000000245 não é válido.
# O CPF 00000000246 não é válido.
# O CPF 00000000247 não é válido.
# O CPF 00000000248 não é válido.
# O CPF 00000000249 não é válido.
# O CPF 00000000250 não é válido.
# O CPF 00000000251 não é válido.
# O CPF 00000000252 não é válido.
# O CPF 00000000253 não é válido.
# O CPF 00000000254 não é válido.
# O CPF 00000000255 não é válido.
# O CPF 00000000256 não é válido.
# O CPF 00000000257 não é válido.
# O CPF 00000000258 não é válido.
# O CPF 00000000259 não é válido.
# O CPF 00000000260 não é válido.
# O CPF 00000000261 não é válido.
# O CPF 00000000262 não é válido.
# O CPF 00000000263 não é válido.
# O CPF 00000000264 não é válido.
# O CPF 00000000265 não é válido.
# O CPF 00000000266 não é válido.
# O CPF 00000000267 não é válido.
# O CPF 00000000268 não é válido.
# O CPF 00000000269 não é válido.
# O CPF 00000000270 não é válido.
# O CPF 00000000271 não é válido.
# O CPF 00000000272 é válido.
# O CPF 00000000273 não é válido.
# O CPF 00000000274 não é válido.
# O CPF 00000000275 não é válido.
# O CPF 00000000276 não é válido.
# O CPF 00000000277 não é válido.
# O CPF 00000000278 não é válido.
# O CPF 00000000279 não é válido.
# O CPF 00000000280 não é válido.
# O CPF 00000000281 não é válido.
# O CPF 00000000282 não é válido.
# O CPF 00000000283 não é válido.
# O CPF 00000000284 não é válido.
# O CPF 00000000285 não é válido.
# O CPF 00000000286 não é válido.
# O CPF 00000000287 não é válido.
# O CPF 00000000288 não é válido.
# O CPF 00000000289 não é válido.
# O CPF 00000000290 não é válido.
# O CPF 00000000291 não é válido.
# O CPF 00000000292 não é válido.
# O CPF 00000000293 não é válido.
# O CPF 00000000294 não é válido.
# O CPF 00000000295 não é válido.
# O CPF 00000000296 não é válido.
# O CPF 00000000297 não é válido.
# O CPF 00000000298 não é válido.
# O CPF 00000000299 não é válido.
# O CPF 00000000300 não é válido.
# O CPF 00000000301 não é válido.
# O CPF 00000000302 não é válido.
# O CPF 00000000303 não é válido.
# O CPF 00000000304 não é válido.
# O CPF 00000000305 não é válido.
# O CPF 00000000306 não é válido.
# O CPF 00000000307 não é válido.
# O CPF 00000000308 não é válido.
# O CPF 00000000309 não é válido.
# O CPF 00000000310 não é válido.
# O CPF 00000000311 não é válido.
# O CPF 00000000312 não é válido.
# O CPF 00000000313 não é válido.
# O CPF 00000000314 não é válido.
# O CPF 00000000315 não é válido.
# O CPF 00000000316 não é válido.
# O CPF 00000000317 não é válido.
# O CPF 00000000318 não é válido.
# O CPF 00000000319 não é válido.
# O CPF 00000000320 não é válido.
# O CPF 00000000321 não é válido.
# O CPF 00000000322 não é válido.
# O CPF 00000000323 não é válido.
# O CPF 00000000324 não é válido.
# O CPF 00000000325 não é válido.
# O CPF 00000000326 não é válido.
# O CPF 00000000327 não é válido.
# O CPF 00000000328 não é válido.
# O CPF 00000000329 não é válido.
# O CPF 00000000330 não é válido.
# O CPF 00000000331 não é válido.
# O CPF 00000000332 não é válido.
# O CPF 00000000333 não é válido.
# O CPF 00000000334 não é válido.
# O CPF 00000000335 não é válido.
# O CPF 00000000336 não é válido.
# O CPF 00000000337 não é válido.
# O CPF 00000000338 não é válido.
# O CPF 00000000339 não é válido.
# O CPF 00000000340 não é válido.
# O CPF 00000000341 não é válido.
# O CPF 00000000342 não é válido.
# O CPF 00000000343 não é válido.
# O CPF 00000000344 não é válido.
# O CPF 00000000345 não é válido.
# O CPF 00000000346 não é válido.
# O CPF 00000000347 não é válido.
# O CPF 00000000348 não é válido.
# O CPF 00000000349 não é válido.
# O CPF 00000000350 não é válido.
# O CPF 00000000351 não é válido.
# O CPF 00000000352 não é válido.
# O CPF 00000000353 é válido.
# O CPF 00000000354 não é válido.
# O CPF 00000000355 não é válido.
# O CPF 00000000356 não é válido.
# O CPF 00000000357 não é válido.
# O CPF 00000000358 não é válido.
# O CPF 00000000359 não é válido.
# O CPF 00000000360 não é válido.
# O CPF 00000000361 não é válido.
# O CPF 00000000362 não é válido.
# O CPF 00000000363 não é válido.
# O CPF 00000000364 não é válido.
# O CPF 00000000365 não é válido.
# O CPF 00000000366 não é válido.
# O CPF 00000000367 não é válido.
# O CPF 00000000368 não é válido.
# O CPF 00000000369 não é válido.
# O CPF 00000000370 não é válido.
# O CPF 00000000371 não é válido.
# O CPF 00000000372 não é válido.
# O CPF 00000000373 não é válido.
# O CPF 00000000374 não é válido.
# O CPF 00000000375 não é válido.
# O CPF 00000000376 não é válido.
# O CPF 00000000377 não é válido.
# O CPF 00000000378 não é válido.
# O CPF 00000000379 não é válido.
# O CPF 00000000380 não é válido.
# O CPF 00000000381 não é válido.
# O CPF 00000000382 não é válido.
# O CPF 00000000383 não é válido.
# O CPF 00000000384 não é válido.
# O CPF 00000000385 não é válido.
# O CPF 00000000386 não é válido.
# O CPF 00000000387 não é válido.
# O CPF 00000000388 não é válido.
# O CPF 00000000389 não é válido.
# O CPF 00000000390 não é válido.
# O CPF 00000000391 não é válido.
# O CPF 00000000392 não é válido.
# O CPF 00000000393 não é válido.
# O CPF 00000000394 não é válido.
# O CPF 00000000395 não é válido.
# O CPF 00000000396 não é válido.
# O CPF 00000000397 não é válido.
# O CPF 00000000398 não é válido.
# O CPF 00000000399 não é válido.
# O CPF 00000000400 não é válido.
# O CPF 00000000401 não é válido.
# O CPF 00000000402 não é válido.
# O CPF 00000000403 não é válido.
# O CPF 00000000404 não é válido.
# O CPF 00000000405 não é válido.
# O CPF 00000000406 não é válido.
# O CPF 00000000407 não é válido.
# O CPF 00000000408 não é válido.
# O CPF 00000000409 não é válido.
# O CPF 00000000410 não é válido.
# O CPF 00000000411 não é válido.
# O CPF 00000000412 não é válido.
# O CPF 00000000413 não é válido.
# O CPF 00000000414 não é válido.
# O CPF 00000000415 não é válido.
# O CPF 00000000416 não é válido.
# O CPF 00000000417 não é válido.
# O CPF 00000000418 não é válido.
# O CPF 00000000419 não é válido.
# O CPF 00000000420 não é válido.
# O CPF 00000000421 não é válido.
# O CPF 00000000422 não é válido.
# O CPF 00000000423 não é válido.
# O CPF 00000000424 não é válido.
# O CPF 00000000425 não é válido.
# O CPF 00000000426 não é válido.
# O CPF 00000000427 não é válido.
# O CPF 00000000428 não é válido.
# O CPF 00000000429 não é válido.
# O CPF 00000000430 não é válido.
# O CPF 00000000431 não é válido.
# O CPF 00000000432 não é válido.
# O CPF 00000000433 não é válido.
# O CPF 00000000434 é válido.
# O CPF 00000000435 não é válido.
# O CPF 00000000436 não é válido.
# O CPF 00000000437 não é válido.
# O CPF 00000000438 não é válido.
# O CPF 00000000439 não é válido.
# O CPF 00000000440 não é válido.
# O CPF 00000000441 não é válido.
# O CPF 00000000442 não é válido.
# O CPF 00000000443 não é válido.
# O CPF 00000000444 não é válido.
# O CPF 00000000445 não é válido.
# O CPF 00000000446 não é válido.
# O CPF 00000000447 não é válido.
# O CPF 00000000448 não é válido.
# O CPF 00000000449 não é válido.
# O CPF 00000000450 não é válido.
# O CPF 00000000451 não é válido.
# O CPF 00000000452 não é válido.
# O CPF 00000000453 não é válido.
# O CPF 00000000454 não é válido.
# O CPF 00000000455 não é válido.
# O CPF 00000000456 não é válido.
# O CPF 00000000457 não é válido.
# O CPF 00000000458 não é válido.
# O CPF 00000000459 não é válido.
# O CPF 00000000460 não é válido.
# O CPF 00000000461 não é válido.
# O CPF 00000000462 não é válido.
# O CPF 00000000463 não é válido.
# O CPF 00000000464 não é válido.
# O CPF 00000000465 não é válido.
# O CPF 00000000466 não é válido.
# O CPF 00000000467 não é válido.
# O CPF 00000000468 não é válido.
# O CPF 00000000469 não é válido.
# O CPF 00000000470 não é válido.
# O CPF 00000000471 não é válido.
# O CPF 00000000472 não é válido.
# O CPF 00000000473 não é válido.
# O CPF 00000000474 não é válido.
# O CPF 00000000475 não é válido.
# O CPF 00000000476 não é válido.
# O CPF 00000000477 não é válido.
# O CPF 00000000478 não é válido.
# O CPF 00000000479 não é válido.
# O CPF 00000000480 não é válido.
# O CPF 00000000481 não é válido.
# O CPF 00000000482 não é válido.
# O CPF 00000000483 não é válido.
# O CPF 00000000484 não é válido.
# O CPF 00000000485 não é válido.
# O CPF 00000000486 não é válido.
# O CPF 00000000487 não é válido.
# O CPF 00000000488 não é válido.
# O CPF 00000000489 não é válido.
# O CPF 00000000490 não é válido.
# O CPF 00000000491 não é válido.
# O CPF 00000000492 não é válido.
# O CPF 00000000493 não é válido.
# O CPF 00000000494 não é válido.
# O CPF 00000000495 não é válido.
# O CPF 00000000496 não é válido.
# O CPF 00000000497 não é válido.
# O CPF 00000000498 não é válido.
# O CPF 00000000499 não é válido.
# O CPF 00000000500 não é válido.
# O CPF 00000000501 não é válido.
# O CPF 00000000502 não é válido.
# O CPF 00000000503 não é válido.
# O CPF 00000000504 não é válido.
# O CPF 00000000505 não é válido.
# O CPF 00000000506 não é válido.
# O CPF 00000000507 não é válido.
# O CPF 00000000508 não é válido.
# O CPF 00000000509 não é válido.
# O CPF 00000000510 não é válido.
# O CPF 00000000511 não é válido.
# O CPF 00000000512 não é válido.
# O CPF 00000000513 não é válido.
# O CPF 00000000514 não é válido.
# O CPF 00000000515 é válido.
# O CPF 00000000516 não é válido.
# O CPF 00000000517 não é válido.
# O CPF 00000000518 não é válido.
# O CPF 00000000519 não é válido.
# O CPF 00000000520 não é válido.
# O CPF 00000000521 não é válido.
# O CPF 00000000522 não é válido.
# O CPF 00000000523 não é válido.
# O CPF 00000000524 não é válido.
# O CPF 00000000525 não é válido.
# O CPF 00000000526 não é válido.
# O CPF 00000000527 não é válido.
# O CPF 00000000528 não é válido.
# O CPF 00000000529 não é válido.
# O CPF 00000000530 não é válido.
# O CPF 00000000531 não é válido.
# O CPF 00000000532 não é válido.
# O CPF 00000000533 não é válido.
# O CPF 00000000534 não é válido.
# O CPF 00000000535 não é válido.
# O CPF 00000000536 não é válido.
# O CPF 00000000537 não é válido.
# O CPF 00000000538 não é válido.
# O CPF 00000000539 não é válido.
# O CPF 00000000540 não é válido.
# O CPF 00000000541 não é válido.
# O CPF 00000000542 não é válido.
# O CPF 00000000543 não é válido.
# O CPF 00000000544 não é válido.
# O CPF 00000000545 não é válido.
# O CPF 00000000546 não é válido.
# O CPF 00000000547 não é válido.
# O CPF 00000000548 não é válido.
# O CPF 00000000549 não é válido.
# O CPF 00000000550 não é válido.
# O CPF 00000000551 não é válido.
# O CPF 00000000552 não é válido.
# O CPF 00000000553 não é válido.
# O CPF 00000000554 não é válido.
# O CPF 00000000555 não é válido.
# O CPF 00000000556 não é válido.
# O CPF 00000000557 não é válido.
# O CPF 00000000558 não é válido.
# O CPF 00000000559 não é válido.
# O CPF 00000000560 não é válido.
# O CPF 00000000561 não é válido.
# O CPF 00000000562 não é válido.
# O CPF 00000000563 não é válido.
# O CPF 00000000564 não é válido.
# O CPF 00000000565 não é válido.
# O CPF 00000000566 não é válido.
# O CPF 00000000567 não é válido.
# O CPF 00000000568 não é válido.
# O CPF 00000000569 não é válido.
# O CPF 00000000570 não é válido.
# O CPF 00000000571 não é válido.
# O CPF 00000000572 não é válido.
# O CPF 00000000573 não é válido.
# O CPF 00000000574 não é válido.
# O CPF 00000000575 não é válido.
# O CPF 00000000576 não é válido.
# O CPF 00000000577 não é válido.
# O CPF 00000000578 não é válido.
# O CPF 00000000579 não é válido.
# O CPF 00000000580 não é válido.
# O CPF 00000000581 não é válido.
# O CPF 00000000582 não é válido.
# O CPF 00000000583 não é válido.
# O CPF 00000000584 não é válido.
# O CPF 00000000585 não é válido.
# O CPF 00000000586 não é válido.
# O CPF 00000000587 não é válido.
# O CPF 00000000588 não é válido.
# O CPF 00000000589 não é válido.
# O CPF 00000000590 não é válido.
# O CPF 00000000591 não é válido.
# O CPF 00000000592 não é válido.
# O CPF 00000000593 não é válido.
# O CPF 00000000594 não é válido.
# O CPF 00000000595 não é válido.
# O CPF 00000000596 não é válido.
# O CPF 00000000597 não é válido.
# O CPF 00000000598 não é válido.
# O CPF 00000000599 não é válido.
# O CPF 00000000600 não é válido.
# O CPF 00000000601 não é válido.
# O CPF 00000000602 não é válido.
# O CPF 00000000603 não é válido.
# O CPF 00000000604 não é válido.
# O CPF 00000000605 não é válido.
# O CPF 00000000606 não é válido.
# O CPF 00000000607 não é válido.
# O CPF 00000000608 não é válido.
# O CPF 00000000609 não é válido.
# O CPF 00000000610 não é válido.
# O CPF 00000000611 não é válido.
# O CPF 00000000612 não é válido.
# O CPF 00000000613 não é válido.
# O CPF 00000000614 não é válido.
# O CPF 00000000615 não é válido.
# O CPF 00000000616 não é válido.
# O CPF 00000000617 não é válido.
# O CPF 00000000618 não é válido.
# O CPF 00000000619 não é válido.
# O CPF 00000000620 não é válido.
# O CPF 00000000621 não é válido.
# O CPF 00000000622 não é válido.
# O CPF 00000000623 não é válido.
# O CPF 00000000624 não é válido.
# O CPF 00000000625 não é válido.
# O CPF 00000000626 não é válido.
# O CPF 00000000627 não é válido.
# O CPF 00000000628 não é válido.
# O CPF 00000000629 não é válido.
# O CPF 00000000630 não é válido.
# O CPF 00000000631 não é válido.
# O CPF 00000000632 não é válido.
# O CPF 00000000633 não é válido.
# O CPF 00000000634 não é válido.
# O CPF 00000000635 não é válido.
# O CPF 00000000636 não é válido.
# O CPF 00000000637 não é válido.
# O CPF 00000000638 não é válido.
# O CPF 00000000639 não é válido.
# O CPF 00000000640 não é válido.
# O CPF 00000000641 não é válido.
# O CPF 00000000642 não é válido.
# O CPF 00000000643 não é válido.
# O CPF 00000000644 não é válido.
# O CPF 00000000645 não é válido.
# O CPF 00000000646 não é válido.
# O CPF 00000000647 não é válido.
# O CPF 00000000648 não é válido.
# O CPF 00000000649 não é válido.
# O CPF 00000000650 não é válido.
# O CPF 00000000651 não é válido.
# O CPF 00000000652 não é válido.
# O CPF 00000000653 não é válido.
# O CPF 00000000654 não é válido.
# O CPF 00000000655 não é válido.
# O CPF 00000000656 não é válido.
# O CPF 00000000657 não é válido.
# O CPF 00000000658 não é válido.
# O CPF 00000000659 não é válido.
# O CPF 00000000660 não é válido.
# O CPF 00000000661 não é válido.
# O CPF 00000000662 não é válido.
# O CPF 00000000663 não é válido.
# O CPF 00000000664 não é válido.
# O CPF 00000000665 não é válido.
# O CPF 00000000666 não é válido.
# O CPF 00000000667 não é válido.
# O CPF 00000000668 não é válido.
# O CPF 00000000669 não é válido.
# O CPF 00000000670 não é válido.
# O CPF 00000000671 não é válido.
# O CPF 00000000672 não é válido.
# O CPF 00000000673 não é válido.
# O CPF 00000000674 não é válido.
# O CPF 00000000675 não é válido.
# O CPF 00000000676 não é válido.
# O CPF 00000000677 não é válido.
# O CPF 00000000678 não é válido.
# O CPF 00000000679 não é válido.
# O CPF 00000000680 não é válido.
# O CPF 00000000681 não é válido.
# O CPF 00000000682 não é válido.
# O CPF 00000000683 não é válido.
# O CPF 00000000684 não é válido.
# O CPF 00000000685 não é válido.
# O CPF 00000000686 não é válido.
# O CPF 00000000687 não é válido.
# O CPF 00000000688 não é válido.
# O CPF 00000000689 não é válido.
# O CPF 00000000690 não é válido.
# O CPF 00000000691 não é válido.
# O CPF 00000000692 não é válido.
# O CPF 00000000693 não é válido.
# O CPF 00000000694 não é válido.
# O CPF 00000000695 não é válido.
# O CPF 00000000696 não é válido.
# O CPF 00000000697 não é válido.
# O CPF 00000000698 não é válido.
# O CPF 00000000699 não é válido.
# O CPF 00000000700 não é válido.
# O CPF 00000000701 não é válido.
# O CPF 00000000702 não é válido.
# O CPF 00000000703 não é válido.
# O CPF 00000000704 não é válido.
# O CPF 00000000705 não é válido.
# O CPF 00000000706 não é válido.
# O CPF 00000000707 não é válido.
# O CPF 00000000708 não é válido.
# O CPF 00000000709 não é válido.
# O CPF 00000000710 não é válido.
# O CPF 00000000711 não é válido.
# O CPF 00000000712 não é válido.
# O CPF 00000000713 não é válido.
# O CPF 00000000714 não é válido.
# O CPF 00000000715 não é válido.
# O CPF 00000000716 não é válido.
# O CPF 00000000717 não é válido.
# O CPF 00000000718 não é válido.
# O CPF 00000000719 não é válido.
# O CPF 00000000720 não é válido.
# O CPF 00000000721 não é válido.
# O CPF 00000000722 não é válido.
# O CPF 00000000723 não é válido.
# O CPF 00000000724 não é válido.
# O CPF 00000000725 não é válido.
# O CPF 00000000726 não é válido.
# O CPF 00000000727 não é válido.
# O CPF 00000000728 não é válido.
# O CPF 00000000729 não é válido.
# O CPF 00000000730 não é válido.
# O CPF 00000000731 não é válido.
# O CPF 00000000732 não é válido.
# O CPF 00000000733 não é válido.
# O CPF 00000000734 não é válido.
# O CPF 00000000735 não é válido.
# O CPF 00000000736 não é válido.
# O CPF 00000000737 não é válido.
# O CPF 00000000738 não é válido.
# O CPF 00000000739 não é válido.
# O CPF 00000000740 não é válido.
# O CPF 00000000741 não é válido.
# O CPF 00000000742 não é válido.
# O CPF 00000000743 não é válido.
# O CPF 00000000744 não é válido.
# O CPF 00000000745 não é válido.
# O CPF 00000000746 não é válido.
# O CPF 00000000747 não é válido.
# O CPF 00000000748 não é válido.
# O CPF 00000000749 não é válido.
# O CPF 00000000750 não é válido.
# O CPF 00000000751 não é válido.
# O CPF 00000000752 não é válido.
# O CPF 00000000753 não é válido.
# O CPF 00000000754 não é válido.
# O CPF 00000000755 não é válido.
# O CPF 00000000756 não é válido.
# O CPF 00000000757 não é válido.
# O CPF 00000000758 não é válido.
# O CPF 00000000759 não é válido.
# O CPF 00000000760 não é válido.
# O CPF 00000000761 não é válido.
# O CPF 00000000762 não é válido.
# O CPF 00000000763 não é válido.
# O CPF 00000000764 não é válido.
# O CPF 00000000765 não é válido.
# O CPF 00000000766 não é válido.
# O CPF 00000000767 não é válido.
# O CPF 00000000768 não é válido.
# O CPF 00000000769 não é válido.
# O CPF 00000000770 não é válido.
# O CPF 00000000771 não é válido.
# O CPF 00000000772 não é válido.
# O CPF 00000000773 não é válido.
# O CPF 00000000774 não é válido.
# O CPF 00000000775 não é válido.
# O CPF 00000000776 não é válido.
# O CPF 00000000777 não é válido.
# O CPF 00000000778 não é válido.
# O CPF 00000000779 não é válido.
# O CPF 00000000780 não é válido.
# O CPF 00000000781 não é válido.
# O CPF 00000000782 não é válido.
# O CPF 00000000783 não é válido.
# O CPF 00000000784 não é válido.
# O CPF 00000000785 não é válido.
# O CPF 00000000786 não é válido.
# O CPF 00000000787 é válido.
# O CPF 00000000788 não é válido.
# O CPF 00000000789 não é válido.
# O CPF 00000000790 não é válido.
# O CPF 00000000791 não é válido.
# O CPF 00000000792 não é válido.
# O CPF 00000000793 não é válido.
# O CPF 00000000794 não é válido.
# O CPF 00000000795 não é válido.
# O CPF 00000000796 não é válido.
# O CPF 00000000797 não é válido.
# O CPF 00000000798 não é válido.
# O CPF 00000000799 não é válido.
# O CPF 00000000800 não é válido.
# O CPF 00000000801 não é válido.
# O CPF 00000000802 não é válido.
# O CPF 00000000803 não é válido.
# O CPF 00000000804 não é válido.
# O CPF 00000000805 não é válido.
# O CPF 00000000806 não é válido.
# O CPF 00000000807 não é válido.
# O CPF 00000000808 não é válido.
# O CPF 00000000809 não é válido.
# O CPF 00000000810 não é válido.
# O CPF 00000000811 não é válido.
# O CPF 00000000812 não é válido.
# O CPF 00000000813 não é válido.
# O CPF 00000000814 não é válido.
# O CPF 00000000815 não é válido.
# O CPF 00000000816 não é válido.
# O CPF 00000000817 não é válido.
# O CPF 00000000818 não é válido.
# O CPF 00000000819 não é válido.
# O CPF 00000000820 não é válido.
# O CPF 00000000821 não é válido.
# O CPF 00000000822 não é válido.
# O CPF 00000000823 não é válido.
# O CPF 00000000824 não é válido.
# O CPF 00000000825 não é válido.
# O CPF 00000000826 não é válido.
# O CPF 00000000827 não é válido.
# O CPF 00000000828 não é válido.
# O CPF 00000000829 não é válido.
# O CPF 00000000830 não é válido.
# O CPF 00000000831 não é válido.
# O CPF 00000000832 não é válido.
# O CPF 00000000833 não é válido.
# O CPF 00000000834 não é válido.
# O CPF 00000000835 não é válido.
# O CPF 00000000836 não é válido.
# O CPF 00000000837 não é válido.
# O CPF 00000000838 não é válido.
# O CPF 00000000839 não é válido.
# O CPF 00000000840 não é válido.
# O CPF 00000000841 não é válido.
# O CPF 00000000842 não é válido.
# O CPF 00000000843 não é válido.
# O CPF 00000000844 não é válido.
# O CPF 00000000845 não é válido.
# O CPF 00000000846 não é válido.
# O CPF 00000000847 não é válido.
# O CPF 00000000848 não é válido.
# O CPF 00000000849 não é válido.
# O CPF 00000000850 não é válido.
# O CPF 00000000851 não é válido.
# O CPF 00000000852 não é válido.
# O CPF 00000000853 não é válido.
# O CPF 00000000854 não é válido.
# O CPF 00000000855 não é válido.
# O CPF 00000000856 não é válido.
# O CPF 00000000857 não é válido.
# O CPF 00000000858 não é válido.
# O CPF 00000000859 não é válido.
# O CPF 00000000860 não é válido.
# O CPF 00000000861 não é válido.
# O CPF 00000000862 não é válido.
# O CPF 00000000863 não é válido.
# O CPF 00000000864 não é válido.
# O CPF 00000000865 não é válido.
# O CPF 00000000866 não é válido.
# O CPF 00000000867 não é válido.
# O CPF 00000000868 é válido.
# O CPF 00000000869 não é válido.
# O CPF 00000000870 não é válido.
# O CPF 00000000871 não é válido.
# O CPF 00000000872 não é válido.
# O CPF 00000000873 não é válido.
# O CPF 00000000874 não é válido.
# O CPF 00000000875 não é válido.
# O CPF 00000000876 não é válido.
# O CPF 00000000877 não é válido.
# O CPF 00000000878 não é válido.
# O CPF 00000000879 não é válido.
# O CPF 00000000880 não é válido.
# O CPF 00000000881 não é válido.
# O CPF 00000000882 não é válido.
# O CPF 00000000883 não é válido.
# O CPF 00000000884 não é válido.
# O CPF 00000000885 não é válido.
# O CPF 00000000886 não é válido.
# O CPF 00000000887 não é válido.
# O CPF 00000000888 não é válido.
# O CPF 00000000889 não é válido.
# O CPF 00000000890 não é válido.
# O CPF 00000000891 não é válido.
# O CPF 00000000892 não é válido.
# O CPF 00000000893 não é válido.
# O CPF 00000000894 não é válido.
# O CPF 00000000895 não é válido.
# O CPF 00000000896 não é válido.
# O CPF 00000000897 não é válido.
# O CPF 00000000898 não é válido.
# O CPF 00000000899 não é válido.
# O CPF 00000000900 não é válido.
# O CPF 00000000901 não é válido.
# O CPF 00000000902 não é válido.
# O CPF 00000000903 não é válido.
# O CPF 00000000904 não é válido.
# O CPF 00000000905 não é válido.
# O CPF 00000000906 não é válido.
# O CPF 00000000907 não é válido.
# O CPF 00000000908 não é válido.
# O CPF 00000000909 não é válido.
# O CPF 00000000910 não é válido.
# O CPF 00000000911 não é válido.
# O CPF 00000000912 não é válido.
# O CPF 00000000913 não é válido.
# O CPF 00000000914 não é válido.
# O CPF 00000000915 não é válido.
# O CPF 00000000916 não é válido.
# O CPF 00000000917 não é válido.
# O CPF 00000000918 não é válido.
# O CPF 00000000919 não é válido.
# O CPF 00000000920 não é válido.
# O CPF 00000000921 não é válido.
# O CPF 00000000922 não é válido.
# O CPF 00000000923 não é válido.
# O CPF 00000000924 não é válido.
# O CPF 00000000925 não é válido.
# O CPF 00000000926 não é válido.
# O CPF 00000000927 não é válido.
# O CPF 00000000928 não é válido.
# O CPF 00000000929 não é válido.
# O CPF 00000000930 não é válido.
# O CPF 00000000931 não é válido.
# O CPF 00000000932 não é válido.
# O CPF 00000000933 não é válido.
# O CPF 00000000934 não é válido.
# O CPF 00000000935 não é válido.
# O CPF 00000000936 não é válido.
# O CPF 00000000937 não é válido.
# O CPF 00000000938 não é válido.
# O CPF 00000000939 não é válido.
# O CPF 00000000940 não é válido.
# O CPF 00000000941 não é válido.
# O CPF 00000000942 não é válido.
# O CPF 00000000943 não é válido.
# O CPF 00000000944 não é válido.
# O CPF 00000000945 não é válido.
# O CPF 00000000946 não é válido.
# O CPF 00000000947 não é válido.
# O CPF 00000000948 não é válido.
# O CPF 00000000949 é válido.
# O CPF 00000000950 não é válido.
# O CPF 00000000951 não é válido.
# O CPF 00000000952 não é válido.
# O CPF 00000000953 não é válido.
# O CPF 00000000954 não é válido.
# O CPF 00000000955 não é válido.
# O CPF 00000000956 não é válido.
# O CPF 00000000957 não é válido.
# O CPF 00000000958 não é válido.
# O CPF 00000000959 não é válido.
# O CPF 00000000960 não é válido.
# O CPF 00000000961 não é válido.
# O CPF 00000000962 não é válido.
# O CPF 00000000963 não é válido.
# O CPF 00000000964 não é válido.
# O CPF 00000000965 não é válido.
# O CPF 00000000966 não é válido.
# O CPF 00000000967 não é válido.
# O CPF 00000000968 não é válido.
# O CPF 00000000969 não é válido.
# O CPF 00000000970 não é válido.
# O CPF 00000000971 não é válido.
# O CPF 00000000972 não é válido.
# O CPF 00000000973 não é válido.
# O CPF 00000000974 não é válido.
# O CPF 00000000975 não é válido.
# O CPF 00000000976 não é válido.
# O CPF 00000000977 não é válido.
# O CPF 00000000978 não é válido.
# O CPF 00000000979 não é válido.
# O CPF 00000000980 não é válido.
# O CPF 00000000981 não é válido.
# O CPF 00000000982 não é válido.
# O CPF 00000000983 não é válido.
# O CPF 00000000984 não é válido.
# O CPF 00000000985 não é válido.
# O CPF 00000000986 não é válido.
# O CPF 00000000987 não é válido.
# O CPF 00000000988 não é válido.
# O CPF 00000000989 não é válido.
# O CPF 00000000990 não é válido.
# O CPF 00000000991 não é válido.
# O CPF 00000000992 não é válido.
# O CPF 00000000993 não é válido.
# O CPF 00000000994 não é válido.
# O CPF 00000000995 não é válido.
# O CPF 00000000996 não é válido.
# O CPF 00000000997 não é válido.
# O CPF 00000000998 não é válido.
# O CPF 00000000999 não é válido.
# O CPF 00000001000 não é válido.
# O CPF 00000001001 não é válido.
# O CPF 00000001002 não é válido.
# O CPF 00000001003 não é válido.
# O CPF 00000001004 não é válido.
# O CPF 00000001005 não é válido.
# O CPF 00000001006 não é válido.
# O CPF 00000001007 não é válido.
# O CPF 00000001008 não é válido.
# O CPF 00000001009 não é válido.
# O CPF 00000001010 não é válido.
# O CPF 00000001011 não é válido.
# O CPF 00000001012 não é válido.
# O CPF 00000001013 não é válido.
# O CPF 00000001014 não é válido.
# O CPF 00000001015 não é válido.
# O CPF 00000001016 não é válido.
# O CPF 00000001017 não é válido.
# O CPF 00000001018 não é válido.
# O CPF 00000001019 não é válido.
# O CPF 00000001020 não é válido.
# O CPF 00000001021 não é válido.
# O CPF 00000001022 não é válido.
# O CPF 00000001023 não é válido.
# O CPF 00000001024 não é válido.
# O CPF 00000001025 não é válido.
# O CPF 00000001026 não é válido.
# O CPF 00000001027 não é válido.
# O CPF 00000001028 não é válido.
# O CPF 00000001029 não é válido.
# O CPF 00000001030 não é válido.
# O CPF 00000001031 não é válido.
# O CPF 00000001032 não é válido.
# O CPF 00000001033 não é válido.
# O CPF 00000001034 não é válido.
# O CPF 00000001035 não é válido.
# O CPF 00000001036 não é válido.
# O CPF 00000001037 não é válido.
# O CPF 00000001038 não é válido.
# O CPF 00000001039 não é válido.
# O CPF 00000001040 não é válido.
# O CPF 00000001041 não é válido.
# O CPF 00000001042 não é válido.
# O CPF 00000001043 não é válido.
# O CPF 00000001044 não é válido.
# O CPF 00000001045 não é válido.
# O CPF 00000001046 não é válido.
# O CPF 00000001047 não é válido.
# O CPF 00000001048 não é válido.
# O CPF 00000001049 não é válido.
# O CPF 00000001050 não é válido.
# O CPF 00000001051 não é válido.
# O CPF 00000001052 não é válido.
# O CPF 00000001053 não é válido.
# O CPF 00000001054 não é válido.
# O CPF 00000001055 não é válido.
# O CPF 00000001056 não é válido.
# O CPF 00000001057 não é válido.
# O CPF 00000001058 não é válido.
# O CPF 00000001059 não é válido.
# O CPF 00000001060 não é válido.
# O CPF 00000001061 não é válido.
# O CPF 00000001062 não é válido.
# O CPF 00000001063 não é válido.
# O CPF 00000001064 não é válido.
# O CPF 00000001065 não é válido.
# O CPF 00000001066 não é válido.
# O CPF 00000001067 não é válido.
# O CPF 00000001068 não é válido.
# O CPF 00000001069 não é válido.
# O CPF 00000001070 não é válido.
# O CPF 00000001071 não é válido.
# O CPF 00000001072 não é válido.
# O CPF 00000001073 não é válido.
# O CPF 00000001074 não é válido.
# O CPF 00000001075 não é válido.
# O CPF 00000001076 não é válido.
# O CPF 00000001077 não é válido.
# O CPF 00000001078 não é válido.
# O CPF 00000001079 não é válido.
# O CPF 00000001080 não é válido.
# O CPF 00000001081 não é válido.
# O CPF 00000001082 é válido.
# O CPF 00000001083 não é válido.
# O CPF 00000001084 não é válido.
# O CPF 00000001085 não é válido.
# O CPF 00000001086 não é válido.
# O CPF 00000001087 não é válido.
# O CPF 00000001088 não é válido.
# O CPF 00000001089 não é válido.
# O CPF 00000001090 não é válido.
# O CPF 00000001091 não é válido.
# O CPF 00000001092 não é válido.
# O CPF 00000001093 não é válido.
# O CPF 00000001094 não é válido.
# O CPF 00000001095 não é válido.
# O CPF 00000001096 não é válido.
# O CPF 00000001097 não é válido.
# O CPF 00000001098 não é válido.
# O CPF 00000001099 não é válido.
# O CPF 00000001100 não é válido.
# O CPF 00000001101 não é válido.
# O CPF 00000001102 não é válido.
# O CPF 00000001103 não é válido.
# O CPF 00000001104 não é válido.
# O CPF 00000001105 não é válido.
# O CPF 00000001106 não é válido.
# O CPF 00000001107 não é válido.
# O CPF 00000001108 não é válido.
# O CPF 00000001109 não é válido.
# O CPF 00000001110 não é válido.
# O CPF 00000001111 não é válido.
# O CPF 00000001112 não é válido.
# O CPF 00000001113 não é válido.
# O CPF 00000001114 não é válido.
# O CPF 00000001115 não é válido.
# O CPF 00000001116 não é válido.
# O CPF 00000001117 não é válido.
# O CPF 00000001118 não é válido.
# O CPF 00000001119 não é válido.
# O CPF 00000001120 não é válido.
# O CPF 00000001121 não é válido.
# O CPF 00000001122 não é válido.
# O CPF 00000001123 não é válido.
# O CPF 00000001124 não é válido.
# O CPF 00000001125 não é válido.
# O CPF 00000001126 não é válido.
# O CPF 00000001127 não é válido.
# O CPF 00000001128 não é válido.
# O CPF 00000001129 não é válido.
# O CPF 00000001130 não é válido.
# O CPF 00000001131 não é válido.
# O CPF 00000001132 não é válido.
# O CPF 00000001133 não é válido.
# O CPF 00000001134 não é válido.
# O CPF 00000001135 não é válido.
# O CPF 00000001136 não é válido.
# O CPF 00000001137 não é válido.
# O CPF 00000001138 não é válido.
# O CPF 00000001139 não é válido.
# O CPF 00000001140 não é válido.
# O CPF 00000001141 não é válido.
# O CPF 00000001142 não é válido.
# O CPF 00000001143 não é válido.
# O CPF 00000001144 não é válido.
# O CPF 00000001145 não é válido.
# O CPF 00000001146 não é válido.
# O CPF 00000001147 não é válido.
# O CPF 00000001148 não é válido.
# O CPF 00000001149 não é válido.
# O CPF 00000001150 não é válido.
# O CPF 00000001151 não é válido.
# O CPF 00000001152 não é válido.
# O CPF 00000001153 não é válido.
# O CPF 00000001154 não é válido.
# O CPF 00000001155 não é válido.
# O CPF 00000001156 não é válido.
# O CPF 00000001157 não é válido.
# O CPF 00000001158 não é válido.
# O CPF 00000001159 não é válido.
# O CPF 00000001160 não é válido.
# O CPF 00000001161 não é válido.
# O CPF 00000001162 não é válido.
# O CPF 00000001163 é válido.
# O CPF 00000001164 não é válido.
# O CPF 00000001165 não é válido.
# O CPF 00000001166 não é válido.
# O CPF 00000001167 não é válido.
# O CPF 00000001168 não é válido.
# O CPF 00000001169 não é válido.
# O CPF 00000001170 não é válido.
# O CPF 00000001171 não é válido.
# O CPF 00000001172 não é válido.
# O CPF 00000001173 não é válido.
# O CPF 00000001174 não é válido.
# O CPF 00000001175 não é válido.
# O CPF 00000001176 não é válido.
# O CPF 00000001177 não é válido.
# O CPF 00000001178 não é válido.
# O CPF 00000001179 não é válido.
# O CPF 00000001180 não é válido.
# O CPF 00000001181 não é válido.
# O CPF 00000001182 não é válido.
# O CPF 00000001183 não é válido.
# O CPF 00000001184 não é válido.
# O CPF 00000001185 não é válido.
# O CPF 00000001186 não é válido.
# O CPF 00000001187 não é válido.
# O CPF 00000001188 não é válido.
# O CPF 00000001189 não é válido.
# O CPF 00000001190 não é válido.
# O CPF 00000001191 não é válido.
# O CPF 00000001192 não é válido.
# O CPF 00000001193 não é válido.
# O CPF 00000001194 não é válido.
# O CPF 00000001195 não é válido.
# O CPF 00000001196 não é válido.
# O CPF 00000001197 não é válido.
# O CPF 00000001198 não é válido.
# O CPF 00000001199 não é válido.
# O CPF 00000001200 não é válido.
# O CPF 00000001201 não é válido.
# O CPF 00000001202 não é válido.
# O CPF 00000001203 não é válido.
# O CPF 00000001204 não é válido.
# O CPF 00000001205 não é válido.
# O CPF 00000001206 não é válido.
# O CPF 00000001207 não é válido.
# O CPF 00000001208 não é válido.
# O CPF 00000001209 não é válido.
# O CPF 00000001210 não é válido.
# O CPF 00000001211 não é válido.
# O CPF 00000001212 não é válido.
# O CPF 00000001213 não é válido.
# O CPF 00000001214 não é válido.
# O CPF 00000001215 não é válido.
# O CPF 00000001216 não é válido.
# O CPF 00000001217 não é válido.
# O CPF 00000001218 não é válido.
# O CPF 00000001219 não é válido.
# O CPF 00000001220 não é válido.
# O CPF 00000001221 não é válido.
# O CPF 00000001222 não é válido.
# O CPF 00000001223 não é válido.
# O CPF 00000001224 não é válido.
# O CPF 00000001225 não é válido.
# O CPF 00000001226 não é válido.
# O CPF 00000001227 não é válido.
# O CPF 00000001228 não é válido.
# O CPF 00000001229 não é válido.
# O CPF 00000001230 não é válido.
# O CPF 00000001231 não é válido.
# O CPF 00000001232 não é válido.
# O CPF 00000001233 não é válido.
# O CPF 00000001234 não é válido.
# O CPF 00000001235 não é válido.
# O CPF 00000001236 não é válido.
# O CPF 00000001237 não é válido.
# O CPF 00000001238 não é válido.
# O CPF 00000001239 não é válido.
# O CPF 00000001240 não é válido.
# O CPF 00000001241 não é válido.
# O CPF 00000001242 não é válido.
# O CPF 00000001243 não é válido.
# O CPF 00000001244 é válido.
# O CPF 00000001245 não é válido.
# O CPF 00000001246 não é válido.
# O CPF 00000001247 não é válido.
# O CPF 00000001248 não é válido.
# O CPF 00000001249 não é válido.
# O CPF 00000001250 não é válido.
# O CPF 00000001251 não é válido.
# O CPF 00000001252 não é válido.
# O CPF 00000001253 não é válido.
# O CPF 00000001254 não é válido.
# O CPF 00000001255 não é válido.
# O CPF 00000001256 não é válido.
# O CPF 00000001257 não é válido.
# O CPF 00000001258 não é válido.
# O CPF 00000001259 não é válido.
# O CPF 00000001260 não é válido.
# O CPF 00000001261 não é válido.
# O CPF 00000001262 não é válido.
# O CPF 00000001263 não é válido.
# O CPF 00000001264 não é válido.
# O CPF 00000001265 não é válido.
# O CPF 00000001266 não é válido.
# O CPF 00000001267 não é válido.
# O CPF 00000001268 não é válido.
# O CPF 00000001269 não é válido.
# O CPF 00000001270 não é válido.
# O CPF 00000001271 não é válido.
# O CPF 00000001272 não é válido.
# O CPF 00000001273 não é válido.
# O CPF 00000001274 não é válido.
# O CPF 00000001275 não é válido.
# O CPF 00000001276 não é válido.
# O CPF 00000001277 não é válido.
# O CPF 00000001278 não é válido.
# O CPF 00000001279 não é válido.
# O CPF 00000001280 não é válido.
# O CPF 00000001281 não é válido.
# O CPF 00000001282 não é válido.
# O CPF 00000001283 não é válido.
# O CPF 00000001284 não é válido.
# O CPF 00000001285 não é válido.
# O CPF 00000001286 não é válido.
# O CPF 00000001287 não é válido.
# O CPF 00000001288 não é válido.
# O CPF 00000001289 não é válido.
# O CPF 00000001290 não é válido.
# O CPF 00000001291 não é válido.
# O CPF 00000001292 não é válido.
# O CPF 00000001293 não é válido.
# O CPF 00000001294 não é válido.
# O CPF 00000001295 não é válido.
# O CPF 00000001296 não é válido.
# O CPF 00000001297 não é válido.
# O CPF 00000001298 não é válido.
# O CPF 00000001299 não é válido.
# O CPF 00000001300 não é válido.
# O CPF 00000001301 não é válido.
# O CPF 00000001302 não é válido.
# O CPF 00000001303 não é válido.
# O CPF 00000001304 não é válido.
# O CPF 00000001305 não é válido.
# O CPF 00000001306 não é válido.
# O CPF 00000001307 não é válido.
# O CPF 00000001308 não é válido.
# O CPF 00000001309 não é válido.
# O CPF 00000001310 não é válido.
# O CPF 00000001311 não é válido.
# O CPF 00000001312 não é válido.
# O CPF 00000001313 não é válido.
# O CPF 00000001314 não é válido.
# O CPF 00000001315 não é válido.
# O CPF 00000001316 não é válido.
# O CPF 00000001317 não é válido.
# O CPF 00000001318 não é válido.
# O CPF 00000001319 não é válido.
# O CPF 00000001320 não é válido.
# O CPF 00000001321 não é válido.
# O CPF 00000001322 não é válido.
# O CPF 00000001323 não é válido.
# O CPF 00000001324 não é válido.
# O CPF 00000001325 é válido.
# O CPF 00000001326 não é válido.
# O CPF 00000001327 não é válido.
# O CPF 00000001328 não é válido.
# O CPF 00000001329 não é válido.
# O CPF 00000001330 não é válido.
# O CPF 00000001331 não é válido.
# O CPF 00000001332 não é válido.
# O CPF 00000001333 não é válido.
# O CPF 00000001334 não é válido.
# O CPF 00000001335 não é válido.
# O CPF 00000001336 não é válido.
# O CPF 00000001337 não é válido.
# O CPF 00000001338 não é válido.
# O CPF 00000001339 não é válido.
# O CPF 00000001340 não é válido.
# O CPF 00000001341 não é válido.
# O CPF 00000001342 não é válido.
# O CPF 00000001343 não é válido.
# O CPF 00000001344 não é válido.
# O CPF 00000001345 não é válido.
# O CPF 00000001346 não é válido.
# O CPF 00000001347 não é válido.
# O CPF 00000001348 não é válido.
# O CPF 00000001349 não é válido.
# O CPF 00000001350 não é válido.
# O CPF 00000001351 não é válido.
# O CPF 00000001352 não é válido.
# O CPF 00000001353 não é válido.
# O CPF 00000001354 não é válido.
# O CPF 00000001355 não é válido.
# O CPF 00000001356 não é válido.
# O CPF 00000001357 não é válido.
# O CPF 00000001358 não é válido.
# O CPF 00000001359 não é válido.
# O CPF 00000001360 não é válido.
# O CPF 00000001361 não é válido.
# O CPF 00000001362 não é válido.
# O CPF 00000001363 não é válido.
# O CPF 00000001364 não é válido.
# O CPF 00000001365 não é válido.
# O CPF 00000001366 não é válido.
# O CPF 00000001367 não é válido.
# O CPF 00000001368 não é válido.
# O CPF 00000001369 não é válido.
# O CPF 00000001370 não é válido.
# O CPF 00000001371 não é válido.
# O CPF 00000001372 não é válido.
# O CPF 00000001373 não é válido.
# O CPF 00000001374 não é válido.
# O CPF 00000001375 não é válido.
# O CPF 00000001376 não é válido.
# O CPF 00000001377 não é válido.
# O CPF 00000001378 não é válido.
# O CPF 00000001379 não é válido.
# O CPF 00000001380 não é válido.
# O CPF 00000001381 não é válido.
# O CPF 00000001382 não é válido.
# O CPF 00000001383 não é válido.
# O CPF 00000001384 não é válido.
# O CPF 00000001385 não é válido.
# O CPF 00000001386 não é válido.
# O CPF 00000001387 não é válido.
# O CPF 00000001388 não é válido.
# O CPF 00000001389 não é válido.
# O CPF 00000001390 não é válido.
# O CPF 00000001391 não é válido.
# O CPF 00000001392 não é válido.
# O CPF 00000001393 não é válido.
# O CPF 00000001394 não é válido.
# O CPF 00000001395 não é válido.
# O CPF 00000001396 não é válido.
# O CPF 00000001397 não é válido.
# O CPF 00000001398 não é válido.
# O CPF 00000001399 não é válido.
# O CPF 00000001400 não é válido.
# O CPF 00000001401 não é válido.
# O CPF 00000001402 não é válido.
# O CPF 00000001403 não é válido.
# O CPF 00000001404 não é válido.
# O CPF 00000001405 não é válido.
# O CPF 00000001406 é válido.
# O CPF 00000001407 não é válido.
# O CPF 00000001408 não é válido.
# O CPF 00000001409 não é válido.
# O CPF 00000001410 não é válido.
# O CPF 00000001411 não é válido.
# O CPF 00000001412 não é válido.
# O CPF 00000001413 não é válido.
# O CPF 00000001414 não é válido.
# O CPF 00000001415 não é válido.
# O CPF 00000001416 não é válido.
# O CPF 00000001417 não é válido.
# O CPF 00000001418 não é válido.
# O CPF 00000001419 não é válido.
# O CPF 00000001420 não é válido.
# O CPF 00000001421 não é válido.
# O CPF 00000001422 não é válido.
# O CPF 00000001423 não é válido.
# O CPF 00000001424 não é válido.
# O CPF 00000001425 não é válido.
# O CPF 00000001426 não é válido.
# O CPF 00000001427 não é válido.
# O CPF 00000001428 não é válido.
# O CPF 00000001429 não é válido.
# O CPF 00000001430 não é válido.
# O CPF 00000001431 não é válido.
# O CPF 00000001432 não é válido.
# O CPF 00000001433 não é válido.
# O CPF 00000001434 não é válido.
# O CPF 00000001435 não é válido.
# O CPF 00000001436 não é válido.
# O CPF 00000001437 não é válido.
# O CPF 00000001438 não é válido.
# O CPF 00000001439 não é válido.
# O CPF 00000001440 não é válido.
# O CPF 00000001441 não é válido.
# O CPF 00000001442 não é válido.
# O CPF 00000001443 não é válido.
# O CPF 00000001444 não é válido.
# O CPF 00000001445 não é válido.
# O CPF 00000001446 não é válido.
# O CPF 00000001447 não é válido.
# O CPF 00000001448 não é válido.
# O CPF 00000001449 não é válido.
# O CPF 00000001450 não é válido.
# O CPF 00000001451 não é válido.
# O CPF 00000001452 não é válido.
# O CPF 00000001453 não é válido.
# O CPF 00000001454 não é válido.
# O CPF 00000001455 não é válido.
# O CPF 00000001456 não é válido.
# O CPF 00000001457 não é válido.
# O CPF 00000001458 não é válido.
# O CPF 00000001459 não é válido.
# O CPF 00000001460 não é válido.
# O CPF 00000001461 não é válido.
# O CPF 00000001462 não é válido.
# O CPF 00000001463 não é válido.
# O CPF 00000001464 não é válido.
# O CPF 00000001465 não é válido.
# O CPF 00000001466 não é válido.
# O CPF 00000001467 não é válido.
# O CPF 00000001468 não é válido.
# O CPF 00000001469 não é válido.
# O CPF 00000001470 não é válido.
# O CPF 00000001471 não é válido.
# O CPF 00000001472 não é válido.
# O CPF 00000001473 não é válido.
# O CPF 00000001474 não é válido.
# O CPF 00000001475 não é válido.
# O CPF 00000001476 não é válido.
# O CPF 00000001477 não é válido.
# O CPF 00000001478 não é válido.
# O CPF 00000001479 não é válido.
# O CPF 00000001480 não é válido.
# O CPF 00000001481 não é válido.
# O CPF 00000001482 não é válido.
# O CPF 00000001483 não é válido.
# O CPF 00000001484 não é válido.
# O CPF 00000001485 não é válido.
# O CPF 00000001486 não é válido.
# O CPF 00000001487 não é válido.
# O CPF 00000001488 não é válido.
# O CPF 00000001489 não é válido.
# O CPF 00000001490 não é válido.
# O CPF 00000001491 não é válido.
# O CPF 00000001492 não é válido.
# O CPF 00000001493 não é válido.
# O CPF 00000001494 não é válido.
# O CPF 00000001495 não é válido.
# O CPF 00000001496 não é válido.
# O CPF 00000001497 não é válido.
# O CPF 00000001498 não é válido.
# O CPF 00000001499 não é válido.
# O CPF 00000001500 não é válido.
# ...
# O CPF 00000009500 não é válido.
# O CPF 00000009501 não é válido.
# O CPF 00000009502 não é válido.
# O CPF 00000009503 não é válido.
# O CPF 00000009504 não é válido.
# O CPF 00000009505 não é válido.
# O CPF 00000009506 não é válido.
# O CPF 00000009507 não é válido.
# O CPF 00000009508 não é válido.
# O CPF 00000009509 não é válido.
# O CPF 00000009510 não é válido.
# O CPF 00000009511 não é válido.
# O CPF 00000009512 não é válido.
# O CPF 00000009513 não é válido.
# O CPF 00000009514 não é válido.
# O CPF 00000009515 não é válido.
# O CPF 00000009516 não é válido.
# O CPF 00000009517 não é válido.
# O CPF 00000009518 não é válido.
# O CPF 00000009519 não é válido.
# O CPF 00000009520 não é válido.
# O CPF 00000009521 não é válido.
# O CPF 00000009522 não é válido.
# O CPF 00000009523 não é válido.
# O CPF 00000009524 não é válido.
# O CPF 00000009525 não é válido.
# O CPF 00000009526 não é válido.
# O CPF 00000009527 não é válido.
# O CPF 00000009528 não é válido.
# O CPF 00000009529 não é válido.
# O CPF 00000009530 não é válido.
# O CPF 00000009531 não é válido.
# O CPF 00000009532 não é válido.
# O CPF 00000009533 não é válido.
# O CPF 00000009534 não é válido.
# O CPF 00000009535 não é válido.
# O CPF 00000009536 não é válido.
# O CPF 00000009537 não é válido.
# O CPF 00000009538 não é válido.
# O CPF 00000009539 não é válido.
# O CPF 00000009540 não é válido.
# O CPF 00000009541 não é válido.
# O CPF 00000009542 não é válido.
# O CPF 00000009543 não é válido.
# O CPF 00000009544 não é válido.
# O CPF 00000009545 não é válido.
# O CPF 00000009546 não é válido.
# O CPF 00000009547 não é válido.
# O CPF 00000009548 não é válido.
# O CPF 00000009549 não é válido.
# O CPF 00000009550 não é válido.
# O CPF 00000009551 não é válido.
# O CPF 00000009552 não é válido.
# O CPF 00000009553 não é válido.
# O CPF 00000009554 não é válido.
# O CPF 00000009555 não é válido.
# O CPF 00000009556 não é válido.
# O CPF 00000009557 não é válido.
# O CPF 00000009558 não é válido.
# O CPF 00000009559 não é válido.
# O CPF 00000009560 não é válido.
# O CPF 00000009561 não é válido.
# O CPF 00000009562 não é válido.
# O CPF 00000009563 não é válido.
# O CPF 00000009564 não é válido.
# O CPF 00000009565 não é válido.
# O CPF 00000009566 não é válido.
# O CPF 00000009567 não é válido.
# O CPF 00000009568 não é válido.
# O CPF 00000009569 não é válido.
# O CPF 00000009570 não é válido.
# O CPF 00000009571 é válido.
# O CPF 00000009572 não é válido.
# O CPF 00000009573 não é válido.
# O CPF 00000009574 não é válido.
# O CPF 00000009575 não é válido.
# O CPF 00000009576 não é válido.
# O CPF 00000009577 não é válido.
# O CPF 00000009578 não é válido.
# O CPF 00000009579 não é válido.
# O CPF 00000009580 não é válido.
# O CPF 00000009581 não é válido.
# O CPF 00000009582 não é válido.
# O CPF 00000009583 não é válido.
# O CPF 00000009584 não é válido.
# O CPF 00000009585 não é válido.
# O CPF 00000009586 não é válido.
# O CPF 00000009587 não é válido.
# O CPF 00000009588 não é válido.
# O CPF 00000009589 não é válido.
# O CPF 00000009590 não é válido.
# O CPF 00000009591 não é válido.
# O CPF 00000009592 não é válido.
# O CPF 00000009593 não é válido.
# O CPF 00000009594 não é válido.
# O CPF 00000009595 não é válido.
# O CPF 00000009596 não é válido.
# O CPF 00000009597 não é válido.
# O CPF 00000009598 não é válido.
# O CPF 00000009599 não é válido.
# O CPF 00000009600 não é válido.
# O CPF 00000009601 não é válido.
# O CPF 00000009602 não é válido.
# O CPF 00000009603 não é válido.
# O CPF 00000009604 não é válido.
# O CPF 00000009605 não é válido.
# O CPF 00000009606 não é válido.
# O CPF 00000009607 não é válido.
# O CPF 00000009608 não é válido.
# O CPF 00000009609 não é válido.
# O CPF 00000009610 não é válido.
# O CPF 00000009611 não é válido.
# O CPF 00000009612 não é válido.
# O CPF 00000009613 não é válido.
# O CPF 00000009614 não é válido.
# O CPF 00000009615 não é válido.
# O CPF 00000009616 não é válido.
# O CPF 00000009617 não é válido.
# O CPF 00000009618 não é válido.
# O CPF 00000009619 não é válido.
# O CPF 00000009620 não é válido.
# O CPF 00000009621 não é válido.
# O CPF 00000009622 não é válido.
# O CPF 00000009623 não é válido.
# O CPF 00000009624 não é válido.
# O CPF 00000009625 não é válido.
# O CPF 00000009626 não é válido.
# O CPF 00000009627 não é válido.
# O CPF 00000009628 não é válido.
# O CPF 00000009629 não é válido.
# O CPF 00000009630 não é válido.
# O CPF 00000009631 não é válido.
# O CPF 00000009632 não é válido.
# O CPF 00000009633 não é válido.
# O CPF 00000009634 não é válido.
# O CPF 00000009635 não é válido.
# O CPF 00000009636 não é válido.
# O CPF 00000009637 não é válido.
# O CPF 00000009638 não é válido.
# O CPF 00000009639 não é válido.
# O CPF 00000009640 não é válido.
# O CPF 00000009641 não é válido.
# O CPF 00000009642 não é válido.
# O CPF 00000009643 não é válido.
# O CPF 00000009644 não é válido.
# O CPF 00000009645 não é válido.
# O CPF 00000009646 não é válido.
# O CPF 00000009647 não é válido.
# O CPF 00000009648 não é válido.
# O CPF 00000009649 não é válido.
# O CPF 00000009650 não é válido.
# O CPF 00000009651 não é válido.
# O CPF 00000009652 é válido.
# O CPF 00000009653 não é válido.
# O CPF 00000009654 não é válido.
# O CPF 00000009655 não é válido.
# O CPF 00000009656 não é válido.
# O CPF 00000009657 não é válido.
# O CPF 00000009658 não é válido.
# O CPF 00000009659 não é válido.
# O CPF 00000009660 não é válido.
# O CPF 00000009661 não é válido.
# O CPF 00000009662 não é válido.
# O CPF 00000009663 não é válido.
# O CPF 00000009664 não é válido.
# O CPF 00000009665 não é válido.
# O CPF 00000009666 não é válido.
# O CPF 00000009667 não é válido.
# O CPF 00000009668 não é válido.
# O CPF 00000009669 não é válido.
# O CPF 00000009670 não é válido.
# O CPF 00000009671 não é válido.
# O CPF 00000009672 não é válido.
# O CPF 00000009673 não é válido.
# O CPF 00000009674 não é válido.
# O CPF 00000009675 não é válido.
# O CPF 00000009676 não é válido.
# O CPF 00000009677 não é válido.
# O CPF 00000009678 não é válido.
# O CPF 00000009679 não é válido.
# O CPF 00000009680 não é válido.
# O CPF 00000009681 não é válido.
# O CPF 00000009682 não é válido.
# O CPF 00000009683 não é válido.
# O CPF 00000009684 não é válido.
# O CPF 00000009685 não é válido.
# O CPF 00000009686 não é válido.
# O CPF 00000009687 não é válido.
# O CPF 00000009688 não é válido.
# O CPF 00000009689 não é válido.
# O CPF 00000009690 não é válido.
# O CPF 00000009691 não é válido.
# O CPF 00000009692 não é válido.
# O CPF 00000009693 não é válido.
# O CPF 00000009694 não é válido.
# O CPF 00000009695 não é válido.
# O CPF 00000009696 não é válido.
# O CPF 00000009697 não é válido.
# O CPF 00000009698 não é válido.
# O CPF 00000009699 não é válido.
# O CPF 00000009700 não é válido.
# O CPF 00000009701 não é válido.
# O CPF 00000009702 não é válido.
# O CPF 00000009703 não é válido.
# O CPF 00000009704 não é válido.
# O CPF 00000009705 não é válido.
# O CPF 00000009706 não é válido.
# O CPF 00000009707 não é válido.
# O CPF 00000009708 não é válido.
# O CPF 00000009709 não é válido.
# O CPF 00000009710 não é válido.
# O CPF 00000009711 não é válido.
# O CPF 00000009712 não é válido.
# O CPF 00000009713 não é válido.
# O CPF 00000009714 não é válido.
# O CPF 00000009715 não é válido.
# O CPF 00000009716 não é válido.
# O CPF 00000009717 não é válido.
# O CPF 00000009718 não é válido.
# O CPF 00000009719 não é válido.
# O CPF 00000009720 não é válido.
# O CPF 00000009721 não é válido.
# O CPF 00000009722 não é válido.
# O CPF 00000009723 não é válido.
# O CPF 00000009724 não é válido.
# O CPF 00000009725 não é válido.
# O CPF 00000009726 não é válido.
# O CPF 00000009727 não é válido.
# O CPF 00000009728 não é válido.
# O CPF 00000009729 não é válido.
# O CPF 00000009730 não é válido.
# O CPF 00000009731 não é válido.
# O CPF 00000009732 não é válido.
# O CPF 00000009733 é válido.
# O CPF 00000009734 não é válido.
# O CPF 00000009735 não é válido.
# O CPF 00000009736 não é válido.
# O CPF 00000009737 não é válido.
# O CPF 00000009738 não é válido.
# O CPF 00000009739 não é válido.
# O CPF 00000009740 não é válido.
# O CPF 00000009741 não é válido.
# O CPF 00000009742 não é válido.
# O CPF 00000009743 não é válido.
# O CPF 00000009744 não é válido.
# O CPF 00000009745 não é válido.
# O CPF 00000009746 não é válido.
# O CPF 00000009747 não é válido.
# O CPF 00000009748 não é válido.
# O CPF 00000009749 não é válido.
# O CPF 00000009750 não é válido.
# O CPF 00000009751 não é válido.
# O CPF 00000009752 não é válido.
# O CPF 00000009753 não é válido.
# O CPF 00000009754 não é válido.
# O CPF 00000009755 não é válido.
# O CPF 00000009756 não é válido.
# O CPF 00000009757 não é válido.
# O CPF 00000009758 não é válido.
# O CPF 00000009759 não é válido.
# O CPF 00000009760 não é válido.
# O CPF 00000009761 não é válido.
# O CPF 00000009762 não é válido.
# O CPF 00000009763 não é válido.
# O CPF 00000009764 não é válido.
# O CPF 00000009765 não é válido.
# O CPF 00000009766 não é válido.
# O CPF 00000009767 não é válido.
# O CPF 00000009768 não é válido.
# O CPF 00000009769 não é válido.
# O CPF 00000009770 não é válido.
# O CPF 00000009771 não é válido.
# O CPF 00000009772 não é válido.
# O CPF 00000009773 não é válido.
# O CPF 00000009774 não é válido.
# O CPF 00000009775 não é válido.
# O CPF 00000009776 não é válido.
# O CPF 00000009777 não é válido.
# O CPF 00000009778 não é válido.
# O CPF 00000009779 não é válido.
# O CPF 00000009780 não é válido.
# O CPF 00000009781 não é válido.
# O CPF 00000009782 não é válido.
# O CPF 00000009783 não é válido.
# O CPF 00000009784 não é válido.
# O CPF 00000009785 não é válido.
# O CPF 00000009786 não é válido.
# O CPF 00000009787 não é válido.
# O CPF 00000009788 não é válido.
# O CPF 00000009789 não é válido.
# O CPF 00000009790 não é válido.
# O CPF 00000009791 não é válido.
# O CPF 00000009792 não é válido.
# O CPF 00000009793 não é válido.
# O CPF 00000009794 não é válido.
# O CPF 00000009795 não é válido.
# O CPF 00000009796 não é válido.
# O CPF 00000009797 não é válido.
# O CPF 00000009798 não é válido.
# O CPF 00000009799 não é válido.
# O CPF 00000009800 não é válido.
# O CPF 00000009801 não é válido.
# O CPF 00000009802 não é válido.
# O CPF 00000009803 não é válido.
# O CPF 00000009804 não é válido.
# O CPF 00000009805 não é válido.
# O CPF 00000009806 não é válido.
# O CPF 00000009807 não é válido.
# O CPF 00000009808 não é válido.
# O CPF 00000009809 não é válido.
# O CPF 00000009810 não é válido.
# O CPF 00000009811 não é válido.
# O CPF 00000009812 não é válido.
# O CPF 00000009813 não é válido.
# O CPF 00000009814 é válido.
# O CPF 00000009815 não é válido.
# O CPF 00000009816 não é válido.
# O CPF 00000009817 não é válido.
# O CPF 00000009818 não é válido.
# O CPF 00000009819 não é válido.
# O CPF 00000009820 não é válido.
# O CPF 00000009821 não é válido.
# O CPF 00000009822 não é válido.
# O CPF 00000009823 não é válido.
# O CPF 00000009824 não é válido.
# O CPF 00000009825 não é válido.
# O CPF 00000009826 não é válido.
# O CPF 00000009827 não é válido.
# O CPF 00000009828 não é válido.
# O CPF 00000009829 não é válido.
# O CPF 00000009830 não é válido.
# O CPF 00000009831 não é válido.
# O CPF 00000009832 não é válido.
# O CPF 00000009833 não é válido.
# O CPF 00000009834 não é válido.
# O CPF 00000009835 não é válido.
# O CPF 00000009836 não é válido.
# O CPF 00000009837 não é válido.
# O CPF 00000009838 não é válido.
# O CPF 00000009839 não é válido.
# O CPF 00000009840 não é válido.
# O CPF 00000009841 não é válido.
# O CPF 00000009842 não é válido.
# O CPF 00000009843 não é válido.
# O CPF 00000009844 não é válido.
# O CPF 00000009845 não é válido.
# O CPF 00000009846 não é válido.
# O CPF 00000009847 não é válido.
# O CPF 00000009848 não é válido.
# O CPF 00000009849 não é válido.
# O CPF 00000009850 não é válido.
# O CPF 00000009851 não é válido.
# O CPF 00000009852 não é válido.
# O CPF 00000009853 não é válido.
# O CPF 00000009854 não é válido.
# O CPF 00000009855 não é válido.
# O CPF 00000009856 não é válido.
# O CPF 00000009857 não é válido.
# O CPF 00000009858 não é válido.
# O CPF 00000009859 não é válido.
# O CPF 00000009860 não é válido.
# O CPF 00000009861 não é válido.
# O CPF 00000009862 não é válido.
# O CPF 00000009863 não é válido.
# O CPF 00000009864 não é válido.
# O CPF 00000009865 não é válido.
# O CPF 00000009866 não é válido.
# O CPF 00000009867 não é válido.
# O CPF 00000009868 não é válido.
# O CPF 00000009869 não é válido.
# O CPF 00000009870 não é válido.
# O CPF 00000009871 não é válido.
# O CPF 00000009872 não é válido.
# O CPF 00000009873 não é válido.
# O CPF 00000009874 não é válido.
# O CPF 00000009875 não é válido.
# O CPF 00000009876 não é válido.
# O CPF 00000009877 não é válido.
# O CPF 00000009878 não é válido.
# O CPF 00000009879 não é válido.
# O CPF 00000009880 não é válido.
# O CPF 00000009881 não é válido.
# O CPF 00000009882 não é válido.
# O CPF 00000009883 não é válido.
# O CPF 00000009884 não é válido.
# O CPF 00000009885 não é válido.
# O CPF 00000009886 não é válido.
# O CPF 00000009887 não é válido.
# O CPF 00000009888 não é válido.
# O CPF 00000009889 não é válido.
# O CPF 00000009890 não é válido.
# O CPF 00000009891 não é válido.
# O CPF 00000009892 não é válido.
# O CPF 00000009893 não é válido.
# O CPF 00000009894 não é válido.
# O CPF 00000009895 não é válido.
# O CPF 00000009896 não é válido.
# O CPF 00000009897 não é válido.
# O CPF 00000009898 não é válido.
# O CPF 00000009899 não é válido.
# O CPF 00000009900 não é válido.
# O CPF 00000009901 não é válido.
# O CPF 00000009902 não é válido.
# O CPF 00000009903 não é válido.
# O CPF 00000009904 não é válido.
# O CPF 00000009905 não é válido.
# O CPF 00000009906 não é válido.
# O CPF 00000009907 não é válido.
# O CPF 00000009908 não é válido.
# O CPF 00000009909 não é válido.
# O CPF 00000009910 não é válido.
# O CPF 00000009911 não é válido.
# O CPF 00000009912 não é válido.
# O CPF 00000009913 não é válido.
# O CPF 00000009914 não é válido.
# O CPF 00000009915 não é válido.
# O CPF 00000009916 não é válido.
# O CPF 00000009917 não é válido.
# O CPF 00000009918 não é válido.
# O CPF 00000009919 não é válido.
# O CPF 00000009920 não é válido.
# O CPF 00000009921 não é válido.
# O CPF 00000009922 não é válido.
# O CPF 00000009923 não é válido.
# O CPF 00000009924 não é válido.
# O CPF 00000009925 não é válido.
# O CPF 00000009926 não é válido.
# O CPF 00000009927 não é válido.
# O CPF 00000009928 não é válido.
# O CPF 00000009929 não é válido.
# O CPF 00000009930 não é válido.
# O CPF 00000009931 não é válido.
# O CPF 00000009932 não é válido.
# O CPF 00000009933 não é válido.
# O CPF 00000009934 não é válido.
# O CPF 00000009935 não é válido.
# O CPF 00000009936 não é válido.
# O CPF 00000009937 não é válido.
# O CPF 00000009938 não é válido.
# O CPF 00000009939 não é válido.
# O CPF 00000009940 não é válido.
# O CPF 00000009941 não é válido.
# O CPF 00000009942 não é válido.
# O CPF 00000009943 não é válido.
# O CPF 00000009944 não é válido.
# O CPF 00000009945 não é válido.
# O CPF 00000009946 não é válido.
# O CPF 00000009947 não é válido.
# O CPF 00000009948 não é válido.
# O CPF 00000009949 não é válido.
# O CPF 00000009950 não é válido.
# O CPF 00000009951 não é válido.
# O CPF 00000009952 não é válido.
# O CPF 00000009953 não é válido.
# O CPF 00000009954 não é válido.
# O CPF 00000009955 não é válido.
# O CPF 00000009956 não é válido.
# O CPF 00000009957 não é válido.
# O CPF 00000009958 não é válido.
# O CPF 00000009959 não é válido.
# O CPF 00000009960 não é válido.
# O CPF 00000009961 não é válido.
# O CPF 00000009962 não é válido.
# O CPF 00000009963 não é válido.
# O CPF 00000009964 não é válido.
# O CPF 00000009965 não é válido.
# O CPF 00000009966 não é válido.
# O CPF 00000009967 não é válido.
# O CPF 00000009968 não é válido.
# O CPF 00000009969 não é válido.
# O CPF 00000009970 não é válido.
# O CPF 00000009971 não é válido.
# O CPF 00000009972 não é válido.
# O CPF 00000009973 não é válido.
# O CPF 00000009974 não é válido.
# O CPF 00000009975 não é válido.
# O CPF 00000009976 não é válido.
# O CPF 00000009977 não é válido.
# O CPF 00000009978 não é válido.
# O CPF 00000009979 não é válido.
# O CPF 00000009980 não é válido.
# O CPF 00000009981 não é válido.
# O CPF 00000009982 não é válido.
# O CPF 00000009983 não é válido.
# O CPF 00000009984 não é válido.
# O CPF 00000009985 não é válido.
# O CPF 00000009986 não é válido.
# O CPF 00000009987 não é válido.
# O CPF 00000009988 não é válido.
# O CPF 00000009989 não é válido.
# O CPF 00000009990 não é válido.
# O CPF 00000009991 não é válido.
# O CPF 00000009992 não é válido.
# O CPF 00000009993 não é válido.
# O CPF 00000009994 não é válido.
# O CPF 00000009995 não é válido.
# O CPF 00000009996 não é válido.
# O CPF 00000009997 não é válido.
# O CPF 00000009998 não é válido.
# O CPF 00000009999 não é válido.

# %%
tempo_validar_recurssiva = end_time - start_time
print("Tempo total funcao validar_cpf2:", end_time - start_time, "segundos")
# Out:
# Tempo total funcao validar_cpf2: 0.06305050849914551 segundos

# %%
import pandas as pd
tempos = {'Função': {0: 'validacao_cpf',
                     1: 'validar_cpf',
                     2: 'validar_cpf2',
                     3: 'validar_recurssiva'},
          'Tempo': {0: tempo_validacao_cpf,
                     1: tempo_validar_cpf,
                     2: tempo_validar_cpf2,
                     3: tempo_validar_recurssiva}}
tempos = pd.DataFrame(tempos)
tempos
# Out:
#                Função     Tempo
# 0       validacao_cpf  0.054999
# 1         validar_cpf  0.047113
# 2        validar_cpf2  0.047000
# 3  validar_recurssiva  0.063051

# %% [markdown]
# ### Portanto, concluimos que a função "validar_cpf2" é a que performa mais rápido.
